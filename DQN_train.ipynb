# %% [markdown]
# # LunarLander DQN Training
#
# Interactive training notebook with configurable hyperparameters.

# %%
import gymnasium as gym
from src.envs.make_env import make_env
from src.agents.epsilon_greedy_agent import EpsilonGreedyAgent
from src.networks.q_network import QNetwork
from src.replay.replay_buffer import ReplayBuffer
from src.training.trainer import Trainer
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Hyperparameters Configuration
#
# Modify these values to tune the training process:

# %%
# ============ TRAINING HYPERPARAMETERS ============
# Environment
num_episodes = 800  # Total number of training episodes
log_interval = 20  # Print stats every N episodes

# Training
train_every = 4  # Training step every N environment steps
batch_size = 64
learning_rate = 0.0001
gamma = 0.99  # Discount factor
replay_buffer_size = 50000  # Maximum size of the replay buffer

# Target Network Update
update_mode = 'soft'  # 'soft' for soft update every step, 'hard' for hard update every N steps
tau = 1e-1  # Soft update rate (used only if update_mode='soft')
target_update_freq = 100  # Hard update frequency (used only if update_mode='hard')

# Exploration
epsilon_starting_value = 1  # Initial exploration rate
epsilon_ending_value = 0.01   # Final exploration rate
epsilon_decay_value = 0.995   # Decay factor per episode

# %% [markdown]
# ## Initialize Components

# %%
# Initialize Q-Network
q_network = QNetwork(input_size=8, output_size=4)

# Initialize epsilon from config
epsilon = epsilon_starting_value

# Initialize agent
agent = EpsilonGreedyAgent(action_space=4, q_network=q_network, epsilon=epsilon)

# Initialize replay buffer
replay_buffer = ReplayBuffer(max_size=replay_buffer_size)

# Initialize trainer with hyperparameters
trainer = Trainer(
    q_network, 
    learning_rate=learning_rate, 
    replay_buffer=replay_buffer, 
    gamma=gamma,
    update_mode=update_mode,
    tau=tau,
    target_update_freq=target_update_freq
)

# Create environment
env = make_env(render_mode="rgb_array")
# Out:
# c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
import csv
import os
import pandas as pd
from src.training.episode_outcome import categorize_episode_outcome, get_outcome_icon

# ===== AUTO-INCREMENT RUN ID =====
configs_file = 'runs/all_configs_combined.csv'
runs_file = 'runs/all_runs_combined.csv'

# Read existing configs to find last run_id
df_configs = pd.read_csv(configs_file, dtype={'run_id': str})
last_run_id = df_configs['run_id'].astype(int).max()
new_run_id = str(last_run_id + 1).zfill(2)

print(f"📋 Last run_id found: {last_run_id:02d}")
print(f"🆕 New run_id: {new_run_id}")

# ===== APPEND NEW CONFIG TO all_configs_combined.csv =====
new_config = {
    'run_id': new_run_id,
    'num_episodes': num_episodes,
    'log_interval': log_interval,
    'train_every': train_every,
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'gamma': gamma,
    'update_mode': update_mode,
    'tau': tau,
    'target_update_freq': target_update_freq,
    'replay_buffer_size': replay_buffer_size,
    'epsilon_starting_value': epsilon_starting_value,
    'epsilon_ending_value': epsilon_ending_value,
    'epsilon_decay_value': epsilon_decay_value
}

# Append to configs file
new_config_df = pd.DataFrame([new_config])
new_config_df.to_csv(configs_file, mode='a', header=False, index=False)
print(f"✅ Config appended to {configs_file}")

# ===== SETUP LOG FILE =====
run_list_dir = 'runs/run_list'
os.makedirs(run_list_dir, exist_ok=True)
log_file = f'{run_list_dir}/run{new_run_id}.csv'

with open(log_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['episode', 'reward', 'length', 'terminated', 'truncated', 'outcome'])

print(f"📁 Log file created: {log_file}")
# Out:
# 📋 Last run_id found: 16
# 🆕 New run_id: 17
# ✅ Config appended to runs/all_configs_combined.csv
# 📁 Log file created: runs/run_list/run17.csv

# %% [markdown]
# ## Training Loop with Visualization

# %%
# Training loop with episode outcome logging
episode_rewards = []
training_steps = 0
episode_outcomes = []
episode_logs = []  # Store logs for appending to combined file

print(f"🚀 Starting training for Run {new_run_id}...\n")

for episode in range(num_episodes):
    obs, info = env.reset()
    total_reward = 0.0
    terminated = False
    truncated = False
    episode_length = 0
    final_obs = obs
    last_step_reward = 0.0  # keep last reward of the episode

    while not (terminated or truncated):
        # Ask agent for action
        action = agent.act(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)

        # store last step reward (used for outcome classification)
        last_step_reward = reward

        # Store transition in replay buffer
        done = terminated or truncated
        replay_buffer.add(obs, action, reward, next_obs, done)

        # Training step: sample batch and update network
        if training_steps % train_every == 0:
            loss = trainer.train_step(batch_size=batch_size)

        training_steps += 1
        total_reward += reward
        episode_length += 1
        obs = next_obs
        final_obs = next_obs

    episode_rewards.append(total_reward)

    # Categorize episode outcome
    outcome = categorize_episode_outcome(final_obs, episode_length, last_step_reward)
    episode_outcomes.append(outcome)

    # Store log entry
    log_entry = {
        'run_id': new_run_id,
        'episode': episode + 1,
        'reward': round(total_reward, 2),
        'length': episode_length,
        'terminated': int(terminated),
        'truncated': int(truncated),
        'outcome': outcome
    }
    episode_logs.append(log_entry)

    # Log to individual run CSV file
    with open(log_file, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([episode + 1, f"{total_reward:.2f}", episode_length,
                         int(terminated), int(truncated), outcome])

    # Decay epsilon after each episode
    epsilon = max(epsilon_ending_value, epsilon * epsilon_decay_value)
    agent.set_epsilon(epsilon)

    # Print individual episode result
    outcome_icon = get_outcome_icon(outcome)
    print(
        f"Episode {episode + 1:4d} | Steps: {episode_length:4d} | Reward: {total_reward:7.2f} | "
        f"{outcome_icon} {outcome.replace('_', ' ').title()} | ε: {epsilon:.4f}"
    )

    # Log average reward every N episodes
    if (episode + 1) % log_interval == 0:
        avg_reward = sum(episode_rewards[-log_interval:]) / log_interval

        # Count outcomes in recent window
        recent_outcomes = episode_outcomes[-log_interval:]
        outcome_counts = {
            'success': recent_outcomes.count('landed_success'),
            'crashed': recent_outcomes.count('crashed'),
            'out_of_bounds': recent_outcomes.count('out_of_bounds'),
            'time_limit': recent_outcomes.count('time_limit')
        }

        print(
            f"  └─ Avg Reward: {avg_reward:7.3f} | "
            f"Success: {outcome_counts['success']}, "
            f"Crashed: {outcome_counts['crashed']}, "
            f"Out of bounds: {outcome_counts['out_of_bounds']}, "
            f"Time limit: {outcome_counts['time_limit']}"
        )
        print()

env.close()

# ===== APPEND LOGS TO all_runs_combined.csv =====
logs_df = pd.DataFrame(episode_logs)
logs_df.to_csv(runs_file, mode='a', header=False, index=False)
print(f"✅ Logs appended to {runs_file}")

print(f"\n✅ Training completed for Run {new_run_id}!")
print(f"Total episodes: {num_episodes}")
print(f"Replay buffer size: {len(replay_buffer)} transitions")
print(f"Total training steps: {training_steps}")
print(f"Final epsilon: {epsilon:.4f}")

# Final statistics
success_count = episode_outcomes.count('landed_success')
crashed_count = episode_outcomes.count('crashed')
out_of_bounds_count = episode_outcomes.count('out_of_bounds')
time_limit_count = episode_outcomes.count('time_limit')

print(f"\n📊 Episode Outcomes:")
print(f"  🚀 Landed successfully: {success_count} ({100*success_count/num_episodes:.1f}%)")
print(f"  💥 Crashed: {crashed_count} ({100*crashed_count/num_episodes:.1f}%)")
print(f"  📍 Out of bounds: {out_of_bounds_count} ({100*out_of_bounds_count/num_episodes:.1f}%)")
print(f"  ⏱️  Time limit: {time_limit_count} ({100*time_limit_count/num_episodes:.1f}%)")
print(f"\n📁 Individual log saved to: {log_file}")
print(f"📁 Combined logs updated: {runs_file}")
print(f"📁 Configs updated: {configs_file}")
# Out:
# 🚀 Starting training for Run 17...
#
# Episode    1 | Steps:   84 | Reward:  -81.79 | 🔴 Crashed | ε: 0.9950
# Episode    2 | Steps:  118 | Reward: -398.18 | 🔴 Crashed | ε: 0.9900
# Episode    3 | Steps:   90 | Reward: -104.31 | 🔴 Crashed | ε: 0.9851
# Episode    4 | Steps:  139 | Reward: -168.79 | 🔴 Crashed | ε: 0.9801
# Episode    5 | Steps:   76 | Reward:  -56.68 | 🔴 Crashed | ε: 0.9752
# Episode    6 | Steps:  101 | Reward: -320.90 | 🟡 Out Of Bounds | ε: 0.9704
# Episode    7 | Steps:   63 | Reward:  -95.46 | 🔴 Crashed | ε: 0.9655
# Episode    8 | Steps:   81 | Reward: -163.90 | 🔴 Crashed | ε: 0.9607
# Episode    9 | Steps:   74 | Reward:  -89.29 | 🔴 Crashed | ε: 0.9559
# Episode   10 | Steps:   72 | Reward: -114.92 | 🔴 Crashed | ε: 0.9511
# Episode   11 | Steps:   95 | Reward: -319.78 | 🟡 Out Of Bounds | ε: 0.9464
# Episode   12 | Steps:   98 | Reward: -231.29 | 🔴 Crashed | ε: 0.9416
# Episode   13 | Steps:   65 | Reward: -240.43 | 🔴 Crashed | ε: 0.9369
# Episode   14 | Steps:   93 | Reward: -102.74 | 🔴 Crashed | ε: 0.9322
# Episode   15 | Steps:   86 | Reward: -168.17 | 🔴 Crashed | ε: 0.9276
# Episode   16 | Steps:   95 | Reward: -106.01 | 🔴 Crashed | ε: 0.9229
# Episode   17 | Steps:   98 | Reward:  -87.35 | 🔴 Crashed | ε: 0.9183
# Episode   18 | Steps:  105 | Reward: -336.96 | 🔴 Crashed | ε: 0.9137
# Episode   19 | Steps:   96 | Reward: -433.30 | 🟡 Out Of Bounds | ε: 0.9092
# Episode   20 | Steps:   99 | Reward: -134.56 | 🔴 Crashed | ε: 0.9046
#   └─ Avg Reward: -187.740 | Success: 0, Crashed: 17, Out of bounds: 3, Time limit: 0
#
# Episode   21 | Steps:  122 | Reward:    8.43 | 🔴 Crashed | ε: 0.9001
# Episode   22 | Steps:   79 | Reward:  -44.76 | 🔴 Crashed | ε: 0.8956
# Episode   23 | Steps:  102 | Reward:  -99.99 | 🔴 Crashed | ε: 0.8911
# Episode   24 | Steps:   89 | Reward: -113.46 | 🔴 Crashed | ε: 0.8867
# Episode   25 | Steps:   95 | Reward: -422.37 | 🔴 Crashed | ε: 0.8822
# Episode   26 | Steps:   95 | Reward: -230.61 | 🔴 Crashed | ε: 0.8778
# Episode   27 | Steps:   90 | Reward: -111.90 | 🔴 Crashed | ε: 0.8734
# Episode   28 | Steps:   79 | Reward: -160.73 | 🔴 Crashed | ε: 0.8691
# Episode   29 | Steps:   85 | Reward: -261.23 | 🔴 Crashed | ε: 0.8647
# Episode   30 | Steps:   85 | Reward: -403.48 | 🟡 Out Of Bounds | ε: 0.8604
# Episode   31 | Steps:   87 | Reward:  -91.31 | 🔴 Crashed | ε: 0.8561
# Episode   32 | Steps:  148 | Reward: -567.58 | 🟡 Out Of Bounds | ε: 0.8518
# Episode   33 | Steps:   88 | Reward:  -49.20 | 🔴 Crashed | ε: 0.8475
# Episode   34 | Steps:  114 | Reward: -358.23 | 🔴 Crashed | ε: 0.8433
# Episode   35 | Steps:  108 | Reward: -410.97 | 🟡 Out Of Bounds | ε: 0.8391
# Episode   36 | Steps:   90 | Reward: -410.10 | 🟡 Out Of Bounds | ε: 0.8349
# Episode   37 | Steps:  100 | Reward: -333.38 | 🔴 Crashed | ε: 0.8307
# Episode   38 | Steps:  127 | Reward: -108.00 | 🔴 Crashed | ε: 0.8266
# Episode   39 | Steps:  108 | Reward: -160.33 | 🟡 Out Of Bounds | ε: 0.8224
# Episode   40 | Steps:  103 | Reward: -146.75 | 🟡 Out Of Bounds | ε: 0.8183
#   └─ Avg Reward: -223.797 | Success: 0, Crashed: 14, Out of bounds: 6, Time limit: 0
#
# Episode   41 | Steps:   80 | Reward:  -57.12 | 🔴 Crashed | ε: 0.8142
# Episode   42 | Steps:   91 | Reward: -362.77 | 🟡 Out Of Bounds | ε: 0.8102
# Episode   43 | Steps:   78 | Reward:  -66.25 | 🔴 Crashed | ε: 0.8061
# Episode   44 | Steps:   85 | Reward: -112.51 | 🔴 Crashed | ε: 0.8021
# Episode   45 | Steps:   91 | Reward:  -96.96 | 🔴 Crashed | ε: 0.7981
# Episode   46 | Steps:  109 | Reward: -210.16 | 🔴 Crashed | ε: 0.7941
# Episode   47 | Steps:   71 | Reward:  -65.30 | 🔴 Crashed | ε: 0.7901
# Episode   48 | Steps:   84 | Reward: -181.42 | 🔴 Crashed | ε: 0.7862
# Episode   49 | Steps:   95 | Reward:  -86.18 | 🔴 Crashed | ε: 0.7822
# Episode   50 | Steps:  107 | Reward: -210.75 | 🔴 Crashed | ε: 0.7783
# Episode   51 | Steps:   91 | Reward: -139.98 | 🔴 Crashed | ε: 0.7744
# Episode   52 | Steps:  114 | Reward: -201.68 | 🔴 Crashed | ε: 0.7705
# Episode   53 | Steps:  143 | Reward: -155.47 | 🔴 Crashed | ε: 0.7667
# Episode   54 | Steps:   89 | Reward: -123.58 | 🔴 Crashed | ε: 0.7629
# Episode   55 | Steps:   86 | Reward: -120.81 | 🔴 Crashed | ε: 0.7590
# Episode   56 | Steps:  121 | Reward: -167.28 | 🔴 Crashed | ε: 0.7553
# Episode   57 | Steps:  115 | Reward: -165.91 | 🔴 Crashed | ε: 0.7515
# Episode   58 | Steps:  117 | Reward: -160.30 | 🔴 Crashed | ε: 0.7477
# Episode   59 | Steps:  145 | Reward: -152.77 | 🔴 Crashed | ε: 0.7440
# Episode   60 | Steps:   88 | Reward: -141.22 | 🔴 Crashed | ε: 0.7403
#   └─ Avg Reward: -148.923 | Success: 0, Crashed: 19, Out of bounds: 1, Time limit: 0
#
# Episode   61 | Steps:   80 | Reward:  -92.41 | 🔴 Crashed | ε: 0.7366
# Episode   62 | Steps:   77 | Reward:  -53.33 | 🔴 Crashed | ε: 0.7329
# Episode   63 | Steps:  107 | Reward:  -84.66 | 🔴 Crashed | ε: 0.7292
# Episode   64 | Steps:  154 | Reward:  -49.43 | 🔴 Crashed | ε: 0.7256
# Episode   65 | Steps:  137 | Reward:  -95.36 | 🔴 Crashed | ε: 0.7219
# Episode   66 | Steps:  138 | Reward:  -51.34 | 🔴 Crashed | ε: 0.7183
# Episode   67 | Steps:  146 | Reward:  -18.67 | 🔴 Crashed | ε: 0.7147
# Episode   68 | Steps:  105 | Reward: -194.26 | 🔴 Crashed | ε: 0.7112
# Episode   69 | Steps:   81 | Reward: -117.64 | 🔴 Crashed | ε: 0.7076
# Episode   70 | Steps:  118 | Reward: -114.33 | 🔴 Crashed | ε: 0.7041
# Episode   71 | Steps:   95 | Reward: -115.72 | 🔴 Crashed | ε: 0.7005
# Episode   72 | Steps:  119 | Reward: -117.47 | 🔴 Crashed | ε: 0.6970
# Episode   73 | Steps:  156 | Reward:  -53.62 | 🔴 Crashed | ε: 0.6936
# Episode   74 | Steps:   88 | Reward:  -85.46 | 🔴 Crashed | ε: 0.6901
# Episode   75 | Steps:   89 | Reward:  -62.74 | 🔴 Crashed | ε: 0.6866
# Episode   76 | Steps:  132 | Reward:  -59.10 | 🔴 Crashed | ε: 0.6832
# Episode   77 | Steps:  122 | Reward: -139.38 | 🔴 Crashed | ε: 0.6798
# Episode   78 | Steps:  131 | Reward:  -81.78 | 🔴 Crashed | ε: 0.6764
# Episode   79 | Steps:  115 | Reward:   11.41 | 🔴 Crashed | ε: 0.6730
# Episode   80 | Steps:   73 | Reward:  -84.76 | 🔴 Crashed | ε: 0.6696
#   └─ Avg Reward: -83.003 | Success: 0, Crashed: 20, Out of bounds: 0, Time limit: 0
#
# Episode   81 | Steps:  112 | Reward: -289.59 | 🔴 Crashed | ε: 0.6663
# Episode   82 | Steps:   82 | Reward:  -74.87 | 🔴 Crashed | ε: 0.6630
# Episode   83 | Steps:  126 | Reward: -241.65 | 🔴 Crashed | ε: 0.6597
# Episode   84 | Steps:  107 | Reward:  -63.96 | 🔴 Crashed | ε: 0.6564
# Episode   85 | Steps:   82 | Reward: -115.40 | 🔴 Crashed | ε: 0.6531
# Episode   86 | Steps:  144 | Reward:  -35.70 | 🔴 Crashed | ε: 0.6498
# Episode   87 | Steps:  165 | Reward:  -33.51 | 🔴 Crashed | ε: 0.6466
# Episode   88 | Steps:  115 | Reward: -118.99 | 🔴 Crashed | ε: 0.6433
# Episode   89 | Steps:  117 | Reward:  -40.08 | 🔴 Crashed | ε: 0.6401
# Episode   90 | Steps:   81 | Reward:  -77.62 | 🔴 Crashed | ε: 0.6369
# Episode   91 | Steps:  208 | Reward:  -73.82 | 🔴 Crashed | ε: 0.6337
# Episode   92 | Steps:  198 | Reward:  -74.05 | 🔴 Crashed | ε: 0.6306
# Episode   93 | Steps:  262 | Reward: -109.66 | 🔴 Crashed | ε: 0.6274
# Episode   94 | Steps:  199 | Reward:  -46.00 | 🔴 Crashed | ε: 0.6243
# Episode   95 | Steps:  143 | Reward:  -65.87 | 🔴 Crashed | ε: 0.6211
# Episode   96 | Steps:  127 | Reward: -190.24 | 🔴 Crashed | ε: 0.6180
# Episode   97 | Steps:  182 | Reward: -106.86 | 🔴 Crashed | ε: 0.6149
# Episode   98 | Steps:  108 | Reward:  -69.96 | 🔴 Crashed | ε: 0.6119
# Episode   99 | Steps:  123 | Reward:  -98.96 | 🔴 Crashed | ε: 0.6088
# Episode  100 | Steps:  105 | Reward:  -12.44 | 🔴 Crashed | ε: 0.6058
#   └─ Avg Reward: -96.962 | Success: 0, Crashed: 20, Out of bounds: 0, Time limit: 0
#
# Episode  101 | Steps:  307 | Reward: -142.42 | 🔴 Crashed | ε: 0.6027
# Episode  102 | Steps:  160 | Reward:  -97.55 | 🔴 Crashed | ε: 0.5997
# Episode  103 | Steps:  138 | Reward:  -48.53 | 🔴 Crashed | ε: 0.5967
# Episode  104 | Steps:  128 | Reward: -110.46 | 🔴 Crashed | ε: 0.5937
# Episode  105 | Steps:  198 | Reward:  -47.11 | 🔴 Crashed | ε: 0.5908
# Episode  106 | Steps:  156 | Reward:  -52.62 | 🔴 Crashed | ε: 0.5878
# Episode  107 | Steps:  140 | Reward:  -21.09 | 🔴 Crashed | ε: 0.5849
# Episode  108 | Steps:  152 | Reward:  -78.33 | 🔴 Crashed | ε: 0.5820
# Episode  109 | Steps:  239 | Reward: -136.80 | 🔴 Crashed | ε: 0.5790
# Episode  110 | Steps:   91 | Reward: -112.26 | 🔴 Crashed | ε: 0.5762
# Episode  111 | Steps:  192 | Reward:  -48.97 | 🔴 Crashed | ε: 0.5733
# Episode  112 | Steps:  263 | Reward:  -10.29 | 🔴 Crashed | ε: 0.5704
# Episode  113 | Steps:  180 | Reward:  -85.64 | 🔴 Crashed | ε: 0.5676
# Episode  114 | Steps:  218 | Reward: -101.29 | 🔴 Crashed | ε: 0.5647
# Episode  115 | Steps:  171 | Reward: -169.38 | 🔴 Crashed | ε: 0.5619
# Episode  116 | Steps:  123 | Reward:   -6.65 | 🔴 Crashed | ε: 0.5591
# Episode  117 | Steps:  105 | Reward: -134.95 | 🔴 Crashed | ε: 0.5563
# Episode  118 | Steps:  174 | Reward: -106.14 | 🔴 Crashed | ε: 0.5535
# Episode  119 | Steps:  115 | Reward:  -87.61 | 🔴 Crashed | ε: 0.5507
# Episode  120 | Steps:  276 | Reward: -139.44 | 🔴 Crashed | ε: 0.5480
#   └─ Avg Reward: -86.877 | Success: 0, Crashed: 20, Out of bounds: 0, Time limit: 0
#
# Episode  121 | Steps:  132 | Reward: -130.38 | 🔴 Crashed | ε: 0.5452
# Episode  122 | Steps:  168 | Reward:  -32.41 | 🔴 Crashed | ε: 0.5425
# Episode  123 | Steps:  115 | Reward:  -54.17 | 🔴 Crashed | ε: 0.5398
# Episode  124 | Steps:  223 | Reward:  -97.00 | 🔴 Crashed | ε: 0.5371
# Episode  125 | Steps:  229 | Reward: -182.72 | 🟡 Out Of Bounds | ε: 0.5344
# Episode  126 | Steps:  129 | Reward:  -55.88 | 🔴 Crashed | ε: 0.5318
# Episode  127 | Steps:  151 | Reward:  -81.65 | 🔴 Crashed | ε: 0.5291
# Episode  128 | Steps:  135 | Reward:   -0.80 | 🔴 Crashed | ε: 0.5264
# Episode  129 | Steps:   86 | Reward:  -67.23 | 🔴 Crashed | ε: 0.5238
# Episode  130 | Steps:  270 | Reward: -159.77 | 🔴 Crashed | ε: 0.5212
# Episode  131 | Steps:  218 | Reward:  -18.98 | 🔴 Crashed | ε: 0.5186
# Episode  132 | Steps:  106 | Reward:  -63.59 | 🔴 Crashed | ε: 0.5160
# Episode  133 | Steps:  357 | Reward:  -22.47 | 🔴 Crashed | ε: 0.5134
# Episode  134 | Steps:  146 | Reward: -138.77 | 🔴 Crashed | ε: 0.5108
# Episode  135 | Steps:  222 | Reward:  -89.35 | 🟡 Out Of Bounds | ε: 0.5083
# Episode  136 | Steps:  180 | Reward: -143.93 | 🔴 Crashed | ε: 0.5058
# Episode  137 | Steps:  472 | Reward: -184.68 | 🔴 Crashed | ε: 0.5032
# Episode  138 | Steps:  180 | Reward:  -48.93 | 🔴 Crashed | ε: 0.5007
# Episode  139 | Steps:  324 | Reward: -270.80 | 🔴 Crashed | ε: 0.4982
# Episode  140 | Steps: 1000 | Reward: -106.03 | 🔵 Time Limit | ε: 0.4957
#   └─ Avg Reward: -97.479 | Success: 0, Crashed: 17, Out of bounds: 2, Time limit: 1
#
# Episode  141 | Steps:  193 | Reward:  -57.10 | 🔴 Crashed | ε: 0.4932
# Episode  142 | Steps:  166 | Reward:  -51.97 | 🔴 Crashed | ε: 0.4908
# Episode  143 | Steps: 1000 | Reward:    6.72 | 🔵 Time Limit | ε: 0.4883
# Episode  144 | Steps:  189 | Reward:  -25.99 | 🔴 Crashed | ε: 0.4859
# Episode  145 | Steps:  212 | Reward:  -96.25 | 🔴 Crashed | ε: 0.4834
# Episode  146 | Steps:  189 | Reward:  -22.37 | 🔴 Crashed | ε: 0.4810
# Episode  147 | Steps:  133 | Reward:  -51.69 | 🔴 Crashed | ε: 0.4786
# Episode  148 | Steps:  127 | Reward:  -89.11 | 🟡 Out Of Bounds | ε: 0.4762
# Episode  149 | Steps: 1000 | Reward:  -32.61 | 🔵 Time Limit | ε: 0.4738
# Episode  150 | Steps:  241 | Reward: -116.17 | 🔴 Crashed | ε: 0.4715
# Episode  151 | Steps:  159 | Reward:  -32.83 | 🔴 Crashed | ε: 0.4691
# Episode  152 | Steps:  167 | Reward:  -37.32 | 🔴 Crashed | ε: 0.4668
# Episode  153 | Steps:  455 | Reward: -127.69 | 🔴 Crashed | ε: 0.4644
# Episode  154 | Steps: 1000 | Reward:  -32.80 | 🔵 Time Limit | ε: 0.4621
# Episode  155 | Steps:  145 | Reward:  -80.21 | 🔴 Crashed | ε: 0.4598
# Episode  156 | Steps:  493 | Reward: -176.04 | 🔴 Crashed | ε: 0.4575
# Episode  157 | Steps:  860 | Reward: -122.36 | 🔴 Crashed | ε: 0.4552
# Episode  158 | Steps:  204 | Reward:  -44.69 | 🔴 Crashed | ε: 0.4529
# Episode  159 | Steps:  126 | Reward:  -47.80 | 🔴 Crashed | ε: 0.4507
# Episode  160 | Steps:  178 | Reward: -239.43 | 🔴 Crashed | ε: 0.4484
#   └─ Avg Reward: -73.886 | Success: 0, Crashed: 16, Out of bounds: 1, Time limit: 3
#
# Episode  161 | Steps: 1000 | Reward:   -9.42 | 🔵 Time Limit | ε: 0.4462
# Episode  162 | Steps:  241 | Reward:  -14.10 | 🔴 Crashed | ε: 0.4440
# Episode  163 | Steps:  696 | Reward:  -71.78 | 🔴 Crashed | ε: 0.4417
# Episode  164 | Steps:  537 | Reward:  -76.52 | 🔴 Crashed | ε: 0.4395
# Episode  165 | Steps:  321 | Reward:  -29.71 | 🔴 Crashed | ε: 0.4373
# Episode  166 | Steps: 1000 | Reward:   10.86 | 🔵 Time Limit | ε: 0.4351
# Episode  167 | Steps:   93 | Reward:  -66.21 | 🔴 Crashed | ε: 0.4330
# Episode  168 | Steps:  646 | Reward:  -48.97 | 🔴 Crashed | ε: 0.4308
# Episode  169 | Steps: 1000 | Reward:  -66.02 | 🔵 Time Limit | ε: 0.4286
# Episode  170 | Steps:  163 | Reward:  -39.95 | 🔴 Crashed | ε: 0.4265
# Episode  171 | Steps: 1000 | Reward:   -4.92 | 🔵 Time Limit | ε: 0.4244
# Episode  172 | Steps:  210 | Reward: -159.37 | 🟡 Out Of Bounds | ε: 0.4223
# Episode  173 | Steps: 1000 | Reward:   17.17 | 🔵 Time Limit | ε: 0.4201
# Episode  174 | Steps:  206 | Reward:  -99.46 | 🟡 Out Of Bounds | ε: 0.4180
# Episode  175 | Steps: 1000 | Reward:  -52.17 | 🔵 Time Limit | ε: 0.4159
# Episode  176 | Steps:  167 | Reward:  -71.00 | 🟡 Out Of Bounds | ε: 0.4139
# Episode  177 | Steps: 1000 | Reward:  -42.75 | 🔵 Time Limit | ε: 0.4118
# Episode  178 | Steps:  173 | Reward:  -77.82 | 🟡 Out Of Bounds | ε: 0.4097
# Episode  179 | Steps: 1000 | Reward:  -49.49 | 🔵 Time Limit | ε: 0.4077
# Episode  180 | Steps: 1000 | Reward:  -61.61 | 🔵 Time Limit | ε: 0.4057
#   └─ Avg Reward: -50.661 | Success: 0, Crashed: 7, Out of bounds: 4, Time limit: 9
#
# Episode  181 | Steps: 1000 | Reward:  -42.96 | 🔵 Time Limit | ε: 0.4036
# Episode  182 | Steps:  677 | Reward: -148.87 | 🔴 Crashed | ε: 0.4016
# Episode  183 | Steps:  127 | Reward: -108.85 | 🟡 Out Of Bounds | ε: 0.3996
# Episode  184 | Steps: 1000 | Reward:    8.41 | 🔵 Time Limit | ε: 0.3976
# Episode  185 | Steps:  254 | Reward: -105.77 | 🟡 Out Of Bounds | ε: 0.3956
# Episode  186 | Steps:  104 | Reward:  -98.78 | 🔴 Crashed | ε: 0.3936
# Episode  187 | Steps: 1000 | Reward:  -58.61 | 🔵 Time Limit | ε: 0.3917
# Episode  188 | Steps:  293 | Reward:  -34.91 | 🔴 Crashed | ε: 0.3897
# Episode  189 | Steps: 1000 | Reward:  -74.63 | 🔵 Time Limit | ε: 0.3878
# Episode  190 | Steps: 1000 | Reward:  -59.14 | 🔵 Time Limit | ε: 0.3858
# Episode  191 | Steps:  193 | Reward:  -99.81 | 🔴 Crashed | ε: 0.3839
# Episode  192 | Steps: 1000 | Reward:  -76.43 | 🔵 Time Limit | ε: 0.3820
# Episode  193 | Steps:  606 | Reward: -115.49 | 🔴 Crashed | ε: 0.3801
# Episode  194 | Steps: 1000 | Reward:  -85.72 | 🔵 Time Limit | ε: 0.3782
# Episode  195 | Steps: 1000 | Reward:  -45.11 | 🔵 Time Limit | ε: 0.3763
# Episode  196 | Steps:   61 | Reward:  -34.75 | 🔴 Crashed | ε: 0.3744
# Episode  197 | Steps: 1000 | Reward:  -23.86 | 🔵 Time Limit | ε: 0.3725
# Episode  198 | Steps: 1000 | Reward:  -82.54 | 🔵 Time Limit | ε: 0.3707
# Episode  199 | Steps: 1000 | Reward:  -51.21 | 🔵 Time Limit | ε: 0.3688
# Episode  200 | Steps: 1000 | Reward:  -84.04 | 🔵 Time Limit | ε: 0.3670
#   └─ Avg Reward: -71.154 | Success: 0, Crashed: 6, Out of bounds: 2, Time limit: 12
#
# Episode  201 | Steps:  243 | Reward:  -38.55 | 🔴 Crashed | ε: 0.3651
# Episode  202 | Steps: 1000 | Reward:  -56.73 | 🔵 Time Limit | ε: 0.3633
# Episode  203 | Steps: 1000 | Reward:  -89.30 | 🔵 Time Limit | ε: 0.3615
# Episode  204 | Steps:  187 | Reward:   31.22 | 🔴 Crashed | ε: 0.3597
# Episode  205 | Steps: 1000 | Reward: -106.82 | 🔵 Time Limit | ε: 0.3579
# Episode  206 | Steps: 1000 | Reward:  -21.61 | 🔵 Time Limit | ε: 0.3561
# Episode  207 | Steps: 1000 | Reward: -154.16 | 🔵 Time Limit | ε: 0.3543
# Episode  208 | Steps: 1000 | Reward:  -51.69 | 🔵 Time Limit | ε: 0.3525
# Episode  209 | Steps: 1000 | Reward:  -85.35 | 🔵 Time Limit | ε: 0.3508
# Episode  210 | Steps: 1000 | Reward:  -29.13 | 🔵 Time Limit | ε: 0.3490
# Episode  211 | Steps: 1000 | Reward:   -5.85 | 🔵 Time Limit | ε: 0.3473
# Episode  212 | Steps: 1000 | Reward: -126.14 | 🔵 Time Limit | ε: 0.3455
# Episode  213 | Steps: 1000 | Reward:  -24.73 | 🔵 Time Limit | ε: 0.3438
# Episode  214 | Steps: 1000 | Reward:   46.02 | 🔵 Time Limit | ε: 0.3421
# Episode  215 | Steps: 1000 | Reward:  -29.34 | 🔵 Time Limit | ε: 0.3404
# Episode  216 | Steps:  248 | Reward:    6.22 | 🔴 Crashed | ε: 0.3387
# Episode  217 | Steps: 1000 | Reward:   29.65 | 🔵 Time Limit | ε: 0.3370
# Episode  218 | Steps: 1000 | Reward:   -1.76 | 🔵 Time Limit | ε: 0.3353
# Episode  219 | Steps:  125 | Reward:   35.52 | 🔴 Crashed | ε: 0.3336
# Episode  220 | Steps:  332 | Reward:  -16.67 | 🔴 Crashed | ε: 0.3320
#   └─ Avg Reward: -34.460 | Success: 0, Crashed: 5, Out of bounds: 0, Time limit: 15
#
# Episode  221 | Steps: 1000 | Reward:  -16.99 | 🔵 Time Limit | ε: 0.3303
# Episode  222 | Steps: 1000 | Reward:   27.39 | 🔵 Time Limit | ε: 0.3286
# Episode  223 | Steps: 1000 | Reward:    8.40 | 🔵 Time Limit | ε: 0.3270
# Episode  224 | Steps: 1000 | Reward:  -16.37 | 🔵 Time Limit | ε: 0.3254
# Episode  225 | Steps: 1000 | Reward:   15.43 | 🔵 Time Limit | ε: 0.3237
# Episode  226 | Steps: 1000 | Reward:  -42.84 | 🔵 Time Limit | ε: 0.3221
# Episode  227 | Steps: 1000 | Reward: -127.65 | 🔵 Time Limit | ε: 0.3205
# Episode  228 | Steps: 1000 | Reward:  -18.21 | 🔵 Time Limit | ε: 0.3189
# Episode  229 | Steps: 1000 | Reward:   18.92 | 🔵 Time Limit | ε: 0.3173
# Episode  230 | Steps: 1000 | Reward:  -23.54 | 🔵 Time Limit | ε: 0.3157
# Episode  231 | Steps: 1000 | Reward:  -48.17 | 🔵 Time Limit | ε: 0.3141
# Episode  232 | Steps: 1000 | Reward:  -74.81 | 🔵 Time Limit | ε: 0.3126
# Episode  233 | Steps: 1000 | Reward:  -44.03 | 🔵 Time Limit | ε: 0.3110
# Episode  234 | Steps: 1000 | Reward:  -28.05 | 🔵 Time Limit | ε: 0.3095
# Episode  235 | Steps: 1000 | Reward:  -29.51 | 🔵 Time Limit | ε: 0.3079
# Episode  236 | Steps: 1000 | Reward:   -7.32 | 🔵 Time Limit | ε: 0.3064
# Episode  237 | Steps: 1000 | Reward:  -29.64 | 🔵 Time Limit | ε: 0.3048
# Episode  238 | Steps: 1000 | Reward:   -7.85 | 🔵 Time Limit | ε: 0.3033
# Episode  239 | Steps: 1000 | Reward:  -34.44 | 🔵 Time Limit | ε: 0.3018
# Episode  240 | Steps:  348 | Reward:  -12.73 | 🔴 Crashed | ε: 0.3003
#   └─ Avg Reward: -24.601 | Success: 0, Crashed: 1, Out of bounds: 0, Time limit: 19
#
# Episode  241 | Steps:  417 | Reward:  -32.72 | 🔴 Crashed | ε: 0.2988
# Episode  242 | Steps: 1000 | Reward:  -53.73 | 🔵 Time Limit | ε: 0.2973
# Episode  243 | Steps: 1000 | Reward:   69.70 | 🔵 Time Limit | ε: 0.2958
# Episode  244 | Steps:  823 | Reward: -302.86 | 🔴 Crashed | ε: 0.2943
# Episode  245 | Steps: 1000 | Reward:   67.03 | 🔵 Time Limit | ε: 0.2929
# Episode  246 | Steps:  176 | Reward:   -2.76 | 🔴 Crashed | ε: 0.2914
# Episode  247 | Steps: 1000 | Reward:    5.61 | 🔵 Time Limit | ε: 0.2899
# Episode  248 | Steps: 1000 | Reward:   20.68 | 🔵 Time Limit | ε: 0.2885
# Episode  249 | Steps: 1000 | Reward:    2.88 | 🔵 Time Limit | ε: 0.2870
# Episode  250 | Steps:  259 | Reward: -106.76 | 🟡 Out Of Bounds | ε: 0.2856
# Episode  251 | Steps: 1000 | Reward:  -12.01 | 🔵 Time Limit | ε: 0.2842
# Episode  252 | Steps: 1000 | Reward:   64.67 | 🔵 Time Limit | ε: 0.2828
# Episode  253 | Steps: 1000 | Reward:   48.93 | 🔵 Time Limit | ε: 0.2813
# Episode  254 | Steps: 1000 | Reward:   37.81 | 🔵 Time Limit | ε: 0.2799
# Episode  255 | Steps:  778 | Reward:  161.12 | 🟢 Landed Success | ε: 0.2785
# Episode  256 | Steps: 1000 | Reward:  105.41 | 🔵 Time Limit | ε: 0.2771
# Episode  257 | Steps:  123 | Reward:    1.95 | 🔴 Crashed | ε: 0.2758
# Episode  258 | Steps:  293 | Reward:   -4.74 | 🔴 Crashed | ε: 0.2744
# Episode  259 | Steps: 1000 | Reward:    8.49 | 🔵 Time Limit | ε: 0.2730
# Episode  260 | Steps: 1000 | Reward:   67.80 | 🔵 Time Limit | ε: 0.2716
#   └─ Avg Reward:   7.324 | Success: 1, Crashed: 5, Out of bounds: 1, Time limit: 13
#
# Episode  261 | Steps: 1000 | Reward:   59.10 | 🔵 Time Limit | ε: 0.2703
# Episode  262 | Steps: 1000 | Reward:   23.96 | 🔵 Time Limit | ε: 0.2689
# Episode  263 | Steps:  858 | Reward:  192.71 | 🟢 Landed Success | ε: 0.2676
# Episode  264 | Steps: 1000 | Reward:   63.81 | 🔵 Time Limit | ε: 0.2663
# Episode  265 | Steps:  691 | Reward: -385.89 | 🔴 Crashed | ε: 0.2649
# Episode  266 | Steps: 1000 | Reward:   48.85 | 🔵 Time Limit | ε: 0.2636
# Episode  267 | Steps: 1000 | Reward:  134.93 | 🔵 Time Limit | ε: 0.2623
# Episode  268 | Steps: 1000 | Reward:   96.25 | 🔵 Time Limit | ε: 0.2610
# Episode  269 | Steps: 1000 | Reward:   33.76 | 🔵 Time Limit | ε: 0.2597
# Episode  270 | Steps: 1000 | Reward:   67.88 | 🔵 Time Limit | ε: 0.2584
# Episode  271 | Steps: 1000 | Reward:   77.73 | 🔵 Time Limit | ε: 0.2571
# Episode  272 | Steps:  105 | Reward:   39.35 | 🔴 Crashed | ε: 0.2558
# Episode  273 | Steps: 1000 | Reward:   92.00 | 🔵 Time Limit | ε: 0.2545
# Episode  274 | Steps:  117 | Reward:  -41.37 | 🔴 Crashed | ε: 0.2532
# Episode  275 | Steps: 1000 | Reward:   66.05 | 🔵 Time Limit | ε: 0.2520
# Episode  276 | Steps:  910 | Reward:  199.07 | 🟢 Landed Success | ε: 0.2507
# Episode  277 | Steps: 1000 | Reward:   88.00 | 🔵 Time Limit | ε: 0.2495
# Episode  278 | Steps:  142 | Reward:  -53.01 | 🔴 Crashed | ε: 0.2482
# Episode  279 | Steps: 1000 | Reward:  112.17 | 🔵 Time Limit | ε: 0.2470
# Episode  280 | Steps:  973 | Reward:  219.40 | 🟢 Landed Success | ε: 0.2457
#   └─ Avg Reward:  56.737 | Success: 3, Crashed: 4, Out of bounds: 0, Time limit: 13
#
# Episode  281 | Steps:  167 | Reward:   14.85 | 🔴 Crashed | ε: 0.2445
# Episode  282 | Steps:  682 | Reward:  202.05 | 🟢 Landed Success | ε: 0.2433
# Episode  283 | Steps:  816 | Reward:  223.38 | 🟢 Landed Success | ε: 0.2421
# Episode  284 | Steps: 1000 | Reward:   84.94 | 🔵 Time Limit | ε: 0.2409
# Episode  285 | Steps: 1000 | Reward:  -11.14 | 🔵 Time Limit | ε: 0.2397
# Episode  286 | Steps:  146 | Reward:  -39.36 | 🔴 Crashed | ε: 0.2385
# Episode  287 | Steps: 1000 | Reward:   81.73 | 🔵 Time Limit | ε: 0.2373
# Episode  288 | Steps:  426 | Reward:  200.24 | 🟢 Landed Success | ε: 0.2361
# Episode  289 | Steps: 1000 | Reward:  152.50 | 🔵 Time Limit | ε: 0.2349
# Episode  290 | Steps:  236 | Reward:  -19.13 | 🔴 Crashed | ε: 0.2337
# Episode  291 | Steps:  520 | Reward:  243.53 | 🟢 Landed Success | ε: 0.2326
# Episode  292 | Steps: 1000 | Reward:  193.41 | 🔵 Time Limit | ε: 0.2314
# Episode  293 | Steps:   95 | Reward: -118.09 | 🔴 Crashed | ε: 0.2302
# Episode  294 | Steps: 1000 | Reward:  -20.75 | 🔵 Time Limit | ε: 0.2291
# Episode  295 | Steps:  205 | Reward: -108.94 | 🟡 Out Of Bounds | ε: 0.2279
# Episode  296 | Steps:  129 | Reward:   33.09 | 🔴 Crashed | ε: 0.2268
# Episode  297 | Steps: 1000 | Reward:   98.11 | 🔵 Time Limit | ε: 0.2257
# Episode  298 | Steps:   93 | Reward:  -10.07 | 🔴 Crashed | ε: 0.2245
# Episode  299 | Steps: 1000 | Reward:   74.62 | 🔵 Time Limit | ε: 0.2234
# Episode  300 | Steps:  444 | Reward:  287.50 | 🟢 Landed Success | ε: 0.2223
#   └─ Avg Reward:  78.124 | Success: 5, Crashed: 6, Out of bounds: 1, Time limit: 8
#
# Episode  301 | Steps: 1000 | Reward:  135.41 | 🔵 Time Limit | ε: 0.2212
# Episode  302 | Steps: 1000 | Reward:  133.53 | 🔵 Time Limit | ε: 0.2201
# Episode  303 | Steps: 1000 | Reward:   51.48 | 🔵 Time Limit | ε: 0.2190
# Episode  304 | Steps:  694 | Reward:  255.62 | 🟢 Landed Success | ε: 0.2179
# Episode  305 | Steps: 1000 | Reward:  140.00 | 🔵 Time Limit | ε: 0.2168
# Episode  306 | Steps: 1000 | Reward:  115.09 | 🔵 Time Limit | ε: 0.2157
# Episode  307 | Steps:  828 | Reward:  153.32 | 🟢 Landed Success | ε: 0.2146
# Episode  308 | Steps:  876 | Reward:  204.40 | 🟢 Landed Success | ε: 0.2136
# Episode  309 | Steps:  725 | Reward:  200.37 | 🟢 Landed Success | ε: 0.2125
# Episode  310 | Steps: 1000 | Reward:  121.33 | 🔵 Time Limit | ε: 0.2114
# Episode  311 | Steps:  500 | Reward:  224.45 | 🟢 Landed Success | ε: 0.2104
# Episode  312 | Steps: 1000 | Reward:  127.33 | 🔵 Time Limit | ε: 0.2093
# Episode  313 | Steps: 1000 | Reward:   84.64 | 🔵 Time Limit | ε: 0.2083
# Episode  314 | Steps: 1000 | Reward:   95.43 | 🔵 Time Limit | ε: 0.2072
# Episode  315 | Steps:  413 | Reward:  223.79 | 🟢 Landed Success | ε: 0.2062
# Episode  316 | Steps:  152 | Reward:  -21.60 | 🔴 Crashed | ε: 0.2052
# Episode  317 | Steps: 1000 | Reward:   72.25 | 🔵 Time Limit | ε: 0.2041
# Episode  318 | Steps:  371 | Reward:   28.37 | 🔴 Crashed | ε: 0.2031
# Episode  319 | Steps: 1000 | Reward:   84.46 | 🔵 Time Limit | ε: 0.2021
# Episode  320 | Steps: 1000 | Reward:  119.11 | 🔵 Time Limit | ε: 0.2011
#   └─ Avg Reward: 127.440 | Success: 6, Crashed: 2, Out of bounds: 0, Time limit: 12
#
# Episode  321 | Steps: 1000 | Reward:   -7.61 | 🔵 Time Limit | ε: 0.2001
# Episode  322 | Steps: 1000 | Reward:  174.77 | 🔵 Time Limit | ε: 0.1991
# Episode  323 | Steps: 1000 | Reward:  139.76 | 🔵 Time Limit | ε: 0.1981
# Episode  324 | Steps: 1000 | Reward:  107.09 | 🔵 Time Limit | ε: 0.1971
# Episode  325 | Steps: 1000 | Reward:   71.68 | 🔵 Time Limit | ε: 0.1961
# Episode  326 | Steps: 1000 | Reward:   91.01 | 🔵 Time Limit | ε: 0.1951
# Episode  327 | Steps: 1000 | Reward:   93.79 | 🔵 Time Limit | ε: 0.1942
# Episode  328 | Steps:  652 | Reward:  128.80 | 🟢 Landed Success | ε: 0.1932
# Episode  329 | Steps:  602 | Reward:  230.55 | 🟢 Landed Success | ε: 0.1922
# Episode  330 | Steps:  509 | Reward:  228.44 | 🟢 Landed Success | ε: 0.1913
# Episode  331 | Steps: 1000 | Reward:   51.07 | 🔵 Time Limit | ε: 0.1903
# Episode  332 | Steps:  118 | Reward:   10.43 | 🔴 Crashed | ε: 0.1893
# Episode  333 | Steps:  107 | Reward:  -14.66 | 🔴 Crashed | ε: 0.1884
# Episode  334 | Steps:  727 | Reward:  152.11 | 🟢 Landed Success | ε: 0.1875
# Episode  335 | Steps:  589 | Reward:  312.55 | 🟢 Landed Success | ε: 0.1865
# Episode  336 | Steps:  366 | Reward:  244.02 | 🟢 Landed Success | ε: 0.1856
# Episode  337 | Steps: 1000 | Reward:   85.80 | 🔵 Time Limit | ε: 0.1847
# Episode  338 | Steps:  559 | Reward:  179.78 | 🟢 Landed Success | ε: 0.1837
# Episode  339 | Steps: 1000 | Reward:  113.57 | 🔵 Time Limit | ε: 0.1828
# Episode  340 | Steps: 1000 | Reward:  119.33 | 🔵 Time Limit | ε: 0.1819
#   └─ Avg Reward: 125.614 | Success: 7, Crashed: 2, Out of bounds: 0, Time limit: 11
#
# Episode  341 | Steps:  729 | Reward:  216.87 | 🟢 Landed Success | ε: 0.1810
# Episode  342 | Steps:  923 | Reward:  212.70 | 🟢 Landed Success | ε: 0.1801
# Episode  343 | Steps: 1000 | Reward:   70.71 | 🔵 Time Limit | ε: 0.1792
# Episode  344 | Steps:  763 | Reward:  188.45 | 🟢 Landed Success | ε: 0.1783
# Episode  345 | Steps: 1000 | Reward:   29.12 | 🔵 Time Limit | ε: 0.1774
# Episode  346 | Steps: 1000 | Reward:   32.90 | 🔵 Time Limit | ε: 0.1765
# Episode  347 | Steps: 1000 | Reward:   77.69 | 🔵 Time Limit | ε: 0.1756
# Episode  348 | Steps: 1000 | Reward:   87.22 | 🔵 Time Limit | ε: 0.1748
# Episode  349 | Steps: 1000 | Reward:   85.16 | 🔵 Time Limit | ε: 0.1739
# Episode  350 | Steps:  425 | Reward:  223.85 | 🟢 Landed Success | ε: 0.1730
# Episode  351 | Steps: 1000 | Reward:   74.39 | 🔵 Time Limit | ε: 0.1721
# Episode  352 | Steps:  737 | Reward:  282.73 | 🟢 Landed Success | ε: 0.1713
# Episode  353 | Steps:  388 | Reward:  290.83 | 🟢 Landed Success | ε: 0.1704
# Episode  354 | Steps:  696 | Reward:  237.19 | 🟢 Landed Success | ε: 0.1696
# Episode  355 | Steps:  451 | Reward:  204.63 | 🟢 Landed Success | ε: 0.1687
# Episode  356 | Steps:  845 | Reward:  152.53 | 🟢 Landed Success | ε: 0.1679
# Episode  357 | Steps:  330 | Reward:  298.41 | 🟢 Landed Success | ε: 0.1670
# Episode  358 | Steps:  599 | Reward:  280.57 | 🟢 Landed Success | ε: 0.1662
# Episode  359 | Steps:  340 | Reward:  232.66 | 🟢 Landed Success | ε: 0.1654
# Episode  360 | Steps:  265 | Reward: -164.05 | 🟡 Out Of Bounds | ε: 0.1646
#   └─ Avg Reward: 155.729 | Success: 12, Crashed: 0, Out of bounds: 1, Time limit: 7
#
# Episode  361 | Steps: 1000 | Reward:  107.09 | 🔵 Time Limit | ε: 0.1637
# Episode  362 | Steps:  344 | Reward:  273.91 | 🟢 Landed Success | ε: 0.1629
# Episode  363 | Steps: 1000 | Reward:   68.16 | 🔵 Time Limit | ε: 0.1621
# Episode  364 | Steps:  415 | Reward:  221.79 | 🟢 Landed Success | ε: 0.1613
# Episode  365 | Steps:  568 | Reward:  217.60 | 🟢 Landed Success | ε: 0.1605
# Episode  366 | Steps:  406 | Reward:  211.66 | 🟢 Landed Success | ε: 0.1597
# Episode  367 | Steps:  811 | Reward:  195.77 | 🟢 Landed Success | ε: 0.1589
# Episode  368 | Steps:  336 | Reward:  225.63 | 🟢 Landed Success | ε: 0.1581
# Episode  369 | Steps:  511 | Reward:  271.37 | 🟢 Landed Success | ε: 0.1573
# Episode  370 | Steps:  533 | Reward:  235.83 | 🟢 Landed Success | ε: 0.1565
# Episode  371 | Steps:  898 | Reward:  247.16 | 🟢 Landed Success | ε: 0.1557
# Episode  372 | Steps: 1000 | Reward:   63.28 | 🔵 Time Limit | ε: 0.1549
# Episode  373 | Steps: 1000 | Reward:   78.93 | 🔵 Time Limit | ε: 0.1542
# Episode  374 | Steps: 1000 | Reward:   81.15 | 🔵 Time Limit | ε: 0.1534
# Episode  375 | Steps: 1000 | Reward:   22.91 | 🔵 Time Limit | ε: 0.1526
# Episode  376 | Steps:  677 | Reward:  278.20 | 🟢 Landed Success | ε: 0.1519
# Episode  377 | Steps: 1000 | Reward:  -23.00 | 🔵 Time Limit | ε: 0.1511
# Episode  378 | Steps: 1000 | Reward:   94.14 | 🔵 Time Limit | ε: 0.1504
# Episode  379 | Steps:  514 | Reward:  280.38 | 🟢 Landed Success | ε: 0.1496
# Episode  380 | Steps:  388 | Reward:  239.81 | 🟢 Landed Success | ε: 0.1489
#   └─ Avg Reward: 169.589 | Success: 12, Crashed: 0, Out of bounds: 0, Time limit: 8
#
# Episode  381 | Steps: 1000 | Reward:  132.94 | 🔵 Time Limit | ε: 0.1481
# Episode  382 | Steps:  772 | Reward:  199.87 | 🟢 Landed Success | ε: 0.1474
# Episode  383 | Steps:  435 | Reward:  260.76 | 🟢 Landed Success | ε: 0.1466
# Episode  384 | Steps: 1000 | Reward:   18.89 | 🔵 Time Limit | ε: 0.1459
# Episode  385 | Steps:  357 | Reward:  257.31 | 🟢 Landed Success | ε: 0.1452
# Episode  386 | Steps:  609 | Reward:  135.96 | 🟢 Landed Success | ε: 0.1444
# Episode  387 | Steps:  706 | Reward:  242.51 | 🟢 Landed Success | ε: 0.1437
# Episode  388 | Steps:  429 | Reward:  214.82 | 🟢 Landed Success | ε: 0.1430
# Episode  389 | Steps:  495 | Reward:  223.49 | 🟢 Landed Success | ε: 0.1423
# Episode  390 | Steps:  920 | Reward:  215.50 | 🟢 Landed Success | ε: 0.1416
# Episode  391 | Steps:  231 | Reward:   31.86 | 🔴 Crashed | ε: 0.1409
# Episode  392 | Steps:  504 | Reward:  219.78 | 🟢 Landed Success | ε: 0.1402
# Episode  393 | Steps:  568 | Reward:  186.05 | 🟢 Landed Success | ε: 0.1395
# Episode  394 | Steps:  873 | Reward:  207.29 | 🟢 Landed Success | ε: 0.1388
# Episode  395 | Steps:  443 | Reward:  249.52 | 🟢 Landed Success | ε: 0.1381
# Episode  396 | Steps:  651 | Reward:  260.22 | 🟢 Landed Success | ε: 0.1374
# Episode  397 | Steps:  580 | Reward:  273.79 | 🟢 Landed Success | ε: 0.1367
# Episode  398 | Steps:  791 | Reward:  288.39 | 🟢 Landed Success | ε: 0.1360
# Episode  399 | Steps:  471 | Reward:  223.86 | 🟢 Landed Success | ε: 0.1353
# Episode  400 | Steps:  491 | Reward:  240.87 | 🟢 Landed Success | ε: 0.1347
#   └─ Avg Reward: 204.185 | Success: 17, Crashed: 1, Out of bounds: 0, Time limit: 2
#
# Episode  401 | Steps:  587 | Reward:  119.46 | 🟢 Landed Success | ε: 0.1340
# Episode  402 | Steps:  695 | Reward:  264.64 | 🟢 Landed Success | ε: 0.1333
# Episode  403 | Steps:  327 | Reward:  262.92 | 🟢 Landed Success | ε: 0.1326
# Episode  404 | Steps:  327 | Reward:  287.92 | 🟢 Landed Success | ε: 0.1320
# Episode  405 | Steps:  380 | Reward:  260.31 | 🟢 Landed Success | ε: 0.1313
# Episode  406 | Steps:  339 | Reward: -289.00 | 🔴 Crashed | ε: 0.1307
# Episode  407 | Steps:  421 | Reward: -468.97 | 🟡 Out Of Bounds | ε: 0.1300
# Episode  408 | Steps: 1000 | Reward:   66.28 | 🔵 Time Limit | ε: 0.1294
# Episode  409 | Steps:  533 | Reward:  201.31 | 🟢 Landed Success | ε: 0.1287
# Episode  410 | Steps:  515 | Reward:  238.07 | 🟢 Landed Success | ε: 0.1281
# Episode  411 | Steps:  331 | Reward:  247.67 | 🟢 Landed Success | ε: 0.1274
# Episode  412 | Steps:  427 | Reward:  188.24 | 🟢 Landed Success | ε: 0.1268
# Episode  413 | Steps:  762 | Reward:  207.03 | 🟢 Landed Success | ε: 0.1262
# Episode  414 | Steps:  788 | Reward:  222.21 | 🟢 Landed Success | ε: 0.1255
# Episode  415 | Steps:  960 | Reward:   97.87 | 🟢 Landed Success | ε: 0.1249
# Episode  416 | Steps:  764 | Reward:  191.35 | 🟢 Landed Success | ε: 0.1243
# Episode  417 | Steps:  585 | Reward:  226.09 | 🟢 Landed Success | ε: 0.1237
# Episode  418 | Steps:  554 | Reward:  232.04 | 🟢 Landed Success | ε: 0.1230
# Episode  419 | Steps:  633 | Reward:  186.41 | 🟢 Landed Success | ε: 0.1224
# Episode  420 | Steps:  581 | Reward:  256.40 | 🟢 Landed Success | ε: 0.1218
#   └─ Avg Reward: 149.912 | Success: 17, Crashed: 1, Out of bounds: 1, Time limit: 1
#
# Episode  421 | Steps:  362 | Reward:  244.38 | 🟢 Landed Success | ε: 0.1212
# Episode  422 | Steps:  388 | Reward:  278.21 | 🟢 Landed Success | ε: 0.1206
# Episode  423 | Steps:  320 | Reward:  234.23 | 🟢 Landed Success | ε: 0.1200
# Episode  424 | Steps:  386 | Reward:  281.23 | 🟢 Landed Success | ε: 0.1194
# Episode  425 | Steps:  480 | Reward:  281.06 | 🟢 Landed Success | ε: 0.1188
# Episode  426 | Steps:  448 | Reward:  251.88 | 🟢 Landed Success | ε: 0.1182
# Episode  427 | Steps:  501 | Reward:  278.62 | 🟢 Landed Success | ε: 0.1176
# Episode  428 | Steps:  632 | Reward:  236.02 | 🟢 Landed Success | ε: 0.1170
# Episode  429 | Steps:  499 | Reward:  246.09 | 🟢 Landed Success | ε: 0.1164
# Episode  430 | Steps:  320 | Reward:  254.57 | 🟢 Landed Success | ε: 0.1159
# Episode  431 | Steps:  360 | Reward:  236.14 | 🟢 Landed Success | ε: 0.1153
# Episode  432 | Steps:  286 | Reward:  276.87 | 🟢 Landed Success | ε: 0.1147
# Episode  433 | Steps:  392 | Reward:  252.79 | 🟢 Landed Success | ε: 0.1141
# Episode  434 | Steps:  595 | Reward:  258.93 | 🟢 Landed Success | ε: 0.1136
# Episode  435 | Steps: 1000 | Reward:  106.13 | 🔵 Time Limit | ε: 0.1130
# Episode  436 | Steps:  415 | Reward:  185.35 | 🟢 Landed Success | ε: 0.1124
# Episode  437 | Steps:  414 | Reward:  278.35 | 🟢 Landed Success | ε: 0.1119
# Episode  438 | Steps:  427 | Reward:  260.97 | 🟢 Landed Success | ε: 0.1113
# Episode  439 | Steps:  616 | Reward:  212.81 | 🟢 Landed Success | ε: 0.1107
# Episode  440 | Steps:  713 | Reward:  253.65 | 🟢 Landed Success | ε: 0.1102
#   └─ Avg Reward: 245.415 | Success: 19, Crashed: 0, Out of bounds: 0, Time limit: 1
#
# Episode  441 | Steps:  503 | Reward:  246.25 | 🟢 Landed Success | ε: 0.1096
# Episode  442 | Steps:  357 | Reward:  221.76 | 🟢 Landed Success | ε: 0.1091
# Episode  443 | Steps:  385 | Reward:  262.49 | 🟢 Landed Success | ε: 0.1085
# Episode  444 | Steps:  885 | Reward:  266.32 | 🟢 Landed Success | ε: 0.1080
# Episode  445 | Steps:  368 | Reward:  257.40 | 🟢 Landed Success | ε: 0.1075
# Episode  446 | Steps:  540 | Reward:  224.48 | 🟢 Landed Success | ε: 0.1069
# Episode  447 | Steps:  376 | Reward:  259.95 | 🟢 Landed Success | ε: 0.1064
# Episode  448 | Steps:  289 | Reward:  235.73 | 🟢 Landed Success | ε: 0.1059
# Episode  449 | Steps:  274 | Reward:  250.78 | 🟢 Landed Success | ε: 0.1053
# Episode  450 | Steps:  285 | Reward:  252.02 | 🟢 Landed Success | ε: 0.1048
# Episode  451 | Steps:  573 | Reward:  244.83 | 🟢 Landed Success | ε: 0.1043
# Episode  452 | Steps:  809 | Reward:  284.66 | 🟢 Landed Success | ε: 0.1038
# Episode  453 | Steps:  494 | Reward:  269.29 | 🟢 Landed Success | ε: 0.1032
# Episode  454 | Steps:  374 | Reward:  214.95 | 🟢 Landed Success | ε: 0.1027
# Episode  455 | Steps:  328 | Reward:  245.64 | 🟢 Landed Success | ε: 0.1022
# Episode  456 | Steps:  294 | Reward:  302.43 | 🟢 Landed Success | ε: 0.1017
# Episode  457 | Steps:  314 | Reward:  266.82 | 🟢 Landed Success | ε: 0.1012
# Episode  458 | Steps:  308 | Reward:  274.15 | 🟢 Landed Success | ε: 0.1007
# Episode  459 | Steps:  328 | Reward:  273.40 | 🟢 Landed Success | ε: 0.1002
# Episode  460 | Steps:  365 | Reward:  272.80 | 🟢 Landed Success | ε: 0.0997
#   └─ Avg Reward: 256.307 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  461 | Steps:  466 | Reward:  223.27 | 🟢 Landed Success | ε: 0.0992
# Episode  462 | Steps:  600 | Reward:  229.12 | 🟢 Landed Success | ε: 0.0987
# Episode  463 | Steps:  541 | Reward:  289.04 | 🟢 Landed Success | ε: 0.0982
# Episode  464 | Steps:  378 | Reward:  286.50 | 🟢 Landed Success | ε: 0.0977
# Episode  465 | Steps:  352 | Reward:  262.31 | 🟢 Landed Success | ε: 0.0972
# Episode  466 | Steps:  463 | Reward:  223.65 | 🟢 Landed Success | ε: 0.0967
# Episode  467 | Steps:  318 | Reward:  261.33 | 🟢 Landed Success | ε: 0.0962
# Episode  468 | Steps:  486 | Reward:  275.54 | 🟢 Landed Success | ε: 0.0958
# Episode  469 | Steps:  336 | Reward:  265.65 | 🟢 Landed Success | ε: 0.0953
# Episode  470 | Steps:  391 | Reward:  256.19 | 🟢 Landed Success | ε: 0.0948
# Episode  471 | Steps:  398 | Reward:  238.04 | 🟢 Landed Success | ε: 0.0943
# Episode  472 | Steps:  166 | Reward:   79.99 | 🔴 Crashed | ε: 0.0939
# Episode  473 | Steps:  331 | Reward:  277.59 | 🟢 Landed Success | ε: 0.0934
# Episode  474 | Steps:  319 | Reward:  269.59 | 🟢 Landed Success | ε: 0.0929
# Episode  475 | Steps:  302 | Reward:  236.99 | 🟢 Landed Success | ε: 0.0925
# Episode  476 | Steps:  436 | Reward:  251.99 | 🟢 Landed Success | ε: 0.0920
# Episode  477 | Steps:  363 | Reward:  266.57 | 🟢 Landed Success | ε: 0.0915
# Episode  478 | Steps:  565 | Reward:  231.55 | 🟢 Landed Success | ε: 0.0911
# Episode  479 | Steps:  447 | Reward:  210.12 | 🟢 Landed Success | ε: 0.0906
# Episode  480 | Steps:  260 | Reward:  251.59 | 🟢 Landed Success | ε: 0.0902
#   └─ Avg Reward: 244.330 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  481 | Steps:  443 | Reward:  273.60 | 🟢 Landed Success | ε: 0.0897
# Episode  482 | Steps:  507 | Reward:  264.91 | 🟢 Landed Success | ε: 0.0893
# Episode  483 | Steps:  381 | Reward:  264.61 | 🟢 Landed Success | ε: 0.0888
# Episode  484 | Steps:  366 | Reward:  279.04 | 🟢 Landed Success | ε: 0.0884
# Episode  485 | Steps:  348 | Reward:  271.96 | 🟢 Landed Success | ε: 0.0879
# Episode  486 | Steps:  333 | Reward:  227.30 | 🟢 Landed Success | ε: 0.0875
# Episode  487 | Steps:  346 | Reward:  275.39 | 🟢 Landed Success | ε: 0.0871
# Episode  488 | Steps:  480 | Reward:  240.65 | 🟢 Landed Success | ε: 0.0866
# Episode  489 | Steps:  270 | Reward:  287.41 | 🟢 Landed Success | ε: 0.0862
# Episode  490 | Steps:  347 | Reward:  245.12 | 🟢 Landed Success | ε: 0.0858
# Episode  491 | Steps:  556 | Reward:  254.36 | 🟢 Landed Success | ε: 0.0853
# Episode  492 | Steps:  558 | Reward:  253.32 | 🟢 Landed Success | ε: 0.0849
# Episode  493 | Steps:  415 | Reward:  278.59 | 🟢 Landed Success | ε: 0.0845
# Episode  494 | Steps:  291 | Reward:  231.52 | 🟢 Landed Success | ε: 0.0841
# Episode  495 | Steps:  431 | Reward:  246.86 | 🟢 Landed Success | ε: 0.0836
# Episode  496 | Steps:  353 | Reward:  263.79 | 🟢 Landed Success | ε: 0.0832
# Episode  497 | Steps:  266 | Reward:  292.52 | 🟢 Landed Success | ε: 0.0828
# Episode  498 | Steps:  317 | Reward:  263.57 | 🟢 Landed Success | ε: 0.0824
# Episode  499 | Steps:  355 | Reward:  258.27 | 🟢 Landed Success | ε: 0.0820
# Episode  500 | Steps:  298 | Reward:  238.66 | 🟢 Landed Success | ε: 0.0816
#   └─ Avg Reward: 260.572 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  501 | Steps:  295 | Reward:  246.52 | 🟢 Landed Success | ε: 0.0812
# Episode  502 | Steps:  321 | Reward:  237.07 | 🟢 Landed Success | ε: 0.0808
# Episode  503 | Steps:  322 | Reward:  243.22 | 🟢 Landed Success | ε: 0.0804
# Episode  504 | Steps:  297 | Reward:  209.47 | 🟢 Landed Success | ε: 0.0800
# Episode  505 | Steps:  257 | Reward:  263.94 | 🟢 Landed Success | ε: 0.0796
# Episode  506 | Steps:  416 | Reward:  262.40 | 🟢 Landed Success | ε: 0.0792
# Episode  507 | Steps:  317 | Reward:  259.13 | 🟢 Landed Success | ε: 0.0788
# Episode  508 | Steps:  352 | Reward:  274.36 | 🟢 Landed Success | ε: 0.0784
# Episode  509 | Steps:  314 | Reward:  253.81 | 🟢 Landed Success | ε: 0.0780
# Episode  510 | Steps:  284 | Reward:  215.89 | 🟢 Landed Success | ε: 0.0776
# Episode  511 | Steps:  564 | Reward:  247.76 | 🟢 Landed Success | ε: 0.0772
# Episode  512 | Steps:  328 | Reward:  287.85 | 🟢 Landed Success | ε: 0.0768
# Episode  513 | Steps:  324 | Reward:  236.24 | 🟢 Landed Success | ε: 0.0764
# Episode  514 | Steps:  370 | Reward:  255.05 | 🟢 Landed Success | ε: 0.0760
# Episode  515 | Steps:  364 | Reward:  256.91 | 🟢 Landed Success | ε: 0.0757
# Episode  516 | Steps:  264 | Reward:  269.19 | 🟢 Landed Success | ε: 0.0753
# Episode  517 | Steps:  321 | Reward:  249.90 | 🟢 Landed Success | ε: 0.0749
# Episode  518 | Steps:  393 | Reward:  274.65 | 🟢 Landed Success | ε: 0.0745
# Episode  519 | Steps:  309 | Reward:  235.47 | 🟢 Landed Success | ε: 0.0742
# Episode  520 | Steps:  600 | Reward:  210.42 | 🟢 Landed Success | ε: 0.0738
#   └─ Avg Reward: 249.462 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  521 | Steps:  336 | Reward:  270.43 | 🟢 Landed Success | ε: 0.0734
# Episode  522 | Steps:  390 | Reward:  251.05 | 🟢 Landed Success | ε: 0.0731
# Episode  523 | Steps:  230 | Reward:  236.67 | 🟢 Landed Success | ε: 0.0727
# Episode  524 | Steps:  368 | Reward:  280.31 | 🟢 Landed Success | ε: 0.0723
# Episode  525 | Steps:  338 | Reward:  237.45 | 🟢 Landed Success | ε: 0.0720
# Episode  526 | Steps:  401 | Reward:  257.32 | 🟢 Landed Success | ε: 0.0716
# Episode  527 | Steps:  253 | Reward:  283.26 | 🟢 Landed Success | ε: 0.0712
# Episode  528 | Steps:  382 | Reward:  248.97 | 🟢 Landed Success | ε: 0.0709
# Episode  529 | Steps:  274 | Reward:  253.96 | 🟢 Landed Success | ε: 0.0705
# Episode  530 | Steps:  288 | Reward:  250.88 | 🟢 Landed Success | ε: 0.0702
# Episode  531 | Steps:  283 | Reward:  292.43 | 🟢 Landed Success | ε: 0.0698
# Episode  532 | Steps:  258 | Reward:  293.92 | 🟢 Landed Success | ε: 0.0695
# Episode  533 | Steps:  342 | Reward:  283.64 | 🟢 Landed Success | ε: 0.0691
# Episode  534 | Steps:  260 | Reward:  256.39 | 🟢 Landed Success | ε: 0.0688
# Episode  535 | Steps:  269 | Reward:  267.31 | 🟢 Landed Success | ε: 0.0684
# Episode  536 | Steps:  342 | Reward:  253.63 | 🟢 Landed Success | ε: 0.0681
# Episode  537 | Steps:  427 | Reward:  222.60 | 🟢 Landed Success | ε: 0.0678
# Episode  538 | Steps:  235 | Reward:  226.54 | 🟢 Landed Success | ε: 0.0674
# Episode  539 | Steps:  362 | Reward:  271.28 | 🟢 Landed Success | ε: 0.0671
# Episode  540 | Steps:  428 | Reward:  253.33 | 🟢 Landed Success | ε: 0.0668
#   └─ Avg Reward: 259.568 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  541 | Steps:  453 | Reward:  231.07 | 🟢 Landed Success | ε: 0.0664
# Episode  542 | Steps:  379 | Reward:  214.84 | 🟢 Landed Success | ε: 0.0661
# Episode  543 | Steps:  331 | Reward:  303.10 | 🟢 Landed Success | ε: 0.0658
# Episode  544 | Steps:  606 | Reward:  262.69 | 🟢 Landed Success | ε: 0.0654
# Episode  545 | Steps:  305 | Reward:  203.85 | 🟢 Landed Success | ε: 0.0651
# Episode  546 | Steps:  340 | Reward:  269.69 | 🟢 Landed Success | ε: 0.0648
# Episode  547 | Steps:  217 | Reward:  279.42 | 🟢 Landed Success | ε: 0.0645
# Episode  548 | Steps:  346 | Reward:  266.22 | 🟢 Landed Success | ε: 0.0641
# Episode  549 | Steps:  257 | Reward:  296.48 | 🟢 Landed Success | ε: 0.0638
# Episode  550 | Steps:  301 | Reward:  243.78 | 🟢 Landed Success | ε: 0.0635
# Episode  551 | Steps:  319 | Reward:  263.93 | 🟢 Landed Success | ε: 0.0632
# Episode  552 | Steps:  260 | Reward:  259.87 | 🟢 Landed Success | ε: 0.0629
# Episode  553 | Steps:  238 | Reward:  251.02 | 🟢 Landed Success | ε: 0.0625
# Episode  554 | Steps:  359 | Reward:  230.26 | 🟢 Landed Success | ε: 0.0622
# Episode  555 | Steps:  287 | Reward:  243.82 | 🟢 Landed Success | ε: 0.0619
# Episode  556 | Steps:  188 | Reward:  279.27 | 🟢 Landed Success | ε: 0.0616
# Episode  557 | Steps:  269 | Reward:  243.66 | 🟢 Landed Success | ε: 0.0613
# Episode  558 | Steps:  271 | Reward:  260.05 | 🟢 Landed Success | ε: 0.0610
# Episode  559 | Steps:  302 | Reward:  248.12 | 🟢 Landed Success | ε: 0.0607
# Episode  560 | Steps:  323 | Reward:  261.76 | 🟢 Landed Success | ε: 0.0604
#   └─ Avg Reward: 255.645 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  561 | Steps:  306 | Reward:  270.05 | 🟢 Landed Success | ε: 0.0601
# Episode  562 | Steps:  379 | Reward:  276.81 | 🟢 Landed Success | ε: 0.0598
# Episode  563 | Steps:  219 | Reward:  255.70 | 🟢 Landed Success | ε: 0.0595
# Episode  564 | Steps:  244 | Reward:  264.51 | 🟢 Landed Success | ε: 0.0592
# Episode  565 | Steps:  272 | Reward:  225.04 | 🟢 Landed Success | ε: 0.0589
# Episode  566 | Steps:  291 | Reward:  200.72 | 🟢 Landed Success | ε: 0.0586
# Episode  567 | Steps:  422 | Reward:  256.74 | 🟢 Landed Success | ε: 0.0583
# Episode  568 | Steps:  475 | Reward:  234.47 | 🟢 Landed Success | ε: 0.0580
# Episode  569 | Steps:  470 | Reward:  265.49 | 🟢 Landed Success | ε: 0.0577
# Episode  570 | Steps:  306 | Reward:  255.96 | 🟢 Landed Success | ε: 0.0574
# Episode  571 | Steps:  256 | Reward:  243.85 | 🟢 Landed Success | ε: 0.0571
# Episode  572 | Steps:  280 | Reward:  282.13 | 🟢 Landed Success | ε: 0.0569
# Episode  573 | Steps:  180 | Reward:  296.17 | 🟢 Landed Success | ε: 0.0566
# Episode  574 | Steps:  231 | Reward:  308.01 | 🟢 Landed Success | ε: 0.0563
# Episode  575 | Steps:  311 | Reward:  268.74 | 🟢 Landed Success | ε: 0.0560
# Episode  576 | Steps:  379 | Reward:  241.84 | 🟢 Landed Success | ε: 0.0557
# Episode  577 | Steps:  253 | Reward:  251.73 | 🟢 Landed Success | ε: 0.0555
# Episode  578 | Steps:  375 | Reward:  245.87 | 🟢 Landed Success | ε: 0.0552
# Episode  579 | Steps:  236 | Reward:  247.28 | 🟢 Landed Success | ε: 0.0549
# Episode  580 | Steps:  284 | Reward:  292.20 | 🟢 Landed Success | ε: 0.0546
#   └─ Avg Reward: 259.166 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  581 | Steps:  226 | Reward:  248.15 | 🟢 Landed Success | ε: 0.0544
# Episode  582 | Steps:  265 | Reward:  252.99 | 🟢 Landed Success | ε: 0.0541
# Episode  583 | Steps:  236 | Reward:  266.79 | 🟢 Landed Success | ε: 0.0538
# Episode  584 | Steps:  264 | Reward:  225.41 | 🟢 Landed Success | ε: 0.0535
# Episode  585 | Steps:  244 | Reward:  246.17 | 🟢 Landed Success | ε: 0.0533
# Episode  586 | Steps:  206 | Reward:  280.87 | 🟢 Landed Success | ε: 0.0530
# Episode  587 | Steps:  343 | Reward:  249.75 | 🟢 Landed Success | ε: 0.0527
# Episode  588 | Steps:  314 | Reward:  259.64 | 🟢 Landed Success | ε: 0.0525
# Episode  589 | Steps:  505 | Reward:  215.90 | 🟢 Landed Success | ε: 0.0522
# Episode  590 | Steps:   75 | Reward:  -60.39 | 🔴 Crashed | ε: 0.0520
# Episode  591 | Steps:  251 | Reward:  290.41 | 🟢 Landed Success | ε: 0.0517
# Episode  592 | Steps:  283 | Reward:  246.17 | 🟢 Landed Success | ε: 0.0514
# Episode  593 | Steps:  404 | Reward:  229.12 | 🟢 Landed Success | ε: 0.0512
# Episode  594 | Steps:  331 | Reward:  265.56 | 🟢 Landed Success | ε: 0.0509
# Episode  595 | Steps:  296 | Reward:  253.13 | 🟢 Landed Success | ε: 0.0507
# Episode  596 | Steps:  443 | Reward:  256.44 | 🟢 Landed Success | ε: 0.0504
# Episode  597 | Steps:  435 | Reward:  174.83 | 🟢 Landed Success | ε: 0.0502
# Episode  598 | Steps:  405 | Reward:  282.33 | 🟢 Landed Success | ε: 0.0499
# Episode  599 | Steps:  359 | Reward:  281.28 | 🟢 Landed Success | ε: 0.0497
# Episode  600 | Steps:  336 | Reward:  267.99 | 🟢 Landed Success | ε: 0.0494
#   └─ Avg Reward: 236.628 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  601 | Steps:   75 | Reward:    9.54 | 🔴 Crashed | ε: 0.0492
# Episode  602 | Steps:  508 | Reward:  248.93 | 🟢 Landed Success | ε: 0.0489
# Episode  603 | Steps:  270 | Reward:  232.18 | 🟢 Landed Success | ε: 0.0487
# Episode  604 | Steps:  347 | Reward:  237.39 | 🟢 Landed Success | ε: 0.0484
# Episode  605 | Steps:  294 | Reward:  291.67 | 🟢 Landed Success | ε: 0.0482
# Episode  606 | Steps:  187 | Reward:   22.94 | 🔴 Crashed | ε: 0.0479
# Episode  607 | Steps:  420 | Reward:  253.87 | 🟢 Landed Success | ε: 0.0477
# Episode  608 | Steps:  188 | Reward:  280.46 | 🟢 Landed Success | ε: 0.0475
# Episode  609 | Steps:  549 | Reward:  235.02 | 🟢 Landed Success | ε: 0.0472
# Episode  610 | Steps:  289 | Reward:  212.08 | 🟢 Landed Success | ε: 0.0470
# Episode  611 | Steps:  256 | Reward:  254.02 | 🟢 Landed Success | ε: 0.0468
# Episode  612 | Steps:  258 | Reward:  290.11 | 🟢 Landed Success | ε: 0.0465
# Episode  613 | Steps:  273 | Reward:  247.87 | 🟢 Landed Success | ε: 0.0463
# Episode  614 | Steps:  190 | Reward:  263.76 | 🟢 Landed Success | ε: 0.0461
# Episode  615 | Steps: 1000 | Reward:  138.82 | 🔵 Time Limit | ε: 0.0458
# Episode  616 | Steps:  257 | Reward:  286.32 | 🟢 Landed Success | ε: 0.0456
# Episode  617 | Steps:  312 | Reward:  223.30 | 🟢 Landed Success | ε: 0.0454
# Episode  618 | Steps:  543 | Reward:  232.04 | 🟢 Landed Success | ε: 0.0452
# Episode  619 | Steps:  266 | Reward:  237.17 | 🟢 Landed Success | ε: 0.0449
# Episode  620 | Steps:  259 | Reward:  233.03 | 🟢 Landed Success | ε: 0.0447
#   └─ Avg Reward: 221.526 | Success: 17, Crashed: 2, Out of bounds: 0, Time limit: 1
#
# Episode  621 | Steps:  304 | Reward:  237.67 | 🟢 Landed Success | ε: 0.0445
# Episode  622 | Steps:  214 | Reward:  246.15 | 🟢 Landed Success | ε: 0.0443
# Episode  623 | Steps:  226 | Reward:  233.27 | 🟢 Landed Success | ε: 0.0440
# Episode  624 | Steps:  250 | Reward:  206.41 | 🟢 Landed Success | ε: 0.0438
# Episode  625 | Steps:  266 | Reward:  226.61 | 🟢 Landed Success | ε: 0.0436
# Episode  626 | Steps:  225 | Reward:  240.51 | 🟢 Landed Success | ε: 0.0434
# Episode  627 | Steps:  290 | Reward:  219.41 | 🟢 Landed Success | ε: 0.0432
# Episode  628 | Steps:  395 | Reward:  272.53 | 🟢 Landed Success | ε: 0.0429
# Episode  629 | Steps:  221 | Reward:  270.37 | 🟢 Landed Success | ε: 0.0427
# Episode  630 | Steps:  361 | Reward:  221.33 | 🟢 Landed Success | ε: 0.0425
# Episode  631 | Steps:  322 | Reward:  263.73 | 🟢 Landed Success | ε: 0.0423
# Episode  632 | Steps:  200 | Reward:  235.12 | 🟢 Landed Success | ε: 0.0421
# Episode  633 | Steps:  322 | Reward:  238.64 | 🟢 Landed Success | ε: 0.0419
# Episode  634 | Steps:  241 | Reward:  259.27 | 🟢 Landed Success | ε: 0.0417
# Episode  635 | Steps:  319 | Reward:  234.02 | 🟢 Landed Success | ε: 0.0415
# Episode  636 | Steps:  331 | Reward:  235.55 | 🟢 Landed Success | ε: 0.0413
# Episode  637 | Steps:  377 | Reward:  266.57 | 🟢 Landed Success | ε: 0.0410
# Episode  638 | Steps:  201 | Reward:   32.66 | 🔴 Crashed | ε: 0.0408
# Episode  639 | Steps:  276 | Reward:  274.68 | 🟢 Landed Success | ε: 0.0406
# Episode  640 | Steps:  206 | Reward:   -8.27 | 🔴 Crashed | ε: 0.0404
#   └─ Avg Reward: 220.310 | Success: 18, Crashed: 2, Out of bounds: 0, Time limit: 0
#
# Episode  641 | Steps:  306 | Reward:  251.51 | 🟢 Landed Success | ε: 0.0402
# Episode  642 | Steps:  328 | Reward:  241.65 | 🟢 Landed Success | ε: 0.0400
# Episode  643 | Steps:  354 | Reward:  229.31 | 🟢 Landed Success | ε: 0.0398
# Episode  644 | Steps:  426 | Reward:  256.88 | 🟢 Landed Success | ε: 0.0396
# Episode  645 | Steps:  300 | Reward:  245.56 | 🟢 Landed Success | ε: 0.0394
# Episode  646 | Steps:  251 | Reward:  266.75 | 🟢 Landed Success | ε: 0.0392
# Episode  647 | Steps:  420 | Reward:  248.21 | 🟢 Landed Success | ε: 0.0390
# Episode  648 | Steps:  406 | Reward:  260.99 | 🟢 Landed Success | ε: 0.0388
# Episode  649 | Steps:  288 | Reward:  237.40 | 🟢 Landed Success | ε: 0.0387
# Episode  650 | Steps:  285 | Reward:  250.62 | 🟢 Landed Success | ε: 0.0385
# Episode  651 | Steps:  279 | Reward:  259.45 | 🟢 Landed Success | ε: 0.0383
# Episode  652 | Steps:  400 | Reward:  261.81 | 🟢 Landed Success | ε: 0.0381
# Episode  653 | Steps:  315 | Reward:  262.33 | 🟢 Landed Success | ε: 0.0379
# Episode  654 | Steps:  323 | Reward:  254.57 | 🟢 Landed Success | ε: 0.0377
# Episode  655 | Steps:  332 | Reward:  260.50 | 🟢 Landed Success | ε: 0.0375
# Episode  656 | Steps:  346 | Reward:  248.41 | 🟢 Landed Success | ε: 0.0373
# Episode  657 | Steps:  202 | Reward:  285.35 | 🟢 Landed Success | ε: 0.0371
# Episode  658 | Steps:  253 | Reward:  257.47 | 🟢 Landed Success | ε: 0.0369
# Episode  659 | Steps:  252 | Reward:  232.29 | 🟢 Landed Success | ε: 0.0368
# Episode  660 | Steps:  366 | Reward:  231.53 | 🟢 Landed Success | ε: 0.0366
#   └─ Avg Reward: 252.131 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  661 | Steps:  359 | Reward:  261.05 | 🟢 Landed Success | ε: 0.0364
# Episode  662 | Steps:  389 | Reward:  222.12 | 🟢 Landed Success | ε: 0.0362
# Episode  663 | Steps:  325 | Reward:  263.40 | 🟢 Landed Success | ε: 0.0360
# Episode  664 | Steps:  281 | Reward:  237.44 | 🟢 Landed Success | ε: 0.0359
# Episode  665 | Steps:  317 | Reward:  298.62 | 🟢 Landed Success | ε: 0.0357
# Episode  666 | Steps:  244 | Reward:  231.01 | 🟢 Landed Success | ε: 0.0355
# Episode  667 | Steps:  271 | Reward:  251.33 | 🟢 Landed Success | ε: 0.0353
# Episode  668 | Steps:  246 | Reward:  261.15 | 🟢 Landed Success | ε: 0.0351
# Episode  669 | Steps:  261 | Reward:  256.99 | 🟢 Landed Success | ε: 0.0350
# Episode  670 | Steps:  434 | Reward:  276.94 | 🟢 Landed Success | ε: 0.0348
# Episode  671 | Steps:  117 | Reward:  -23.09 | 🔴 Crashed | ε: 0.0346
# Episode  672 | Steps:  300 | Reward:  262.07 | 🟢 Landed Success | ε: 0.0344
# Episode  673 | Steps:  245 | Reward:  268.63 | 🟢 Landed Success | ε: 0.0343
# Episode  674 | Steps:  310 | Reward:  243.60 | 🟢 Landed Success | ε: 0.0341
# Episode  675 | Steps:  220 | Reward:  -29.28 | 🔴 Crashed | ε: 0.0339
# Episode  676 | Steps:  222 | Reward:  245.53 | 🟢 Landed Success | ε: 0.0338
# Episode  677 | Steps:  411 | Reward:  264.23 | 🟢 Landed Success | ε: 0.0336
# Episode  678 | Steps:  234 | Reward:  226.64 | 🟢 Landed Success | ε: 0.0334
# Episode  679 | Steps:  366 | Reward:  276.11 | 🟢 Landed Success | ε: 0.0333
# Episode  680 | Steps:  319 | Reward:  272.85 | 🟢 Landed Success | ε: 0.0331
#   └─ Avg Reward: 228.367 | Success: 18, Crashed: 2, Out of bounds: 0, Time limit: 0
#
# Episode  681 | Steps:  236 | Reward:  253.01 | 🟢 Landed Success | ε: 0.0329
# Episode  682 | Steps:  318 | Reward:  281.64 | 🟢 Landed Success | ε: 0.0328
# Episode  683 | Steps:  104 | Reward:    1.33 | 🔴 Crashed | ε: 0.0326
# Episode  684 | Steps:  174 | Reward:   10.61 | 🔴 Crashed | ε: 0.0324
# Episode  685 | Steps:  357 | Reward:  266.13 | 🟢 Landed Success | ε: 0.0323
# Episode  686 | Steps:   99 | Reward:   -6.94 | 🔴 Crashed | ε: 0.0321
# Episode  687 | Steps:  252 | Reward:  258.74 | 🟢 Landed Success | ε: 0.0319
# Episode  688 | Steps:  319 | Reward:  230.23 | 🟢 Landed Success | ε: 0.0318
# Episode  689 | Steps:  216 | Reward:  245.45 | 🟢 Landed Success | ε: 0.0316
# Episode  690 | Steps:  107 | Reward:  -43.36 | 🔴 Crashed | ε: 0.0315
# Episode  691 | Steps:  156 | Reward:  -22.72 | 🔴 Crashed | ε: 0.0313
# Episode  692 | Steps:  235 | Reward:  241.88 | 🟢 Landed Success | ε: 0.0312
# Episode  693 | Steps:  106 | Reward:  -41.78 | 🔴 Crashed | ε: 0.0310
# Episode  694 | Steps:  291 | Reward:  312.53 | 🟢 Landed Success | ε: 0.0308
# Episode  695 | Steps:  606 | Reward:  190.64 | 🟢 Landed Success | ε: 0.0307
# Episode  696 | Steps:  230 | Reward:  249.48 | 🟢 Landed Success | ε: 0.0305
# Episode  697 | Steps:  544 | Reward:  193.35 | 🟢 Landed Success | ε: 0.0304
# Episode  698 | Steps:  363 | Reward:  267.31 | 🟢 Landed Success | ε: 0.0302
# Episode  699 | Steps:  369 | Reward:  197.86 | 🟢 Landed Success | ε: 0.0301
# Episode  700 | Steps:  387 | Reward:  283.34 | 🟢 Landed Success | ε: 0.0299
#   └─ Avg Reward: 168.437 | Success: 14, Crashed: 6, Out of bounds: 0, Time limit: 0
#
# Episode  701 | Steps:  441 | Reward:  223.56 | 🟢 Landed Success | ε: 0.0298
# Episode  702 | Steps:  374 | Reward:  247.38 | 🟢 Landed Success | ε: 0.0296
# Episode  703 | Steps:  993 | Reward:  146.43 | 🟢 Landed Success | ε: 0.0295
# Episode  704 | Steps:  355 | Reward:  287.33 | 🟢 Landed Success | ε: 0.0293
# Episode  705 | Steps:  619 | Reward:  157.14 | 🟢 Landed Success | ε: 0.0292
# Episode  706 | Steps:  311 | Reward:  246.40 | 🟢 Landed Success | ε: 0.0290
# Episode  707 | Steps:  390 | Reward:  259.82 | 🟢 Landed Success | ε: 0.0289
# Episode  708 | Steps:  478 | Reward:  191.17 | 🟢 Landed Success | ε: 0.0288
# Episode  709 | Steps:  586 | Reward:  203.04 | 🟢 Landed Success | ε: 0.0286
# Episode  710 | Steps:  404 | Reward:  201.11 | 🟢 Landed Success | ε: 0.0285
# Episode  711 | Steps:  307 | Reward:  237.15 | 🟢 Landed Success | ε: 0.0283
# Episode  712 | Steps:  307 | Reward:  241.53 | 🟢 Landed Success | ε: 0.0282
# Episode  713 | Steps:  351 | Reward:  216.44 | 🟢 Landed Success | ε: 0.0280
# Episode  714 | Steps:  345 | Reward:  234.13 | 🟢 Landed Success | ε: 0.0279
# Episode  715 | Steps:  291 | Reward:  248.31 | 🟢 Landed Success | ε: 0.0278
# Episode  716 | Steps:  367 | Reward:  251.78 | 🟢 Landed Success | ε: 0.0276
# Episode  717 | Steps:  255 | Reward:  261.77 | 🟢 Landed Success | ε: 0.0275
# Episode  718 | Steps:  552 | Reward:  240.21 | 🟢 Landed Success | ε: 0.0274
# Episode  719 | Steps:  405 | Reward:  238.42 | 🟢 Landed Success | ε: 0.0272
# Episode  720 | Steps:  284 | Reward:  235.57 | 🟢 Landed Success | ε: 0.0271
#   └─ Avg Reward: 228.434 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  721 | Steps:  264 | Reward:  229.37 | 🟢 Landed Success | ε: 0.0269
# Episode  722 | Steps:  420 | Reward:  253.90 | 🟢 Landed Success | ε: 0.0268
# Episode  723 | Steps:  454 | Reward:  246.24 | 🟢 Landed Success | ε: 0.0267
# Episode  724 | Steps:  351 | Reward:  249.33 | 🟢 Landed Success | ε: 0.0265
# Episode  725 | Steps:  278 | Reward:   44.43 | 🔴 Crashed | ε: 0.0264
# Episode  726 | Steps:  382 | Reward:  275.51 | 🟢 Landed Success | ε: 0.0263
# Episode  727 | Steps:  353 | Reward:  233.83 | 🟢 Landed Success | ε: 0.0261
# Episode  728 | Steps:  342 | Reward:  219.69 | 🟢 Landed Success | ε: 0.0260
# Episode  729 | Steps:  382 | Reward:  235.12 | 🟢 Landed Success | ε: 0.0259
# Episode  730 | Steps:  466 | Reward:  251.17 | 🟢 Landed Success | ε: 0.0258
# Episode  731 | Steps:  444 | Reward:  257.37 | 🟢 Landed Success | ε: 0.0256
# Episode  732 | Steps:  559 | Reward:  206.35 | 🟢 Landed Success | ε: 0.0255
# Episode  733 | Steps:  263 | Reward:  256.59 | 🟢 Landed Success | ε: 0.0254
# Episode  734 | Steps:  397 | Reward:  250.03 | 🟢 Landed Success | ε: 0.0252
# Episode  735 | Steps:  348 | Reward:  199.09 | 🟢 Landed Success | ε: 0.0251
# Episode  736 | Steps:  359 | Reward:  233.61 | 🟢 Landed Success | ε: 0.0250
# Episode  737 | Steps:  395 | Reward:  262.87 | 🟢 Landed Success | ε: 0.0249
# Episode  738 | Steps:  281 | Reward:  260.19 | 🟢 Landed Success | ε: 0.0247
# Episode  739 | Steps:  421 | Reward:  267.16 | 🟢 Landed Success | ε: 0.0246
# Episode  740 | Steps:  380 | Reward:  255.97 | 🟢 Landed Success | ε: 0.0245
#   └─ Avg Reward: 234.391 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  741 | Steps:  430 | Reward:  266.67 | 🟢 Landed Success | ε: 0.0244
# Episode  742 | Steps:  313 | Reward:  234.59 | 🟢 Landed Success | ε: 0.0243
# Episode  743 | Steps:  240 | Reward:  269.44 | 🟢 Landed Success | ε: 0.0241
# Episode  744 | Steps:  398 | Reward:  240.29 | 🟢 Landed Success | ε: 0.0240
# Episode  745 | Steps:  469 | Reward:  226.56 | 🟢 Landed Success | ε: 0.0239
# Episode  746 | Steps:  332 | Reward:  257.58 | 🟢 Landed Success | ε: 0.0238
# Episode  747 | Steps:  290 | Reward:  214.78 | 🟢 Landed Success | ε: 0.0237
# Episode  748 | Steps:  475 | Reward:  253.17 | 🟢 Landed Success | ε: 0.0235
# Episode  749 | Steps:  267 | Reward:  247.95 | 🟢 Landed Success | ε: 0.0234
# Episode  750 | Steps:  264 | Reward:  279.85 | 🟢 Landed Success | ε: 0.0233
# Episode  751 | Steps:  269 | Reward:  230.03 | 🟢 Landed Success | ε: 0.0232
# Episode  752 | Steps:  344 | Reward:  218.78 | 🟢 Landed Success | ε: 0.0231
# Episode  753 | Steps:  420 | Reward:  274.14 | 🟢 Landed Success | ε: 0.0229
# Episode  754 | Steps:  757 | Reward:  230.31 | 🟢 Landed Success | ε: 0.0228
# Episode  755 | Steps:  390 | Reward:  258.78 | 🟢 Landed Success | ε: 0.0227
# Episode  756 | Steps:  237 | Reward:  265.29 | 🟢 Landed Success | ε: 0.0226
# Episode  757 | Steps:  303 | Reward:  231.62 | 🟢 Landed Success | ε: 0.0225
# Episode  758 | Steps:  260 | Reward:  256.88 | 🟢 Landed Success | ε: 0.0224
# Episode  759 | Steps:  383 | Reward:  247.37 | 🟢 Landed Success | ε: 0.0223
# Episode  760 | Steps:  446 | Reward:  227.91 | 🟢 Landed Success | ε: 0.0222
#   └─ Avg Reward: 246.600 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  761 | Steps:  306 | Reward:  232.96 | 🟢 Landed Success | ε: 0.0220
# Episode  762 | Steps:  240 | Reward:  268.34 | 🟢 Landed Success | ε: 0.0219
# Episode  763 | Steps:  427 | Reward:  262.37 | 🟢 Landed Success | ε: 0.0218
# Episode  764 | Steps:  249 | Reward:  248.87 | 🟢 Landed Success | ε: 0.0217
# Episode  765 | Steps:  343 | Reward:  221.31 | 🟢 Landed Success | ε: 0.0216
# Episode  766 | Steps:  545 | Reward:  223.21 | 🟢 Landed Success | ε: 0.0215
# Episode  767 | Steps:  315 | Reward:  259.30 | 🟢 Landed Success | ε: 0.0214
# Episode  768 | Steps:  324 | Reward:  262.60 | 🟢 Landed Success | ε: 0.0213
# Episode  769 | Steps:  241 | Reward:  261.77 | 🟢 Landed Success | ε: 0.0212
# Episode  770 | Steps:  374 | Reward:  254.76 | 🟢 Landed Success | ε: 0.0211
# Episode  771 | Steps:  261 | Reward:  268.81 | 🟢 Landed Success | ε: 0.0210
# Episode  772 | Steps:  407 | Reward:  228.24 | 🟢 Landed Success | ε: 0.0209
# Episode  773 | Steps:  294 | Reward:  266.17 | 🟢 Landed Success | ε: 0.0208
# Episode  774 | Steps:  892 | Reward:  191.20 | 🟢 Landed Success | ε: 0.0207
# Episode  775 | Steps:  385 | Reward:  287.29 | 🟢 Landed Success | ε: 0.0206
# Episode  776 | Steps:  286 | Reward:  231.38 | 🟢 Landed Success | ε: 0.0205
# Episode  777 | Steps:  402 | Reward:  241.95 | 🟢 Landed Success | ε: 0.0203
# Episode  778 | Steps:  363 | Reward:  268.43 | 🟢 Landed Success | ε: 0.0202
# Episode  779 | Steps:  282 | Reward:  271.64 | 🟢 Landed Success | ε: 0.0201
# Episode  780 | Steps:  448 | Reward:  238.32 | 🟢 Landed Success | ε: 0.0200
#   └─ Avg Reward: 249.446 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  781 | Steps:  367 | Reward:  274.58 | 🟢 Landed Success | ε: 0.0199
# Episode  782 | Steps:  272 | Reward:  267.14 | 🟢 Landed Success | ε: 0.0198
# Episode  783 | Steps:  340 | Reward:  252.70 | 🟢 Landed Success | ε: 0.0197
# Episode  784 | Steps:  291 | Reward:  247.65 | 🟢 Landed Success | ε: 0.0196
# Episode  785 | Steps:  245 | Reward:  245.28 | 🟢 Landed Success | ε: 0.0195
# Episode  786 | Steps:  448 | Reward:  274.20 | 🟢 Landed Success | ε: 0.0195
# Episode  787 | Steps:  244 | Reward:  237.00 | 🟢 Landed Success | ε: 0.0194
# Episode  788 | Steps:  342 | Reward:  256.78 | 🟢 Landed Success | ε: 0.0193
# Episode  789 | Steps:  404 | Reward:  240.93 | 🟢 Landed Success | ε: 0.0192
# Episode  790 | Steps:  427 | Reward:  256.85 | 🟢 Landed Success | ε: 0.0191
# Episode  791 | Steps:  388 | Reward:  266.59 | 🟢 Landed Success | ε: 0.0190
# Episode  792 | Steps:  298 | Reward:  236.96 | 🟢 Landed Success | ε: 0.0189
# Episode  793 | Steps:  259 | Reward:  229.63 | 🟢 Landed Success | ε: 0.0188
# Episode  794 | Steps:  289 | Reward:  279.85 | 🟢 Landed Success | ε: 0.0187
# Episode  795 | Steps:  251 | Reward:  260.73 | 🟢 Landed Success | ε: 0.0186
# Episode  796 | Steps:  263 | Reward:  263.86 | 🟢 Landed Success | ε: 0.0185
# Episode  797 | Steps:  275 | Reward:  246.84 | 🟢 Landed Success | ε: 0.0184
# Episode  798 | Steps:  275 | Reward:  256.51 | 🟢 Landed Success | ε: 0.0183
# Episode  799 | Steps:  294 | Reward:  243.36 | 🟢 Landed Success | ε: 0.0182
# Episode  800 | Steps:  273 | Reward:  233.02 | 🟢 Landed Success | ε: 0.0181
#   └─ Avg Reward: 253.523 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# ✅ Logs appended to runs/all_runs_combined.csv
#
# ✅ Training completed for Run 17!
# Total episodes: 800
# Replay buffer size: 50000 transitions
# Total training steps: 350598
# Final epsilon: 0.0181
#
# 📊 Episode Outcomes:
#   🚀 Landed successfully: 443 (55.4%)
#   💥 Crashed: 198 (24.8%)
#   📍 Out of bounds: 23 (2.9%)
#   ⏱️  Time limit: 136 (17.0%)
#
# 📁 Individual log saved to: runs/run_list/run17.csv
# 📁 Combined logs updated: runs/all_runs_combined.csv
# 📁 Configs updated: runs/all_configs_combined.csv

# %% [markdown]
# ## Plot Training Progress

# %%
# Plot episode rewards over time with outcome colors and different markers
fig, ax = plt.subplots(figsize=(14, 6))

# Base line plot
ax.plot(episode_rewards, alpha=0.3, label='Episode Reward', linewidth=1, color='gray')

# Plot moving average
window = 40
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
ax.plot(range(window-1, len(episode_rewards)), moving_avg, linewidth=2.5, 
         label=f'Moving Avg ({window} episodes)', color='black')

# Color and marker mapping for outcomes
outcome_styles = {
    'landed_success': {'color': 'green', 'marker': 'o', 'label': 'Landed Success'},
    'crashed': {'color': 'red', 'marker': 'X', 'label': 'Crashed'},
    'out_of_bounds': {'color': 'yellow', 'marker': '^', 'label': 'Out of Bounds'},
    'time_limit': {'color': 'blue', 'marker': 's', 'label': 'Time Limit'}
}

# Plot scatter points with different markers for each outcome
for outcome, style in outcome_styles.items():
    episodes = [i for i, o in enumerate(episode_outcomes) if o == outcome]
    rewards = [episode_rewards[i] for i in episodes]
    ax.scatter(episodes, rewards, c=style['color'], marker=style['marker'], 
              label=style['label'], s=80, alpha=0.7, edgecolors='black', linewidth=1)

ax.set_xlabel('Episode', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('LunarLander DQN - Training Progress by Outcome', fontsize=14, fontweight='bold')
ax.legend(fontsize=10, loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 Training Statistics:")
print(f"  Average Reward: {np.mean(episode_rewards):.3f}")
print(f"  Max Reward: {np.max(episode_rewards):.3f}")
print(f"  Min Reward: {np.min(episode_rewards):.3f}")
print(f"  Std Dev: {np.std(episode_rewards):.3f}")
# Out:
# 📊 Training Statistics:
#   Average Reward: 111.634
#   Max Reward: 312.549
#   Min Reward: -567.585
#   Std Dev: 169.516

# %% [markdown]
# ## Watch Trained Agent in Action

# %%
from gymnasium.wrappers import RecordVideo
from IPython.display import HTML
import glob
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="rgb_array")
env = RecordVideo(
    env,
    video_folder="videos",
    episode_trigger=lambda episode_id: True,
    name_prefix="trained_agent"
)

obs, info = env.reset()

final_reward = 0.0
terminated = False
truncated = False
episode_steps = 0
final_obs = obs
last_step_reward = 0.0  # ✅ NEW: needed for outcome

agent.set_epsilon(0.0)  # exploit only

while not (terminated or truncated):
    action = agent.act(obs)
    obs, reward, terminated, truncated, info = env.step(action)

    final_reward += reward
    episode_steps += 1
    final_obs = obs
    last_step_reward = reward  # ✅ NEW: keep last step reward

env.close()

# ✅ Categorize episode outcome (correct args)
outcome = categorize_episode_outcome(
    final_obs,
    episode_steps,
    last_step_reward
)
outcome_icon = get_outcome_icon(outcome)

print(f"\n🎬 Trained Agent Performance:")
print(f" Total Reward: {final_reward:.3f}")
print(f" Episode Steps: {episode_steps}")
print(f" Outcome: {outcome_icon} {outcome.replace('_', ' ').title()}")

# pick the newest video (avoids grabbing an older mp4)
video_path = max(glob.glob("videos/*.mp4"), key=lambda p: p)

HTML(f"""
<video width="600" controls autoplay loop>
    <source src="{video_path}" type="video/mp4">
</video>
""")
# Out:
# c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\.venv\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 🎬 Trained Agent Performance:
#  Total Reward: 238.295
#  Episode Steps: 271
#  Outcome: 🟢 Landed Success
# <video width="600" controls autoplay loop>
#     <source src="videos\trained_agent-episode-outofbound.mp4" type="video/mp4">
# </video>
