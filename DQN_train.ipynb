# %% [markdown]
# # LunarLander DQN Training
#
# Interactive training notebook with configurable hyperparameters.

# %%
import gymnasium as gym
from src.envs.make_env import make_env
from src.agents.epsilon_greedy_agent import EpsilonGreedyAgent
from src.networks.q_network import QNetwork
from src.replay.replay_buffer import ReplayBuffer
from src.training.trainer import Trainer
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Hyperparameters Configuration
#
# Modify these values to tune the training process:

# %%
# ============ TRAINING HYPERPARAMETERS ============
# Environment
num_episodes = 800  # Total number of training episodes
log_interval = 20  # Print stats every N episodes

# Training
train_every = 4  # Training step every N environment steps
batch_size = 64
learning_rate = 0.0001
gamma = 0.99  # Discount factor
interpolation_parameter = 1e-3  # Soft update rate for target network
replay_buffer_size = 64

# Exploration
epsilon_starting_value = 1  # Initial exploration rate
epsilon_ending_value = 0.01   # Final exploration rate
epsilon_decay_value = 0.995   # Decay factor per episode

# %% [markdown]
# ## Initialize Components

# %%
# Initialize Q-Network
q_network = QNetwork(input_size=8, output_size=4)

# Initialize epsilon from config
epsilon = epsilon_starting_value

# Initialize agent
agent = EpsilonGreedyAgent(action_space=4, q_network=q_network, epsilon=epsilon)

# Initialize replay buffer
replay_buffer = ReplayBuffer(max_size=replay_buffer_size)

# Initialize trainer with hyperparameters
trainer = Trainer(q_network, learning_rate=learning_rate, replay_buffer=replay_buffer, gamma=gamma)
trainer.interpolation_parameter = interpolation_parameter

# Create environment
env = make_env(render_mode="rgb_array")
# Out:
# c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
import csv
import os
import pandas as pd
from src.training.episode_outcome import categorize_episode_outcome, get_outcome_icon

# ===== AUTO-INCREMENT RUN ID =====
configs_file = 'runs/all_configs_combined.csv'
runs_file = 'runs/all_runs_combined.csv'

# Read existing configs to find last run_id
df_configs = pd.read_csv(configs_file, dtype={'run_id': str})
last_run_id = df_configs['run_id'].astype(int).max()
new_run_id = str(last_run_id + 1).zfill(2)

print(f"📋 Last run_id found: {last_run_id:02d}")
print(f"🆕 New run_id: {new_run_id}")

# ===== APPEND NEW CONFIG TO all_configs_combined.csv =====
new_config = {
    'run_id': new_run_id,
    'num_episodes': num_episodes,
    'log_interval': log_interval,
    'train_every': train_every,
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'gamma': gamma,
    'interpolation_parameter': interpolation_parameter,
    'replay_buffer_size': replay_buffer_size,
    'epsilon_starting_value': epsilon_starting_value,
    'epsilon_ending_value': epsilon_ending_value,
    'epsilon_decay_value': epsilon_decay_value
}

# Append to configs file
new_config_df = pd.DataFrame([new_config])
new_config_df.to_csv(configs_file, mode='a', header=False, index=False)
print(f"✅ Config appended to {configs_file}")

# ===== SETUP LOG FILE =====
run_list_dir = 'runs/run_list'
os.makedirs(run_list_dir, exist_ok=True)
log_file = f'{run_list_dir}/run{new_run_id}.csv'

with open(log_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['episode', 'reward', 'length', 'terminated', 'truncated', 'outcome'])

print(f"📁 Log file created: {log_file}")
# Out:
# 📋 Last run_id found: 07
# 🆕 New run_id: 08
# ✅ Config appended to runs/all_configs_combined.csv
# 📁 Log file created: runs/run_list/run08.csv

# %% [markdown]
# ## Training Loop with Visualization

# %%
# Training loop with episode outcome logging
episode_rewards = []
training_steps = 0
episode_outcomes = []
episode_logs = []  # Store logs for appending to combined file

print(f"🚀 Starting training for Run {new_run_id}...\n")

for episode in range(num_episodes):
    obs, info = env.reset()
    total_reward = 0.0
    terminated = False
    truncated = False
    episode_length = 0
    final_obs = obs
    last_step_reward = 0.0  # keep last reward of the episode

    while not (terminated or truncated):
        # Ask agent for action
        action = agent.act(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)

        # store last step reward (used for outcome classification)
        last_step_reward = reward

        # Store transition in replay buffer
        done = terminated or truncated
        replay_buffer.add(obs, action, reward, next_obs, done)

        # Training step: sample batch and update network
        if training_steps % train_every == 0:
            loss = trainer.train_step(batch_size=batch_size)

        training_steps += 1
        total_reward += reward
        episode_length += 1
        obs = next_obs
        final_obs = next_obs

    episode_rewards.append(total_reward)

    # Categorize episode outcome
    outcome = categorize_episode_outcome(final_obs, episode_length, last_step_reward)
    episode_outcomes.append(outcome)

    # Store log entry
    log_entry = {
        'run_id': new_run_id,
        'episode': episode + 1,
        'reward': round(total_reward, 2),
        'length': episode_length,
        'terminated': int(terminated),
        'truncated': int(truncated),
        'outcome': outcome
    }
    episode_logs.append(log_entry)

    # Log to individual run CSV file
    with open(log_file, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([episode + 1, f"{total_reward:.2f}", episode_length,
                         int(terminated), int(truncated), outcome])

    # Decay epsilon after each episode
    epsilon = max(epsilon_ending_value, epsilon * epsilon_decay_value)
    agent.set_epsilon(epsilon)

    # Print individual episode result
    outcome_icon = get_outcome_icon(outcome)
    print(
        f"Episode {episode + 1:4d} | Steps: {episode_length:4d} | Reward: {total_reward:7.2f} | "
        f"{outcome_icon} {outcome.replace('_', ' ').title()} | ε: {epsilon:.4f}"
    )

    # Log average reward every N episodes
    if (episode + 1) % log_interval == 0:
        avg_reward = sum(episode_rewards[-log_interval:]) / log_interval

        # Count outcomes in recent window
        recent_outcomes = episode_outcomes[-log_interval:]
        outcome_counts = {
            'success': recent_outcomes.count('landed_success'),
            'crashed': recent_outcomes.count('crashed'),
            'out_of_bounds': recent_outcomes.count('out_of_bounds'),
            'time_limit': recent_outcomes.count('time_limit')
        }

        print(
            f"  └─ Avg Reward: {avg_reward:7.3f} | "
            f"Success: {outcome_counts['success']}, "
            f"Crashed: {outcome_counts['crashed']}, "
            f"Out of bounds: {outcome_counts['out_of_bounds']}, "
            f"Time limit: {outcome_counts['time_limit']}"
        )
        print()

env.close()

# ===== APPEND LOGS TO all_runs_combined.csv =====
logs_df = pd.DataFrame(episode_logs)
logs_df.to_csv(runs_file, mode='a', header=False, index=False)
print(f"✅ Logs appended to {runs_file}")

print(f"\n✅ Training completed for Run {new_run_id}!")
print(f"Total episodes: {num_episodes}")
print(f"Replay buffer size: {len(replay_buffer)} transitions")
print(f"Total training steps: {training_steps}")
print(f"Final epsilon: {epsilon:.4f}")

# Final statistics
success_count = episode_outcomes.count('landed_success')
crashed_count = episode_outcomes.count('crashed')
out_of_bounds_count = episode_outcomes.count('out_of_bounds')
time_limit_count = episode_outcomes.count('time_limit')

print(f"\n📊 Episode Outcomes:")
print(f"  🚀 Landed successfully: {success_count} ({100*success_count/num_episodes:.1f}%)")
print(f"  💥 Crashed: {crashed_count} ({100*crashed_count/num_episodes:.1f}%)")
print(f"  📍 Out of bounds: {out_of_bounds_count} ({100*out_of_bounds_count/num_episodes:.1f}%)")
print(f"  ⏱️  Time limit: {time_limit_count} ({100*time_limit_count/num_episodes:.1f}%)")
print(f"\n📁 Individual log saved to: {log_file}")
print(f"📁 Combined logs updated: {runs_file}")
print(f"📁 Configs updated: {configs_file}")
# Out:
# 🚀 Starting training for Run 08...
#
# Episode    1 | Steps:   70 | Reward:   37.28 | 🔴 Crashed | ε: 0.9950
# Episode    2 | Steps:   94 | Reward: -332.04 | 🔴 Crashed | ε: 0.9900
# Episode    3 | Steps:   66 | Reward:   14.74 | 🔴 Crashed | ε: 0.9851
# Episode    4 | Steps:   74 | Reward: -279.17 | 🔴 Crashed | ε: 0.9801
# Episode    5 | Steps:   82 | Reward: -156.33 | 🔴 Crashed | ε: 0.9752
# Episode    6 | Steps:   79 | Reward: -198.49 | 🔴 Crashed | ε: 0.9704
# Episode    7 | Steps:  135 | Reward:  -98.77 | 🔴 Crashed | ε: 0.9655
# Episode    8 | Steps:   86 | Reward: -111.27 | 🔴 Crashed | ε: 0.9607
# Episode    9 | Steps:   77 | Reward:  -95.62 | 🔴 Crashed | ε: 0.9559
# Episode   10 | Steps:   69 | Reward:  -80.54 | 🔴 Crashed | ε: 0.9511
# Episode   11 | Steps:  104 | Reward: -164.89 | 🔴 Crashed | ε: 0.9464
# Episode   12 | Steps:   89 | Reward: -102.60 | 🔴 Crashed | ε: 0.9416
# Episode   13 | Steps:  138 | Reward:  -76.59 | 🔴 Crashed | ε: 0.9369
# Episode   14 | Steps:  114 | Reward:  -81.12 | 🔴 Crashed | ε: 0.9322
# Episode   15 | Steps:  120 | Reward: -173.02 | 🔴 Crashed | ε: 0.9276
# Episode   16 | Steps:  111 | Reward: -178.67 | 🔴 Crashed | ε: 0.9229
# Episode   17 | Steps:   91 | Reward:  -85.26 | 🔴 Crashed | ε: 0.9183
# Episode   18 | Steps:   83 | Reward: -110.03 | 🔴 Crashed | ε: 0.9137
# Episode   19 | Steps:   77 | Reward: -114.84 | 🔴 Crashed | ε: 0.9092
# Episode   20 | Steps:  110 | Reward: -240.51 | 🔴 Crashed | ε: 0.9046
#   └─ Avg Reward: -131.387 | Success: 0, Crashed: 20, Out of bounds: 0, Time limit: 0
#
# Episode   21 | Steps:  117 | Reward: -187.98 | 🔴 Crashed | ε: 0.9001
# Episode   22 | Steps:   62 | Reward:  -79.07 | 🔴 Crashed | ε: 0.8956
# Episode   23 | Steps:  123 | Reward:  -99.54 | 🔴 Crashed | ε: 0.8911
# Episode   24 | Steps:   95 | Reward: -339.90 | 🔴 Crashed | ε: 0.8867
# Episode   25 | Steps:   84 | Reward: -115.16 | 🔴 Crashed | ε: 0.8822
# Episode   26 | Steps:   60 | Reward: -113.07 | 🔴 Crashed | ε: 0.8778
# Episode  378 | Steps:  772 | Reward:  105.96 | 🟢 Landed Success | ε: 0.1504
# Episode  379 | Steps: 1000 | Reward:  -60.10 | 🔵 Time Limit | ε: 0.1496
# Episode  380 | Steps: 1000 | Reward:  -29.35 | 🔵 Time Limit | ε: 0.1489
#   └─ Avg Reward: -27.863 | Success: 3, Crashed: 5, Out of bounds: 2, Time limit: 10
#
# Episode  381 | Steps: 1000 | Reward:   36.67 | 🔵 Time Limit | ε: 0.1481
# Episode  382 | Steps: 1000 | Reward:   46.51 | 🔵 Time Limit | ε: 0.1474
# Episode  383 | Steps: 1000 | Reward:  -91.49 | 🔵 Time Limit | ε: 0.1466
# Episode  384 | Steps: 1000 | Reward:  -28.40 | 🔵 Time Limit | ε: 0.1459
# Episode  385 | Steps: 1000 | Reward:   24.16 | 🔵 Time Limit | ε: 0.1452
# Episode  386 | Steps: 1000 | Reward:   77.91 | 🔵 Time Limit | ε: 0.1444
# Episode  387 | Steps:  551 | Reward:  214.65 | 🟢 Landed Success | ε: 0.1437
# Episode  388 | Steps: 1000 | Reward:    2.09 | 🔵 Time Limit | ε: 0.1430
# Episode  389 | Steps: 1000 | Reward:  -58.79 | 🔵 Time Limit | ε: 0.1423
# Episode  390 | Steps:   67 | Reward:  -82.23 | 🔴 Crashed | ε: 0.1416
# Episode  391 | Steps:  158 | Reward:   32.43 | 🔴 Crashed | ε: 0.1409
# Episode  392 | Steps:  184 | Reward: -340.48 | 🔴 Crashed | ε: 0.1402
# Episode  393 | Steps:  330 | Reward:   -9.13 | 🔴 Crashed | ε: 0.1395
# Episode  394 | Steps: 1000 | Reward:   46.31 | 🔵 Time Limit | ε: 0.1388
# Episode  395 | Steps:  916 | Reward:  189.30 | 🟢 Landed Success | ε: 0.1381
# Episode  396 | Steps:  176 | Reward:   -1.88 | 🔴 Crashed | ε: 0.1374
# Episode  397 | Steps: 1000 | Reward:   -5.20 | 🔵 Time Limit | ε: 0.1367
# Episode  398 | Steps:   60 | Reward:  -92.09 | 🔴 Crashed | ε: 0.1360
# Episode  399 | Steps: 1000 | Reward:  -48.19 | 🔵 Time Limit | ε: 0.1353
# Episode  400 | Steps: 1000 | Reward:   50.56 | 🔵 Time Limit | ε: 0.1347
#   └─ Avg Reward:  -1.863 | Success: 2, Crashed: 6, Out of bounds: 0, Time limit: 12
#
# Episode  401 | Steps:  258 | Reward:  273.85 | 🟢 Landed Success | ε: 0.1340
# Episode  402 | Steps:  371 | Reward:  -41.94 | 🔴 Crashed | ε: 0.1333
# Episode  403 | Steps: 1000 | Reward:   35.90 | 🔵 Time Limit | ε: 0.1326
# Episode  404 | Steps: 1000 | Reward:  -16.34 | 🔵 Time Limit | ε: 0.1320
# Episode  405 | Steps: 1000 | Reward:   14.96 | 🔵 Time Limit | ε: 0.1313
# Episode  406 | Steps: 1000 | Reward:  -27.22 | 🔵 Time Limit | ε: 0.1307
# Episode  407 | Steps:   98 | Reward:   -9.89 | 🔴 Crashed | ε: 0.1300
# Episode  408 | Steps:  193 | Reward:  -39.98 | 🔴 Crashed | ε: 0.1294
#   └─ Avg Reward:  -9.241 | Success: 3, Crashed: 11, Out of bounds: 2, Time limit: 4
#
# Episode  441 | Steps: 1000 | Reward:  -28.82 | 🔵 Time Limit | ε: 0.1096
# Episode  442 | Steps:  130 | Reward: -119.01 | 🟡 Out Of Bounds | ε: 0.1091
# Episode  443 | Steps:  200 | Reward:  -52.11 | 🔴 Crashed | ε: 0.1085
# Episode  444 | Steps: 1000 | Reward:  -44.02 | 🔵 Time Limit | ε: 0.1080
# Episode  445 | Steps:  374 | Reward: -138.20 | 🟡 Out Of Bounds | ε: 0.1075
# Episode  446 | Steps:  396 | Reward:  163.09 | 🟢 Landed Success | ε: 0.1069
# Episode  447 | Steps: 1000 | Reward:  -54.85 | 🔵 Time Limit | ε: 0.1064
# Episode  448 | Steps: 1000 | Reward:  -52.03 | 🔵 Time Limit | ε: 0.1059
# Episode  449 | Steps: 1000 | Reward:  -48.43 | 🔵 Time Limit | ε: 0.1053
# Episode  450 | Steps: 1000 | Reward:  -48.54 | 🔵 Time Limit | ε: 0.1048
# Episode  451 | Steps:  270 | Reward: -139.58 | 🟡 Out Of Bounds | ε: 0.1043
# Episode  452 | Steps:  739 | Reward:  142.46 | 🟢 Landed Success | ε: 0.1038
# Episode  453 | Steps:   70 | Reward:  -49.46 | 🔴 Crashed | ε: 0.1032
# Episode  454 | Steps:   66 | Reward:  -26.95 | 🔴 Crashed | ε: 0.1027
# Episode  455 | Steps: 1000 | Reward: -258.67 | 🔵 Time Limit | ε: 0.1022
# Episode  456 | Steps: 1000 | Reward:  -32.09 | 🔵 Time Limit | ε: 0.1017
# Episode  457 | Steps: 1000 | Reward:  -11.50 | 🔵 Time Limit | ε: 0.1012
# Episode  458 | Steps: 1000 | Reward:  -61.77 | 🔵 Time Limit | ε: 0.1007
# Episode  459 | Steps: 1000 | Reward:  -46.22 | 🔵 Time Limit | ε: 0.1002
# Episode  460 | Steps: 1000 | Reward:  -29.90 | 🔵 Time Limit | ε: 0.0997
#   └─ Avg Reward: -46.830 | Success: 2, Crashed: 3, Out of bounds: 3, Time limit: 12
#
# Episode  461 | Steps: 1000 | Reward:    4.07 | 🔵 Time Limit | ε: 0.0992
# Episode  462 | Steps:  942 | Reward:  176.50 | 🟢 Landed Success | ε: 0.0987
# Episode  463 | Steps: 1000 | Reward:  -25.66 | 🔵 Time Limit | ε: 0.0982
# Episode  464 | Steps:  113 | Reward:  -79.77 | 🔴 Crashed | ε: 0.0977
# Episode  465 | Steps: 1000 | Reward:   80.89 | 🔵 Time Limit | ε: 0.0972
# Episode  466 | Steps: 1000 | Reward:  -66.90 | 🔵 Time Limit | ε: 0.0967
# Episode  467 | Steps:  133 | Reward: -102.83 | 🟡 Out Of Bounds | ε: 0.0962
# Episode  468 | Steps: 1000 | Reward:    3.22 | 🔵 Time Limit | ε: 0.0958
# Episode  469 | Steps:  146 | Reward:  -99.11 | 🟡 Out Of Bounds | ε: 0.0953
# Episode  470 | Steps: 1000 | Reward:  -55.85 | 🔵 Time Limit | ε: 0.0948
# Episode  564 | Steps: 1000 | Reward:  -40.76 | 🔵 Time Limit | ε: 0.0592
# Episode  565 | Steps: 1000 | Reward:  -41.40 | 🔵 Time Limit | ε: 0.0589
# Episode  566 | Steps: 1000 | Reward:  -30.44 | 🔵 Time Limit | ε: 0.0586
# Episode  567 | Steps: 1000 | Reward:  -75.71 | 🔵 Time Limit | ε: 0.0583
# Episode  568 | Steps: 1000 | Reward:   -8.04 | 🔵 Time Limit | ε: 0.0580
# Episode  569 | Steps:  136 | Reward: -102.62 | 🟡 Out Of Bounds | ε: 0.0577
# Episode  570 | Steps: 1000 | Reward:  -41.03 | 🔵 Time Limit | ε: 0.0574
# Episode  571 | Steps: 1000 | Reward:  -36.64 | 🔵 Time Limit | ε: 0.0571
# Episode  572 | Steps: 1000 | Reward:  -18.10 | 🔵 Time Limit | ε: 0.0569
# Episode  573 | Steps: 1000 | Reward:  -67.92 | 🔵 Time Limit | ε: 0.0566
# Episode  574 | Steps: 1000 | Reward:  -56.38 | 🔵 Time Limit | ε: 0.0563
# Episode  575 | Steps: 1000 | Reward:  -14.88 | 🔵 Time Limit | ε: 0.0560
# Episode  576 | Steps:  132 | Reward: -128.32 | 🟡 Out Of Bounds | ε: 0.0557
# Episode  577 | Steps: 1000 | Reward:  -38.50 | 🔵 Time Limit | ε: 0.0555
# Episode  578 | Steps: 1000 | Reward:  -19.70 | 🔵 Time Limit | ε: 0.0552
# Episode  579 | Steps:  148 | Reward: -126.07 | 🟡 Out Of Bounds | ε: 0.0549
# Episode  580 | Steps:  644 | Reward: -257.53 | 🔴 Crashed | ε: 0.0546
#   └─ Avg Reward: -66.400 | Success: 0, Crashed: 2, Out of bounds: 4, Time limit: 14
#
# Episode  581 | Steps: 1000 | Reward:  -54.49 | 🔵 Time Limit | ε: 0.0544
# Episode  582 | Steps: 1000 | Reward:  -63.11 | 🔵 Time Limit | ε: 0.0541
# Episode  583 | Steps: 1000 | Reward:  -49.77 | 🔵 Time Limit | ε: 0.0538
# Episode  584 | Steps: 1000 | Reward:  -54.55 | 🔵 Time Limit | ε: 0.0535
# Episode  585 | Steps: 1000 | Reward:   48.90 | 🔵 Time Limit | ε: 0.0533
# Episode  586 | Steps:  277 | Reward:  198.67 | 🟢 Landed Success | ε: 0.0530
# Episode  587 | Steps:  354 | Reward:  179.82 | 🟢 Landed Success | ε: 0.0527
# Episode  588 | Steps: 1000 | Reward:  -64.75 | 🔵 Time Limit | ε: 0.0525
# Episode  589 | Steps:  231 | Reward:  178.89 | 🟢 Landed Success | ε: 0.0522
# Episode  590 | Steps:  444 | Reward:  186.03 | 🟢 Landed Success | ε: 0.0520
# Episode  591 | Steps:   78 | Reward: -114.23 | 🔴 Crashed | ε: 0.0517
# Episode  592 | Steps:  152 | Reward:  -18.15 | 🔴 Crashed | ε: 0.0514
# Episode  593 | Steps:   69 | Reward: -115.89 | 🔴 Crashed | ε: 0.0512
# Episode  594 | Steps:  561 | Reward: -196.54 | 🟡 Out Of Bounds | ε: 0.0509
# Episode  595 | Steps:  100 | Reward:  -86.51 | 🔴 Crashed | ε: 0.0507
# Episode  596 | Steps:   95 | Reward:  -81.68 | 🔴 Crashed | ε: 0.0504
# Episode  597 | Steps: 1000 | Reward:  -34.14 | 🔵 Time Limit | ε: 0.0502
# Episode  598 | Steps:  514 | Reward:  159.00 | 🟢 Landed Success | ε: 0.0499
# Episode  599 | Steps: 1000 | Reward:  -29.68 | 🔵 Time Limit | ε: 0.0497
# Episode  600 | Steps: 1000 | Reward:  -37.29 | 🔵 Time Limit | ε: 0.0494
#   └─ Avg Reward:  -2.474 | Success: 5, Crashed: 5, Out of bounds: 1, Time limit: 9
#
# Episode  601 | Steps: 1000 | Reward:  -58.00 | 🔵 Time Limit | ε: 0.0492
# Episode  602 | Steps: 1000 | Reward:  -39.48 | 🔵 Time Limit | ε: 0.0489
# Episode  603 | Steps:  867 | Reward:   92.52 | 🟢 Landed Success | ε: 0.0487
# Episode  604 | Steps:  129 | Reward: -194.88 | 🟡 Out Of Bounds | ε: 0.0484
# Episode  605 | Steps: 1000 | Reward:  -44.63 | 🔵 Time Limit | ε: 0.0482
# Episode  606 | Steps: 1000 | Reward:  -57.73 | 🔵 Time Limit | ε: 0.0479
# Episode  607 | Steps: 1000 | Reward: -116.51 | 🔵 Time Limit | ε: 0.0477
# Episode  608 | Steps: 1000 | Reward:  -77.40 | 🔵 Time Limit | ε: 0.0475
# Episode  609 | Steps: 1000 | Reward:   -9.53 | 🔵 Time Limit | ε: 0.0472
# Episode  610 | Steps: 1000 | Reward:  -77.74 | 🔵 Time Limit | ε: 0.0470
# Episode  611 | Steps: 1000 | Reward:  -53.66 | 🔵 Time Limit | ε: 0.0468
# Episode  612 | Steps: 1000 | Reward:  -34.36 | 🔵 Time Limit | ε: 0.0465
# Episode  613 | Steps: 1000 | Reward:   -7.69 | 🔵 Time Limit | ε: 0.0463
# Episode  614 | Steps: 1000 | Reward:  -55.75 | 🔵 Time Limit | ε: 0.0461
# Episode  615 | Steps: 1000 | Reward:  -50.85 | 🔵 Time Limit | ε: 0.0458
# Episode  616 | Steps: 1000 | Reward:  -84.18 | 🔵 Time Limit | ε: 0.0456
# Episode  617 | Steps: 1000 | Reward:  -84.11 | 🔵 Time Limit | ε: 0.0454
# Episode  618 | Steps:  914 | Reward:  141.00 | 🟢 Landed Success | ε: 0.0452
# Episode  619 | Steps:  443 | Reward: -155.90 | 🟡 Out Of Bounds | ε: 0.0449
# Episode  620 | Steps:  204 | Reward: -222.20 | 🟡 Out Of Bounds | ε: 0.0447
#   └─ Avg Reward: -59.554 | Success: 2, Crashed: 0, Out of bounds: 3, Time limit: 15
#
# Episode  621 | Steps:  124 | Reward:   10.16 | 🔴 Crashed | ε: 0.0445
# Episode  622 | Steps: 1000 | Reward:   -0.90 | 🔵 Time Limit | ε: 0.0443
# Episode  623 | Steps:  228 | Reward:  -31.78 | 🔴 Crashed | ε: 0.0440
# Episode  624 | Steps: 1000 | Reward:  -12.12 | 🔵 Time Limit | ε: 0.0438
# Episode  625 | Steps:   82 | Reward:   -5.47 | 🔴 Crashed | ε: 0.0436
# Episode  657 | Steps: 1000 | Reward:  -97.12 | 🔵 Time Limit | ε: 0.0371
# Episode  658 | Steps: 1000 | Reward:   47.94 | 🔵 Time Limit | ε: 0.0369
# Episode  659 | Steps: 1000 | Reward:  -40.55 | 🔵 Time Limit | ε: 0.0368
# Episode  660 | Steps: 1000 | Reward:    6.23 | 🔵 Time Limit | ε: 0.0366
#   └─ Avg Reward: -30.775 | Success: 2, Crashed: 8, Out of bounds: 2, Time limit: 8
#
# Episode  661 | Steps:  127 | Reward:  -76.21 | 🔴 Crashed | ε: 0.0364
# Episode  662 | Steps: 1000 | Reward:  -34.24 | 🔵 Time Limit | ε: 0.0362
# Episode  663 | Steps:  211 | Reward:  -66.33 | 🟡 Out Of Bounds | ε: 0.0360
# Episode  664 | Steps:  149 | Reward: -264.57 | 🟡 Out Of Bounds | ε: 0.0359
# Episode  665 | Steps:  107 | Reward: -180.29 | 🟡 Out Of Bounds | ε: 0.0357
# Episode  666 | Steps: 1000 | Reward:  -51.60 | 🔵 Time Limit | ε: 0.0355
# Episode  667 | Steps:  324 | Reward: -176.99 | 🟡 Out Of Bounds | ε: 0.0353
# Episode  668 | Steps:   73 | Reward:  -24.80 | 🔴 Crashed | ε: 0.0351
# Episode  669 | Steps:   90 | Reward:    0.65 | 🔴 Crashed | ε: 0.0350
# Episode  670 | Steps:  427 | Reward:  228.27 | 🟢 Landed Success | ε: 0.0348
# Episode  671 | Steps:  157 | Reward:  -70.94 | 🔴 Crashed | ε: 0.0346
# Episode  672 | Steps:  249 | Reward: -204.34 | 🔴 Crashed | ε: 0.0344
# Episode  673 | Steps:  118 | Reward:  -49.69 | 🔴 Crashed | ε: 0.0343
# Episode  674 | Steps:  690 | Reward: -249.54 | 🟡 Out Of Bounds | ε: 0.0341
# Episode  675 | Steps:  363 | Reward: -142.86 | 🟡 Out Of Bounds | ε: 0.0339
# Episode  676 | Steps: 1000 | Reward:  -46.55 | 🔵 Time Limit | ε: 0.0338
# Episode  677 | Steps: 1000 | Reward:  -34.22 | 🔵 Time Limit | ε: 0.0336
# Episode  678 | Steps:  155 | Reward:  -75.57 | 🔴 Crashed | ε: 0.0334
# Episode  679 | Steps:  189 | Reward: -270.17 | 🔴 Crashed | ε: 0.0333
# Episode  680 | Steps: 1000 | Reward:  -50.82 | 🔵 Time Limit | ε: 0.0331
#   └─ Avg Reward: -92.040 | Success: 1, Crashed: 8, Out of bounds: 6, Time limit: 5
#
# Episode  681 | Steps: 1000 | Reward:  -13.80 | 🔵 Time Limit | ε: 0.0329
# Episode  682 | Steps: 1000 | Reward:  -16.31 | 🔵 Time Limit | ε: 0.0328
# Episode  683 | Steps: 1000 | Reward:  -73.28 | 🔵 Time Limit | ε: 0.0326
# Episode  684 | Steps: 1000 | Reward: -101.50 | 🔵 Time Limit | ε: 0.0324
# Episode  685 | Steps: 1000 | Reward:  -40.31 | 🔵 Time Limit | ε: 0.0323
# Episode  686 | Steps: 1000 | Reward: -125.21 | 🔵 Time Limit | ε: 0.0321
# Episode  719 | Steps: 1000 | Reward:  -29.97 | 🔵 Time Limit | ε: 0.0272
# Episode  720 | Steps: 1000 | Reward:  -35.62 | 🔵 Time Limit | ε: 0.0271
#   └─ Avg Reward: -59.268 | Success: 2, Crashed: 14, Out of bounds: 1, Time limit: 3
#
# Episode  721 | Steps: 1000 | Reward:  -34.39 | 🔵 Time Limit | ε: 0.0269
# Episode  722 | Steps:  266 | Reward: -139.95 | 🟡 Out Of Bounds | ε: 0.0268
# Episode  723 | Steps: 1000 | Reward:    6.59 | 🔵 Time Limit | ε: 0.0267
# Episode  724 | Steps: 1000 | Reward:    7.39 | 🔵 Time Limit | ε: 0.0265
# Episode  725 | Steps: 1000 | Reward: -127.93 | 🔵 Time Limit | ε: 0.0264
# Episode  726 | Steps:  304 | Reward: -195.96 | 🟡 Out Of Bounds | ε: 0.0263
# Episode  727 | Steps:  987 | Reward: -260.16 | 🟡 Out Of Bounds | ε: 0.0261
# Episode  728 | Steps:  197 | Reward: -115.55 | 🔴 Crashed | ε: 0.0260
# Episode  729 | Steps:  505 | Reward: -112.24 | 🔴 Crashed | ε: 0.0259
# Episode  730 | Steps:  628 | Reward: -238.59 | 🟡 Out Of Bounds | ε: 0.0258
# Episode  731 | Steps:  110 | Reward: -196.28 | 🟡 Out Of Bounds | ε: 0.0256
# Episode  732 | Steps:  292 | Reward: -259.29 | 🟡 Out Of Bounds | ε: 0.0255
# Episode  733 | Steps:  139 | Reward: -241.93 | 🔴 Crashed | ε: 0.0254
# Episode  734 | Steps:  316 | Reward: -218.18 | 🟡 Out Of Bounds | ε: 0.0252
# Episode  735 | Steps:  777 | Reward:  -86.66 | 🔴 Crashed | ε: 0.0251
# Episode  736 | Steps:   87 | Reward:  -36.36 | 🔴 Crashed | ε: 0.0250
# Episode  737 | Steps:   95 | Reward: -100.63 | 🔴 Crashed | ε: 0.0249
# Episode  738 | Steps: 1000 | Reward: -102.19 | 🔵 Time Limit | ε: 0.0247
# Episode  739 | Steps:  648 | Reward: -176.31 | 🟡 Out Of Bounds | ε: 0.0246
# Episode  740 | Steps:  219 | Reward:  -39.53 | 🔴 Crashed | ε: 0.0245
#   └─ Avg Reward: -133.408 | Success: 0, Crashed: 7, Out of bounds: 8, Time limit: 5
#
# Episode  741 | Steps: 1000 | Reward:  -23.85 | 🔵 Time Limit | ε: 0.0244
# Episode  742 | Steps:  107 | Reward:  -68.53 | 🔴 Crashed | ε: 0.0243
# Episode  743 | Steps: 1000 | Reward:  -43.40 | 🔵 Time Limit | ε: 0.0241
# Episode  744 | Steps: 1000 | Reward:  -41.37 | 🔵 Time Limit | ε: 0.0240
# Episode  745 | Steps: 1000 | Reward:  -60.84 | 🔵 Time Limit | ε: 0.0239
# Episode  746 | Steps: 1000 | Reward:  -65.12 | 🔵 Time Limit | ε: 0.0238
# Episode  747 | Steps:  907 | Reward: -217.87 | 🟡 Out Of Bounds | ε: 0.0237
# Episode  748 | Steps: 1000 | Reward:  -65.51 | 🔵 Time Limit | ε: 0.0235
# Episode  749 | Steps: 1000 | Reward: -194.24 | 🔵 Time Limit | ε: 0.0234
#   └─ Avg Reward: -108.707 | Success: 0, Crashed: 8, Out of bounds: 9, Time limit: 3
#
# Episode  781 | Steps: 1000 | Reward:  -48.84 | 🔵 Time Limit | ε: 0.0199
# Episode  782 | Steps:  138 | Reward: -103.88 | 🟡 Out Of Bounds | ε: 0.0198
# Episode  783 | Steps:  130 | Reward: -181.36 | 🟡 Out Of Bounds | ε: 0.0197
# Episode  784 | Steps:  258 | Reward: -200.93 | 🟡 Out Of Bounds | ε: 0.0196
# Episode  785 | Steps:  103 | Reward: -221.60 | 🟡 Out Of Bounds | ε: 0.0195
# Episode  786 | Steps:  301 | Reward: -622.88 | 🔴 Crashed | ε: 0.0195
# Episode  787 | Steps:  168 | Reward: -294.20 | 🔴 Crashed | ε: 0.0194
# Episode  788 | Steps:   80 | Reward:  -28.73 | 🔴 Crashed | ε: 0.0193
# Episode  789 | Steps:  150 | Reward: -159.93 | 🔴 Crashed | ε: 0.0192
# Episode  790 | Steps:  187 | Reward:  -94.28 | 🔴 Crashed | ε: 0.0191
# Episode  791 | Steps: 1000 | Reward:  -43.42 | 🔵 Time Limit | ε: 0.0190
# Episode  792 | Steps:  234 | Reward: -612.52 | 🔴 Crashed | ε: 0.0189
# Episode  793 | Steps:  176 | Reward: -145.11 | 🟡 Out Of Bounds | ε: 0.0188
# Episode  794 | Steps:  167 | Reward: -199.06 | 🟡 Out Of Bounds | ε: 0.0187
# Episode  795 | Steps: 1000 | Reward: -130.87 | 🔵 Time Limit | ε: 0.0186
# Episode  796 | Steps: 1000 | Reward:  -40.75 | 🔵 Time Limit | ε: 0.0185
# Episode  797 | Steps:  144 | Reward: -109.37 | 🟡 Out Of Bounds | ε: 0.0184
# Episode  798 | Steps:  933 | Reward: -304.16 | 🟡 Out Of Bounds | ε: 0.0183
# Episode  799 | Steps:  133 | Reward: -167.46 | 🟡 Out Of Bounds | ε: 0.0182
# Episode  800 | Steps:  526 | Reward: -188.52 | 🟡 Out Of Bounds | ε: 0.0181
#   └─ Avg Reward: -194.894 | Success: 0, Crashed: 6, Out of bounds: 10, Time limit: 4
#
# ✅ Logs appended to runs/all_runs_combined.csv
#
# ✅ Training completed for Run 08!
# Total episodes: 800
# Replay buffer size: 64 transitions
# Total training steps: 341697
# Final epsilon: 0.0181
#
# 📊 Episode Outcomes:
#   🚀 Landed successfully: 45 (5.6%)
#   💥 Crashed: 441 (55.1%)
#   📍 Out of bounds: 108 (13.5%)
#   ⏱️  Time limit: 206 (25.8%)
#
# 📁 Individual log saved to: runs/run_list/run08.csv
# 📁 Combined logs updated: runs/all_runs_combined.csv
# 📁 Configs updated: runs/all_configs_combined.csv

# %% [markdown]
# ## Plot Training Progress

# %%
# Plot episode rewards over time with outcome colors and different markers
fig, ax = plt.subplots(figsize=(14, 6))

# Base line plot
ax.plot(episode_rewards, alpha=0.3, label='Episode Reward', linewidth=1, color='gray')

# Plot moving average
window = 40
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
ax.plot(range(window-1, len(episode_rewards)), moving_avg, linewidth=2.5, 
         label=f'Moving Avg ({window} episodes)', color='black')

# Color and marker mapping for outcomes
outcome_styles = {
    'landed_success': {'color': 'green', 'marker': 'o', 'label': 'Landed Success'},
    'crashed': {'color': 'red', 'marker': 'X', 'label': 'Crashed'},
    'out_of_bounds': {'color': 'yellow', 'marker': '^', 'label': 'Out of Bounds'},
    'time_limit': {'color': 'blue', 'marker': 's', 'label': 'Time Limit'}
}

# Plot scatter points with different markers for each outcome
for outcome, style in outcome_styles.items():
    episodes = [i for i, o in enumerate(episode_outcomes) if o == outcome]
    rewards = [episode_rewards[i] for i in episodes]
    ax.scatter(episodes, rewards, c=style['color'], marker=style['marker'], 
              label=style['label'], s=80, alpha=0.7, edgecolors='black', linewidth=1)

ax.set_xlabel('Episode', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('LunarLander DQN - Training Progress by Outcome', fontsize=14, fontweight='bold')
ax.legend(fontsize=10, loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 Training Statistics:")
print(f"  Average Reward: {np.mean(episode_rewards):.3f}")
print(f"  Max Reward: {np.max(episode_rewards):.3f}")
print(f"  Min Reward: {np.min(episode_rewards):.3f}")
print(f"  Std Dev: {np.std(episode_rewards):.3f}")
# Out:
# 📊 Training Statistics:
#   Average Reward: -101.619
#   Max Reward: 303.254
#   Min Reward: -676.651
#   Std Dev: 132.478

# %% [markdown]
# ## Watch Trained Agent in Action

# %%
from gymnasium.wrappers import RecordVideo
from IPython.display import HTML
import glob
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="rgb_array")
env = RecordVideo(
    env,
    video_folder="videos",
    episode_trigger=lambda episode_id: True,
    name_prefix="trained_agent"
)

obs, info = env.reset()

final_reward = 0.0
terminated = False
truncated = False
episode_steps = 0
final_obs = obs
last_step_reward = 0.0  # ✅ NEW: needed for outcome

agent.set_epsilon(0.0)  # exploit only

while not (terminated or truncated):
    action = agent.act(obs)
    obs, reward, terminated, truncated, info = env.step(action)

    final_reward += reward
    episode_steps += 1
    final_obs = obs
    last_step_reward = reward  # ✅ NEW: keep last step reward

env.close()

# ✅ Categorize episode outcome (correct args)
outcome = categorize_episode_outcome(
    final_obs,
    episode_steps,
    last_step_reward
)
outcome_icon = get_outcome_icon(outcome)

print(f"\n🎬 Trained Agent Performance:")
print(f" Total Reward: {final_reward:.3f}")
print(f" Episode Steps: {episode_steps}")
print(f" Outcome: {outcome_icon} {outcome.replace('_', ' ').title()}")

# pick the newest video (avoids grabbing an older mp4)
video_path = max(glob.glob("videos/*.mp4"), key=lambda p: p)

HTML(f"""
<video width="600" controls autoplay loop>
    <source src="{video_path}" type="video/mp4">
</video>
""")
# Out:
# c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\.venv\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 🎬 Trained Agent Performance:
#  Total Reward: -161.112
#  Episode Steps: 345
#  Outcome: 🟡 Out Of Bounds
# <video width="600" controls autoplay loop>
#     <source src="videos\trained_agent-episode-800.mp4" type="video/mp4">
# </video>
