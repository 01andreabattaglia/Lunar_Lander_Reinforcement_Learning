# %% [markdown]
# # LunarLander DQN Training
#
# Interactive training notebook with configurable hyperparameters.

# %%
import gymnasium as gym
from src.envs.make_env import make_env
from src.agents.epsilon_greedy_agent import EpsilonGreedyAgent
from src.networks.q_network import QNetwork
from src.replay.replay_buffer import ReplayBuffer
from src.training.trainer import Trainer
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Hyperparameters Configuration
#
# Modify these values to tune the training process:

# %%
# ============ TRAINING HYPERPARAMETERS ============
# Environment
num_episodes = 800  # Total number of training episodes
log_interval = 20  # Print stats every N episodes

# Training
train_every = 4  # Training step every N environment steps
batch_size = 64
learning_rate = 0.0001
gamma = 0.99  # Discount factor
replay_buffer_size = 50000  # Maximum size of the replay buffer

# Target Network Update
update_mode = 'hard'  # 'soft' for soft update every step, 'hard' for hard update every N steps
tau = 1e-3  # Soft update rate (used only if update_mode='soft')
target_update_freq = 1  # Hard update frequency (used only if update_mode='hard')

# Exploration
epsilon_starting_value = 1  # Initial exploration rate
epsilon_ending_value = 0.01   # Final exploration rate
epsilon_decay_value = 0.995   # Decay factor per episode

# %% [markdown]
# ## Initialize Components

# %%
# Initialize Q-Network
q_network = QNetwork(input_size=8, output_size=4)

# Initialize epsilon from config
epsilon = epsilon_starting_value

# Initialize agent
agent = EpsilonGreedyAgent(action_space=4, q_network=q_network, epsilon=epsilon)

# Initialize replay buffer
replay_buffer = ReplayBuffer(max_size=replay_buffer_size)

# Initialize trainer with hyperparameters
trainer = Trainer(
    q_network, 
    learning_rate=learning_rate, 
    replay_buffer=replay_buffer, 
    gamma=gamma,
    update_mode=update_mode,
    tau=tau,
    target_update_freq=target_update_freq
)

# Create environment
env = make_env(render_mode="rgb_array")

# %%
import csv
import os
import pandas as pd
from src.training.episode_outcome import categorize_episode_outcome, get_outcome_icon

# ===== AUTO-INCREMENT RUN ID =====
configs_file = 'runs/all_configs_combined.csv'
runs_file = 'runs/all_runs_combined.csv'

# Read existing configs to find last run_id
df_configs = pd.read_csv(configs_file, dtype={'run_id': str})
last_run_id = df_configs['run_id'].astype(int).max()
new_run_id = str(last_run_id + 1).zfill(2)

print(f"📋 Last run_id found: {last_run_id:02d}")
print(f"🆕 New run_id: {new_run_id}")

# ===== APPEND NEW CONFIG TO all_configs_combined.csv =====
new_config = {
    'run_id': new_run_id,
    'num_episodes': num_episodes,
    'log_interval': log_interval,
    'train_every': train_every,
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'gamma': gamma,
    'update_mode': update_mode,
    'tau': tau,
    'target_update_freq': target_update_freq,
    'replay_buffer_size': replay_buffer_size,
    'epsilon_starting_value': epsilon_starting_value,
    'epsilon_ending_value': epsilon_ending_value,
    'epsilon_decay_value': epsilon_decay_value
}

# Append to configs file
new_config_df = pd.DataFrame([new_config])
new_config_df.to_csv(configs_file, mode='a', header=False, index=False)
print(f"✅ Config appended to {configs_file}")

# ===== SETUP LOG FILE =====
run_list_dir = 'runs/run_list'
os.makedirs(run_list_dir, exist_ok=True)
log_file = f'{run_list_dir}/run{new_run_id}.csv'

with open(log_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['episode', 'reward', 'length', 'terminated', 'truncated', 'outcome'])

print(f"📁 Log file created: {log_file}")
# Out:
# 📋 Last run_id found: 13
# 🆕 New run_id: 14
# ✅ Config appended to runs/all_configs_combined.csv
# 📁 Log file created: runs/run_list/run14.csv

# %% [markdown]
# ## Training Loop with Visualization

# %%
# Training loop with episode outcome logging
episode_rewards = []
training_steps = 0
episode_outcomes = []
episode_logs = []  # Store logs for appending to combined file

print(f"🚀 Starting training for Run {new_run_id}...\n")

for episode in range(num_episodes):
    obs, info = env.reset()
    total_reward = 0.0
    terminated = False
    truncated = False
    episode_length = 0
    final_obs = obs
    last_step_reward = 0.0  # keep last reward of the episode

    while not (terminated or truncated):
        # Ask agent for action
        action = agent.act(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)

        # store last step reward (used for outcome classification)
        last_step_reward = reward

        # Store transition in replay buffer
        done = terminated or truncated
        replay_buffer.add(obs, action, reward, next_obs, done)

        # Training step: sample batch and update network
        if training_steps % train_every == 0:
            loss = trainer.train_step(batch_size=batch_size)

        training_steps += 1
        total_reward += reward
        episode_length += 1
        obs = next_obs
        final_obs = next_obs

    episode_rewards.append(total_reward)

    # Categorize episode outcome
    outcome = categorize_episode_outcome(final_obs, episode_length, last_step_reward)
    episode_outcomes.append(outcome)

    # Store log entry
    log_entry = {
        'run_id': new_run_id,
        'episode': episode + 1,
        'reward': round(total_reward, 2),
        'length': episode_length,
        'terminated': int(terminated),
        'truncated': int(truncated),
        'outcome': outcome
    }
    episode_logs.append(log_entry)

    # Log to individual run CSV file
    with open(log_file, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([episode + 1, f"{total_reward:.2f}", episode_length,
                         int(terminated), int(truncated), outcome])

    # Decay epsilon after each episode
    epsilon = max(epsilon_ending_value, epsilon * epsilon_decay_value)
    agent.set_epsilon(epsilon)

    # Print individual episode result
    outcome_icon = get_outcome_icon(outcome)
    print(
        f"Episode {episode + 1:4d} | Steps: {episode_length:4d} | Reward: {total_reward:7.2f} | "
        f"{outcome_icon} {outcome.replace('_', ' ').title()} | ε: {epsilon:.4f}"
    )

    # Log average reward every N episodes
    if (episode + 1) % log_interval == 0:
        avg_reward = sum(episode_rewards[-log_interval:]) / log_interval

        # Count outcomes in recent window
        recent_outcomes = episode_outcomes[-log_interval:]
        outcome_counts = {
            'success': recent_outcomes.count('landed_success'),
            'crashed': recent_outcomes.count('crashed'),
            'out_of_bounds': recent_outcomes.count('out_of_bounds'),
            'time_limit': recent_outcomes.count('time_limit')
        }

        print(
            f"  └─ Avg Reward: {avg_reward:7.3f} | "
            f"Success: {outcome_counts['success']}, "
            f"Crashed: {outcome_counts['crashed']}, "
            f"Out of bounds: {outcome_counts['out_of_bounds']}, "
            f"Time limit: {outcome_counts['time_limit']}"
        )
        print()

env.close()

# ===== APPEND LOGS TO all_runs_combined.csv =====
logs_df = pd.DataFrame(episode_logs)
logs_df.to_csv(runs_file, mode='a', header=False, index=False)
print(f"✅ Logs appended to {runs_file}")

print(f"\n✅ Training completed for Run {new_run_id}!")
print(f"Total episodes: {num_episodes}")
print(f"Replay buffer size: {len(replay_buffer)} transitions")
print(f"Total training steps: {training_steps}")
print(f"Final epsilon: {epsilon:.4f}")

# Final statistics
success_count = episode_outcomes.count('landed_success')
crashed_count = episode_outcomes.count('crashed')
out_of_bounds_count = episode_outcomes.count('out_of_bounds')
time_limit_count = episode_outcomes.count('time_limit')

print(f"\n📊 Episode Outcomes:")
print(f"  🚀 Landed successfully: {success_count} ({100*success_count/num_episodes:.1f}%)")
print(f"  💥 Crashed: {crashed_count} ({100*crashed_count/num_episodes:.1f}%)")
print(f"  📍 Out of bounds: {out_of_bounds_count} ({100*out_of_bounds_count/num_episodes:.1f}%)")
print(f"  ⏱️  Time limit: {time_limit_count} ({100*time_limit_count/num_episodes:.1f}%)")
print(f"\n📁 Individual log saved to: {log_file}")
print(f"📁 Combined logs updated: {runs_file}")
print(f"📁 Configs updated: {configs_file}")
# Out:
# 🚀 Starting training for Run 14...
#
# Episode    1 | Steps:  116 | Reward: -408.22 | 🔴 Crashed | ε: 0.9950
# Episode    2 | Steps:   85 | Reward: -117.57 | 🔴 Crashed | ε: 0.9900
# Episode    3 | Steps:  115 | Reward: -105.20 | 🔴 Crashed | ε: 0.9851
# Episode    4 | Steps:   75 | Reward: -228.62 | 🔴 Crashed | ε: 0.9801
# Episode    5 | Steps:  164 | Reward: -224.10 | 🔴 Crashed | ε: 0.9752
# Episode    6 | Steps:  121 | Reward: -193.08 | 🔴 Crashed | ε: 0.9704
# Episode    7 | Steps:  108 | Reward: -218.16 | 🔴 Crashed | ε: 0.9655
# Episode    8 | Steps:  104 | Reward: -274.28 | 🟡 Out Of Bounds | ε: 0.9607
# Episode    9 | Steps:   85 | Reward: -329.50 | 🔴 Crashed | ε: 0.9559
# Episode   10 | Steps:  111 | Reward:  -98.54 | 🔴 Crashed | ε: 0.9511
# Episode   11 | Steps:  106 | Reward: -140.86 | 🔴 Crashed | ε: 0.9464
# Episode   12 | Steps:   68 | Reward:  -71.70 | 🔴 Crashed | ε: 0.9416
# Episode   13 | Steps:   86 | Reward:  -70.93 | 🔴 Crashed | ε: 0.9369
# Episode   14 | Steps:   79 | Reward: -129.37 | 🔴 Crashed | ε: 0.9322
# Episode   15 | Steps:  107 | Reward: -110.28 | 🔴 Crashed | ε: 0.9276
# Episode   16 | Steps:  107 | Reward: -281.84 | 🟡 Out Of Bounds | ε: 0.9229
# Episode   17 | Steps:   83 | Reward: -105.90 | 🔴 Crashed | ε: 0.9183
# Episode   18 | Steps:   79 | Reward: -100.08 | 🔴 Crashed | ε: 0.9137
# Episode   19 | Steps:  113 | Reward: -218.88 | 🔴 Crashed | ε: 0.9092
# Episode   20 | Steps:   67 | Reward: -150.70 | 🔴 Crashed | ε: 0.9046
#   └─ Avg Reward: -178.890 | Success: 0, Crashed: 18, Out of bounds: 2, Time limit: 0
#
# Episode   21 | Steps:  107 | Reward: -242.54 | 🔴 Crashed | ε: 0.9001
# Episode   22 | Steps:   65 | Reward:  -89.84 | 🔴 Crashed | ε: 0.8956
# Episode   23 | Steps:   66 | Reward:  -76.64 | 🔴 Crashed | ε: 0.8911
# Episode   24 | Steps:   70 | Reward: -103.48 | 🔴 Crashed | ε: 0.8867
# Episode   25 | Steps:   73 | Reward:  -95.70 | 🔴 Crashed | ε: 0.8822
# Episode   26 | Steps:  139 | Reward:    4.67 | 🔴 Crashed | ε: 0.8778
# Episode   27 | Steps:   76 | Reward:  -77.75 | 🔴 Crashed | ε: 0.8734
# Episode   28 | Steps:   84 | Reward: -356.73 | 🟡 Out Of Bounds | ε: 0.8691
# Episode   29 | Steps:  154 | Reward:  -44.99 | 🔴 Crashed | ε: 0.8647
# Episode   30 | Steps:  130 | Reward: -381.34 | 🔴 Crashed | ε: 0.8604
# Episode   31 | Steps:   94 | Reward:   17.09 | 🔴 Crashed | ε: 0.8561
# Episode   32 | Steps:  109 | Reward: -401.26 | 🟡 Out Of Bounds | ε: 0.8518
# Episode   33 | Steps:   86 | Reward: -356.58 | 🔴 Crashed | ε: 0.8475
# Episode   34 | Steps:  142 | Reward: -380.63 | 🔴 Crashed | ε: 0.8433
# Episode   35 | Steps:  119 | Reward: -134.15 | 🔴 Crashed | ε: 0.8391
# Episode   36 | Steps:  137 | Reward:  -93.01 | 🔴 Crashed | ε: 0.8349
# Episode   37 | Steps:  105 | Reward:  -62.08 | 🔴 Crashed | ε: 0.8307
# Episode   38 | Steps:   81 | Reward:  -90.47 | 🔴 Crashed | ε: 0.8266
# Episode   39 | Steps:  107 | Reward: -176.55 | 🟡 Out Of Bounds | ε: 0.8224
# Episode   40 | Steps:   92 | Reward: -340.00 | 🟡 Out Of Bounds | ε: 0.8183
#   └─ Avg Reward: -174.098 | Success: 0, Crashed: 16, Out of bounds: 4, Time limit: 0
#
# Episode   41 | Steps:  167 | Reward:  -42.48 | 🔴 Crashed | ε: 0.8142
# Episode   42 | Steps:  125 | Reward: -231.52 | 🟡 Out Of Bounds | ε: 0.8102
# Episode   43 | Steps:  108 | Reward: -146.04 | 🔴 Crashed | ε: 0.8061
# Episode   44 | Steps:   91 | Reward:  -73.74 | 🔴 Crashed | ε: 0.8021
# Episode   45 | Steps:  117 | Reward: -279.89 | 🟡 Out Of Bounds | ε: 0.7981
# Episode   46 | Steps:   90 | Reward: -155.72 | 🔴 Crashed | ε: 0.7941
# Episode   47 | Steps:  116 | Reward: -224.65 | 🟡 Out Of Bounds | ε: 0.7901
# Episode   48 | Steps:   88 | Reward: -147.06 | 🔴 Crashed | ε: 0.7862
# Episode   49 | Steps:  138 | Reward:  -91.21 | 🔴 Crashed | ε: 0.7822
# Episode   50 | Steps:  108 | Reward:  -44.53 | 🔴 Crashed | ε: 0.7783
# Episode   51 | Steps:   89 | Reward: -102.23 | 🔴 Crashed | ε: 0.7744
# Episode   52 | Steps:  170 | Reward: -159.51 | 🔴 Crashed | ε: 0.7705
# Episode   53 | Steps:  127 | Reward: -201.94 | 🟡 Out Of Bounds | ε: 0.7667
# Episode   54 | Steps:   95 | Reward:  -96.58 | 🔴 Crashed | ε: 0.7629
# Episode   55 | Steps:  136 | Reward:  -31.11 | 🔴 Crashed | ε: 0.7590
# Episode   56 | Steps:  107 | Reward:  -57.06 | 🔴 Crashed | ε: 0.7553
# Episode   57 | Steps:  164 | Reward: -241.96 | 🔴 Crashed | ε: 0.7515
# Episode   58 | Steps:  114 | Reward: -139.83 | 🔴 Crashed | ε: 0.7477
# Episode   59 | Steps:  107 | Reward: -194.91 | 🔴 Crashed | ε: 0.7440
# Episode   60 | Steps:  146 | Reward: -247.74 | 🔴 Crashed | ε: 0.7403
#   └─ Avg Reward: -145.485 | Success: 0, Crashed: 16, Out of bounds: 4, Time limit: 0
#
# Episode   61 | Steps:  168 | Reward:  -33.51 | 🔴 Crashed | ε: 0.7366
# Episode   62 | Steps:  113 | Reward: -129.56 | 🟡 Out Of Bounds | ε: 0.7329
# Episode   63 | Steps:   73 | Reward:  -25.02 | 🔴 Crashed | ε: 0.7292
# Episode   64 | Steps:   84 | Reward:  -68.19 | 🔴 Crashed | ε: 0.7256
# Episode   65 | Steps:  118 | Reward:    2.86 | 🔴 Crashed | ε: 0.7219
# Episode   66 | Steps:  135 | Reward: -183.65 | 🔴 Crashed | ε: 0.7183
# Episode   67 | Steps:  137 | Reward:  -41.92 | 🔴 Crashed | ε: 0.7147
# Episode   68 | Steps:  171 | Reward: -166.07 | 🔴 Crashed | ε: 0.7112
# Episode   69 | Steps:  142 | Reward: -112.00 | 🔴 Crashed | ε: 0.7076
# Episode   70 | Steps:  125 | Reward: -145.72 | 🔴 Crashed | ε: 0.7041
# Episode   71 | Steps:  161 | Reward: -153.33 | 🔴 Crashed | ε: 0.7005
# Episode   72 | Steps:  138 | Reward: -116.72 | 🔴 Crashed | ε: 0.6970
# Episode   73 | Steps:  141 | Reward:  -75.74 | 🔴 Crashed | ε: 0.6936
# Episode   74 | Steps:  116 | Reward: -120.97 | 🔴 Crashed | ε: 0.6901
# Episode   75 | Steps:  153 | Reward: -197.01 | 🔴 Crashed | ε: 0.6866
# Episode   76 | Steps:  158 | Reward: -148.06 | 🔴 Crashed | ε: 0.6832
# Episode   77 | Steps:  113 | Reward:  -81.81 | 🔴 Crashed | ε: 0.6798
# Episode   78 | Steps:  256 | Reward: -138.45 | 🔴 Crashed | ε: 0.6764
# Episode   79 | Steps:   91 | Reward:  -41.69 | 🔴 Crashed | ε: 0.6730
# Episode   80 | Steps:  157 | Reward: -207.81 | 🟡 Out Of Bounds | ε: 0.6696
#   └─ Avg Reward: -109.218 | Success: 0, Crashed: 18, Out of bounds: 2, Time limit: 0
#
# Episode   81 | Steps:  104 | Reward:  -33.06 | 🔴 Crashed | ε: 0.6663
# Episode   82 | Steps:  100 | Reward: -107.49 | 🔴 Crashed | ε: 0.6630
# Episode   83 | Steps:  104 | Reward: -137.41 | 🔴 Crashed | ε: 0.6597
# Episode   84 | Steps:  233 | Reward:  -21.01 | 🔴 Crashed | ε: 0.6564
# Episode   85 | Steps:  129 | Reward:  -68.01 | 🔴 Crashed | ε: 0.6531
# Episode   86 | Steps:   90 | Reward: -145.25 | 🔴 Crashed | ε: 0.6498
# Episode   87 | Steps:   77 | Reward: -119.11 | 🔴 Crashed | ε: 0.6466
# Episode   88 | Steps:   96 | Reward:  -95.86 | 🔴 Crashed | ε: 0.6433
# Episode   89 | Steps:  154 | Reward:  -42.24 | 🔴 Crashed | ε: 0.6401
# Episode   90 | Steps:  173 | Reward: -306.94 | 🔴 Crashed | ε: 0.6369
# Episode   91 | Steps:  159 | Reward:  -76.25 | 🔴 Crashed | ε: 0.6337
# Episode   92 | Steps:  110 | Reward:  -19.90 | 🔴 Crashed | ε: 0.6306
# Episode   93 | Steps:  114 | Reward: -196.76 | 🔴 Crashed | ε: 0.6274
# Episode   94 | Steps:  216 | Reward:  -67.70 | 🔴 Crashed | ε: 0.6243
# Episode   95 | Steps: 1000 | Reward:   47.31 | 🔵 Time Limit | ε: 0.6211
# Episode   96 | Steps:   97 | Reward:  -37.00 | 🔴 Crashed | ε: 0.6180
# Episode   97 | Steps:  124 | Reward: -121.87 | 🔴 Crashed | ε: 0.6149
# Episode   98 | Steps:  199 | Reward:  -67.61 | 🔴 Crashed | ε: 0.6119
# Episode   99 | Steps:  119 | Reward: -110.90 | 🔴 Crashed | ε: 0.6088
# Episode  100 | Steps:   93 | Reward: -104.05 | 🔴 Crashed | ε: 0.6058
#   └─ Avg Reward: -91.554 | Success: 0, Crashed: 19, Out of bounds: 0, Time limit: 1
#
# Episode  101 | Steps:  131 | Reward:  -18.93 | 🔴 Crashed | ε: 0.6027
# Episode  102 | Steps:  104 | Reward: -142.51 | 🔴 Crashed | ε: 0.5997
# Episode  103 | Steps:  101 | Reward: -125.65 | 🔴 Crashed | ε: 0.5967
# Episode  104 | Steps:  121 | Reward:  -71.62 | 🔴 Crashed | ε: 0.5937
# Episode  105 | Steps:  144 | Reward:  -24.97 | 🔴 Crashed | ε: 0.5908
# Episode  106 | Steps:   75 | Reward:  -52.58 | 🔴 Crashed | ε: 0.5878
# Episode  107 | Steps:  129 | Reward:  -81.59 | 🔴 Crashed | ε: 0.5849
# Episode  108 | Steps:   98 | Reward: -106.39 | 🔴 Crashed | ε: 0.5820
# Episode  109 | Steps: 1000 | Reward:  126.81 | 🔵 Time Limit | ε: 0.5790
# Episode  110 | Steps:  168 | Reward:  -71.81 | 🔴 Crashed | ε: 0.5762
# Episode  111 | Steps:  124 | Reward:  -97.57 | 🔴 Crashed | ε: 0.5733
# Episode  112 | Steps:  121 | Reward:  -82.87 | 🔴 Crashed | ε: 0.5704
# Episode  113 | Steps:  116 | Reward:    0.64 | 🔴 Crashed | ε: 0.5676
# Episode  114 | Steps:  138 | Reward:  -66.68 | 🔴 Crashed | ε: 0.5647
# Episode  115 | Steps:  138 | Reward:  -76.72 | 🔴 Crashed | ε: 0.5619
# Episode  116 | Steps:   79 | Reward:  -31.90 | 🔴 Crashed | ε: 0.5591
# Episode  117 | Steps:  230 | Reward:  -34.72 | 🔴 Crashed | ε: 0.5563
# Episode  118 | Steps:   98 | Reward:  -65.42 | 🔴 Crashed | ε: 0.5535
# Episode  119 | Steps:  302 | Reward:  -20.52 | 🔴 Crashed | ε: 0.5507
# Episode  120 | Steps:  120 | Reward:  -66.74 | 🔴 Crashed | ε: 0.5480
#   └─ Avg Reward: -55.588 | Success: 0, Crashed: 19, Out of bounds: 0, Time limit: 1
#
# Episode  121 | Steps:  209 | Reward:  -50.21 | 🔴 Crashed | ε: 0.5452
# Episode  122 | Steps:   96 | Reward:  -75.68 | 🔴 Crashed | ε: 0.5425
# Episode  123 | Steps:   87 | Reward: -138.36 | 🔴 Crashed | ε: 0.5398
# Episode  124 | Steps:  121 | Reward:  -79.84 | 🔴 Crashed | ε: 0.5371
# Episode  125 | Steps:  144 | Reward:  -40.77 | 🔴 Crashed | ε: 0.5344
# Episode  126 | Steps:  156 | Reward:  -76.69 | 🔴 Crashed | ε: 0.5318
# Episode  127 | Steps:  205 | Reward:   -7.15 | 🔴 Crashed | ε: 0.5291
# Episode  128 | Steps:  156 | Reward:   35.65 | 🔴 Crashed | ε: 0.5264
# Episode  129 | Steps:  132 | Reward:  -56.22 | 🔴 Crashed | ε: 0.5238
# Episode  130 | Steps:   88 | Reward:  -82.31 | 🔴 Crashed | ε: 0.5212
# Episode  131 | Steps:  264 | Reward:  -35.90 | 🔴 Crashed | ε: 0.5186
# Episode  132 | Steps:   84 | Reward:  -89.41 | 🔴 Crashed | ε: 0.5160
# Episode  133 | Steps:  253 | Reward:   25.40 | 🔴 Crashed | ε: 0.5134
# Episode  134 | Steps:  124 | Reward:  -39.54 | 🔴 Crashed | ε: 0.5108
# Episode  135 | Steps:  358 | Reward: -153.51 | 🔴 Crashed | ε: 0.5083
# Episode  136 | Steps:  171 | Reward:  -86.01 | 🔴 Crashed | ε: 0.5058
# Episode  137 | Steps:  237 | Reward: -101.57 | 🔴 Crashed | ε: 0.5032
# Episode  138 | Steps:  115 | Reward: -153.55 | 🔴 Crashed | ε: 0.5007
# Episode  139 | Steps:  143 | Reward:  -70.23 | 🔴 Crashed | ε: 0.4982
# Episode  140 | Steps:  132 | Reward:  -33.95 | 🔴 Crashed | ε: 0.4957
#   └─ Avg Reward: -65.493 | Success: 0, Crashed: 20, Out of bounds: 0, Time limit: 0
#
# Episode  141 | Steps:  200 | Reward:    4.25 | 🔴 Crashed | ε: 0.4932
# Episode  142 | Steps:   94 | Reward:  -64.33 | 🔴 Crashed | ε: 0.4908
# Episode  143 | Steps:  118 | Reward:  -81.60 | 🔴 Crashed | ε: 0.4883
# Episode  144 | Steps:  319 | Reward:  -62.07 | 🔴 Crashed | ε: 0.4859
# Episode  145 | Steps:  118 | Reward:  -75.78 | 🔴 Crashed | ε: 0.4834
# Episode  146 | Steps:  102 | Reward:  -88.88 | 🔴 Crashed | ε: 0.4810
# Episode  147 | Steps:  186 | Reward:  -38.49 | 🔴 Crashed | ε: 0.4786
# Episode  148 | Steps:  277 | Reward:  -41.84 | 🔴 Crashed | ε: 0.4762
# Episode  149 | Steps:  424 | Reward: -133.37 | 🟡 Out Of Bounds | ε: 0.4738
# Episode  150 | Steps:  112 | Reward:  -80.22 | 🔴 Crashed | ε: 0.4715
# Episode  151 | Steps:  163 | Reward:  -64.11 | 🔴 Crashed | ε: 0.4691
# Episode  152 | Steps:  127 | Reward:  -97.45 | 🔴 Crashed | ε: 0.4668
# Episode  153 | Steps:  156 | Reward:   -0.86 | 🔴 Crashed | ε: 0.4644
# Episode  154 | Steps:  212 | Reward: -227.11 | 🔴 Crashed | ε: 0.4621
# Episode  155 | Steps:  119 | Reward:  -89.23 | 🔴 Crashed | ε: 0.4598
# Episode  156 | Steps:  125 | Reward:  -86.14 | 🔴 Crashed | ε: 0.4575
# Episode  157 | Steps:  155 | Reward:  -37.60 | 🔴 Crashed | ε: 0.4552
# Episode  158 | Steps:  378 | Reward: -101.34 | 🔴 Crashed | ε: 0.4529
# Episode  159 | Steps: 1000 | Reward: -112.10 | 🔵 Time Limit | ε: 0.4507
# Episode  160 | Steps:  103 | Reward:  -41.15 | 🔴 Crashed | ε: 0.4484
#   └─ Avg Reward: -75.971 | Success: 0, Crashed: 18, Out of bounds: 1, Time limit: 1
#
# Episode  161 | Steps:  533 | Reward:  -55.16 | 🔴 Crashed | ε: 0.4462
# Episode  162 | Steps:  186 | Reward:   28.99 | 🔴 Crashed | ε: 0.4440
# Episode  163 | Steps:  470 | Reward:  -96.14 | 🔴 Crashed | ε: 0.4417
# Episode  164 | Steps:   86 | Reward:  -84.22 | 🔴 Crashed | ε: 0.4395
# Episode  165 | Steps:  237 | Reward:  -31.22 | 🔴 Crashed | ε: 0.4373
# Episode  166 | Steps:  200 | Reward:  -38.59 | 🔴 Crashed | ε: 0.4351
# Episode  167 | Steps:  115 | Reward:  -39.50 | 🔴 Crashed | ε: 0.4330
# Episode  168 | Steps:  329 | Reward:  -40.86 | 🔴 Crashed | ε: 0.4308
# Episode  169 | Steps:  299 | Reward:  -35.42 | 🔴 Crashed | ε: 0.4286
# Episode  170 | Steps:  151 | Reward:  -76.52 | 🟡 Out Of Bounds | ε: 0.4265
# Episode  171 | Steps: 1000 | Reward:   29.58 | 🔵 Time Limit | ε: 0.4244
# Episode  172 | Steps:  727 | Reward: -184.08 | 🟡 Out Of Bounds | ε: 0.4223
# Episode  173 | Steps:  148 | Reward:   -3.09 | 🔴 Crashed | ε: 0.4201
# Episode  174 | Steps:  916 | Reward: -205.88 | 🟡 Out Of Bounds | ε: 0.4180
# Episode  175 | Steps:  178 | Reward:  -45.42 | 🔴 Crashed | ε: 0.4159
# Episode  176 | Steps: 1000 | Reward:    0.50 | 🔵 Time Limit | ε: 0.4139
# Episode  177 | Steps:  245 | Reward: -100.76 | 🔴 Crashed | ε: 0.4118
# Episode  178 | Steps: 1000 | Reward:   26.67 | 🔵 Time Limit | ε: 0.4097
# Episode  179 | Steps: 1000 | Reward:   45.71 | 🔵 Time Limit | ε: 0.4077
# Episode  180 | Steps:  156 | Reward:  -80.08 | 🔴 Crashed | ε: 0.4057
#   └─ Avg Reward: -49.274 | Success: 0, Crashed: 13, Out of bounds: 3, Time limit: 4
#
# Episode  181 | Steps:  140 | Reward:  -45.99 | 🔴 Crashed | ε: 0.4036
# Episode  182 | Steps:  416 | Reward: -119.91 | 🔴 Crashed | ε: 0.4016
# Episode  183 | Steps:  126 | Reward: -185.54 | 🔴 Crashed | ε: 0.3996
# Episode  184 | Steps:  483 | Reward: -180.67 | 🟡 Out Of Bounds | ε: 0.3976
# Episode  185 | Steps:  199 | Reward:  -95.40 | 🔴 Crashed | ε: 0.3956
# Episode  186 | Steps:  120 | Reward:  -18.00 | 🔴 Crashed | ε: 0.3936
# Episode  187 | Steps:  339 | Reward: -137.71 | 🔴 Crashed | ε: 0.3917
# Episode  188 | Steps:  277 | Reward:  -76.18 | 🔴 Crashed | ε: 0.3897
# Episode  189 | Steps:  185 | Reward:   -2.06 | 🔴 Crashed | ε: 0.3878
# Episode  190 | Steps: 1000 | Reward:  -43.32 | 🔵 Time Limit | ε: 0.3858
# Episode  191 | Steps:  186 | Reward:  -38.29 | 🔴 Crashed | ε: 0.3839
# Episode  192 | Steps:  111 | Reward:  -75.75 | 🔴 Crashed | ε: 0.3820
# Episode  193 | Steps:  274 | Reward:  -64.95 | 🔴 Crashed | ε: 0.3801
# Episode  194 | Steps: 1000 | Reward:  -85.18 | 🔵 Time Limit | ε: 0.3782
# Episode  195 | Steps:  191 | Reward: -111.17 | 🔴 Crashed | ε: 0.3763
# Episode  196 | Steps:  929 | Reward: -176.93 | 🟡 Out Of Bounds | ε: 0.3744
# Episode  197 | Steps:  239 | Reward:  -70.08 | 🔴 Crashed | ε: 0.3725
# Episode  198 | Steps:  920 | Reward: -121.03 | 🔴 Crashed | ε: 0.3707
# Episode  199 | Steps: 1000 | Reward:  -52.45 | 🔵 Time Limit | ε: 0.3688
# Episode  200 | Steps: 1000 | Reward:  -30.39 | 🔵 Time Limit | ε: 0.3670
#   └─ Avg Reward: -86.550 | Success: 0, Crashed: 14, Out of bounds: 2, Time limit: 4
#
# Episode  201 | Steps:  343 | Reward:  -44.94 | 🔴 Crashed | ε: 0.3651
# Episode  202 | Steps: 1000 | Reward:  -53.31 | 🔵 Time Limit | ε: 0.3633
# Episode  203 | Steps:  246 | Reward:  -20.15 | 🔴 Crashed | ε: 0.3615
# Episode  204 | Steps: 1000 | Reward:  -53.52 | 🔵 Time Limit | ε: 0.3597
# Episode  205 | Steps:  794 | Reward: -208.01 | 🟡 Out Of Bounds | ε: 0.3579
# Episode  206 | Steps: 1000 | Reward:  -22.94 | 🔵 Time Limit | ε: 0.3561
# Episode  207 | Steps: 1000 | Reward:  -19.40 | 🔵 Time Limit | ε: 0.3543
# Episode  208 | Steps: 1000 | Reward:  -24.15 | 🔵 Time Limit | ε: 0.3525
# Episode  209 | Steps: 1000 | Reward:   -1.33 | 🔵 Time Limit | ε: 0.3508
# Episode  210 | Steps:  791 | Reward: -229.03 | 🟡 Out Of Bounds | ε: 0.3490
# Episode  211 | Steps: 1000 | Reward:  -47.07 | 🔵 Time Limit | ε: 0.3473
# Episode  212 | Steps: 1000 | Reward:   43.76 | 🔵 Time Limit | ε: 0.3455
# Episode  213 | Steps: 1000 | Reward:    9.83 | 🔵 Time Limit | ε: 0.3438
# Episode  214 | Steps: 1000 | Reward:  -30.82 | 🔵 Time Limit | ε: 0.3421
# Episode  215 | Steps: 1000 | Reward:  -40.98 | 🔵 Time Limit | ε: 0.3404
# Episode  216 | Steps: 1000 | Reward:  -19.16 | 🔵 Time Limit | ε: 0.3387
# Episode  217 | Steps:  996 | Reward: -201.19 | 🟡 Out Of Bounds | ε: 0.3370
# Episode  218 | Steps: 1000 | Reward:    9.21 | 🔵 Time Limit | ε: 0.3353
# Episode  219 | Steps: 1000 | Reward:   57.05 | 🔵 Time Limit | ε: 0.3336
# Episode  220 | Steps: 1000 | Reward:  -39.52 | 🔵 Time Limit | ε: 0.3320
#   └─ Avg Reward: -46.783 | Success: 0, Crashed: 2, Out of bounds: 3, Time limit: 15
#
# Episode  221 | Steps: 1000 | Reward:   70.03 | 🔵 Time Limit | ε: 0.3303
# Episode  222 | Steps: 1000 | Reward: -127.49 | 🔵 Time Limit | ε: 0.3286
# Episode  223 | Steps: 1000 | Reward:   18.60 | 🔵 Time Limit | ε: 0.3270
# Episode  224 | Steps: 1000 | Reward:  -39.11 | 🔵 Time Limit | ε: 0.3254
# Episode  225 | Steps:  220 | Reward:  -44.19 | 🔴 Crashed | ε: 0.3237
# Episode  226 | Steps: 1000 | Reward:  -50.01 | 🔵 Time Limit | ε: 0.3221
# Episode  227 | Steps: 1000 | Reward:  -21.59 | 🔵 Time Limit | ε: 0.3205
# Episode  228 | Steps: 1000 | Reward:  -70.80 | 🔵 Time Limit | ε: 0.3189
# Episode  229 | Steps:   93 | Reward:  -70.14 | 🔴 Crashed | ε: 0.3173
# Episode  230 | Steps: 1000 | Reward:  -30.21 | 🔵 Time Limit | ε: 0.3157
# Episode  231 | Steps: 1000 | Reward:  -41.82 | 🔵 Time Limit | ε: 0.3141
# Episode  232 | Steps:  219 | Reward:  -50.85 | 🔴 Crashed | ε: 0.3126
# Episode  233 | Steps: 1000 | Reward:   -6.17 | 🔵 Time Limit | ε: 0.3110
# Episode  234 | Steps: 1000 | Reward:    5.84 | 🔵 Time Limit | ε: 0.3095
# Episode  235 | Steps: 1000 | Reward:  -19.48 | 🔵 Time Limit | ε: 0.3079
# Episode  236 | Steps: 1000 | Reward:   13.44 | 🔵 Time Limit | ε: 0.3064
# Episode  237 | Steps: 1000 | Reward:  -34.95 | 🔵 Time Limit | ε: 0.3048
# Episode  238 | Steps: 1000 | Reward:  -18.54 | 🔵 Time Limit | ε: 0.3033
# Episode  239 | Steps: 1000 | Reward:  -15.12 | 🔵 Time Limit | ε: 0.3018
# Episode  240 | Steps: 1000 | Reward:   12.72 | 🔵 Time Limit | ε: 0.3003
#   └─ Avg Reward: -25.992 | Success: 0, Crashed: 3, Out of bounds: 0, Time limit: 17
#
# Episode  241 | Steps: 1000 | Reward:   -9.72 | 🔵 Time Limit | ε: 0.2988
# Episode  242 | Steps: 1000 | Reward:  -22.16 | 🔵 Time Limit | ε: 0.2973
# Episode  243 | Steps: 1000 | Reward:  -25.24 | 🔵 Time Limit | ε: 0.2958
# Episode  244 | Steps: 1000 | Reward:    0.79 | 🔵 Time Limit | ε: 0.2943
# Episode  245 | Steps: 1000 | Reward:    1.59 | 🔵 Time Limit | ε: 0.2929
# Episode  246 | Steps: 1000 | Reward:  -53.37 | 🔵 Time Limit | ε: 0.2914
# Episode  247 | Steps: 1000 | Reward:  -33.25 | 🔵 Time Limit | ε: 0.2899
# Episode  248 | Steps: 1000 | Reward:  -50.07 | 🔵 Time Limit | ε: 0.2885
# Episode  249 | Steps: 1000 | Reward:   -1.13 | 🔵 Time Limit | ε: 0.2870
# Episode  250 | Steps: 1000 | Reward:    5.25 | 🔵 Time Limit | ε: 0.2856
# Episode  251 | Steps: 1000 | Reward:  -73.02 | 🔵 Time Limit | ε: 0.2842
# Episode  252 | Steps: 1000 | Reward:   27.50 | 🔵 Time Limit | ε: 0.2828
# Episode  253 | Steps:  148 | Reward:   -7.18 | 🔴 Crashed | ε: 0.2813
# Episode  254 | Steps: 1000 | Reward:   48.38 | 🔵 Time Limit | ε: 0.2799
# Episode  255 | Steps: 1000 | Reward:  127.49 | 🔵 Time Limit | ε: 0.2785
# Episode  256 | Steps: 1000 | Reward:   58.96 | 🔵 Time Limit | ε: 0.2771
# Episode  257 | Steps: 1000 | Reward:   28.23 | 🔵 Time Limit | ε: 0.2758
# Episode  258 | Steps: 1000 | Reward:  -14.79 | 🔵 Time Limit | ε: 0.2744
# Episode  259 | Steps: 1000 | Reward:    3.95 | 🔵 Time Limit | ε: 0.2730
# Episode  260 | Steps: 1000 | Reward:  112.75 | 🔵 Time Limit | ε: 0.2716
#   └─ Avg Reward:   6.248 | Success: 0, Crashed: 1, Out of bounds: 0, Time limit: 19
#
# Episode  261 | Steps: 1000 | Reward:   68.37 | 🔵 Time Limit | ε: 0.2703
# Episode  262 | Steps: 1000 | Reward:  -29.27 | 🔵 Time Limit | ε: 0.2689
# Episode  263 | Steps: 1000 | Reward:    5.59 | 🔵 Time Limit | ε: 0.2676
# Episode  264 | Steps: 1000 | Reward:  125.70 | 🔵 Time Limit | ε: 0.2663
# Episode  265 | Steps: 1000 | Reward:   64.08 | 🔵 Time Limit | ε: 0.2649
# Episode  266 | Steps: 1000 | Reward:  102.68 | 🔵 Time Limit | ε: 0.2636
# Episode  267 | Steps: 1000 | Reward:   89.95 | 🔵 Time Limit | ε: 0.2623
# Episode  268 | Steps: 1000 | Reward:   15.41 | 🔵 Time Limit | ε: 0.2610
# Episode  269 | Steps: 1000 | Reward:    4.47 | 🔵 Time Limit | ε: 0.2597
# Episode  270 | Steps:  972 | Reward:  153.58 | 🟢 Landed Success | ε: 0.2584
# Episode  271 | Steps: 1000 | Reward:   11.15 | 🔵 Time Limit | ε: 0.2571
# Episode  272 | Steps: 1000 | Reward:   52.18 | 🔵 Time Limit | ε: 0.2558
# Episode  273 | Steps: 1000 | Reward:   59.17 | 🔵 Time Limit | ε: 0.2545
# Episode  274 | Steps: 1000 | Reward:  103.61 | 🔵 Time Limit | ε: 0.2532
# Episode  275 | Steps: 1000 | Reward:  141.31 | 🔵 Time Limit | ε: 0.2520
# Episode  276 | Steps: 1000 | Reward:   36.26 | 🔵 Time Limit | ε: 0.2507
# Episode  277 | Steps: 1000 | Reward:   49.56 | 🔵 Time Limit | ε: 0.2495
# Episode  278 | Steps: 1000 | Reward:   48.32 | 🔵 Time Limit | ε: 0.2482
# Episode  279 | Steps: 1000 | Reward:  109.33 | 🔵 Time Limit | ε: 0.2470
# Episode  280 | Steps: 1000 | Reward:   59.43 | 🔵 Time Limit | ε: 0.2457
#   └─ Avg Reward:  63.544 | Success: 1, Crashed: 0, Out of bounds: 0, Time limit: 19
#
# Episode  281 | Steps: 1000 | Reward:   57.24 | 🔵 Time Limit | ε: 0.2445
# Episode  282 | Steps:  369 | Reward:  -41.01 | 🔴 Crashed | ε: 0.2433
# Episode  283 | Steps:  335 | Reward:  265.68 | 🟢 Landed Success | ε: 0.2421
# Episode  284 | Steps: 1000 | Reward:   58.70 | 🔵 Time Limit | ε: 0.2409
# Episode  285 | Steps:  918 | Reward:   53.83 | 🟢 Landed Success | ε: 0.2397
# Episode  286 | Steps: 1000 | Reward:  128.98 | 🔵 Time Limit | ε: 0.2385
# Episode  287 | Steps: 1000 | Reward:  158.75 | 🔵 Time Limit | ε: 0.2373
# Episode  288 | Steps: 1000 | Reward:   73.64 | 🔵 Time Limit | ε: 0.2361
# Episode  289 | Steps:  150 | Reward:   63.94 | 🔴 Crashed | ε: 0.2349
# Episode  290 | Steps: 1000 | Reward:   41.96 | 🔵 Time Limit | ε: 0.2337
# Episode  291 | Steps: 1000 | Reward:  111.61 | 🔵 Time Limit | ε: 0.2326
# Episode  292 | Steps:  892 | Reward:  163.40 | 🟢 Landed Success | ε: 0.2314
# Episode  293 | Steps:  191 | Reward:  -48.27 | 🔴 Crashed | ε: 0.2302
# Episode  294 | Steps: 1000 | Reward:   38.34 | 🔵 Time Limit | ε: 0.2291
# Episode  295 | Steps: 1000 | Reward:  108.17 | 🔵 Time Limit | ε: 0.2279
# Episode  296 | Steps:  313 | Reward:   -9.48 | 🔴 Crashed | ε: 0.2268
# Episode  297 | Steps:  779 | Reward:  218.77 | 🟢 Landed Success | ε: 0.2257
# Episode  298 | Steps:  481 | Reward:  190.04 | 🟢 Landed Success | ε: 0.2245
# Episode  299 | Steps:  303 | Reward:  -80.49 | 🔴 Crashed | ε: 0.2234
# Episode  300 | Steps: 1000 | Reward:   48.07 | 🔵 Time Limit | ε: 0.2223
#   └─ Avg Reward:  80.094 | Success: 5, Crashed: 5, Out of bounds: 0, Time limit: 10
#
# Episode  301 | Steps:  129 | Reward:  -34.14 | 🔴 Crashed | ε: 0.2212
# Episode  302 | Steps:  130 | Reward:  -91.04 | 🔴 Crashed | ε: 0.2201
# Episode  303 | Steps:  140 | Reward:   12.14 | 🔴 Crashed | ε: 0.2190
# Episode  304 | Steps:   91 | Reward:  -63.03 | 🔴 Crashed | ε: 0.2179
# Episode  305 | Steps:  100 | Reward:    1.01 | 🔴 Crashed | ε: 0.2168
# Episode  306 | Steps:   94 | Reward:  -84.11 | 🔴 Crashed | ε: 0.2157
# Episode  307 | Steps:   85 | Reward:  -37.33 | 🔴 Crashed | ε: 0.2146
# Episode  308 | Steps:  108 | Reward:  -33.87 | 🔴 Crashed | ε: 0.2136
# Episode  309 | Steps: 1000 | Reward:   66.35 | 🔵 Time Limit | ε: 0.2125
# Episode  310 | Steps: 1000 | Reward:   -6.01 | 🔵 Time Limit | ε: 0.2114
# Episode  311 | Steps:   88 | Reward:  -82.81 | 🔴 Crashed | ε: 0.2104
# Episode  312 | Steps: 1000 | Reward:   59.82 | 🔵 Time Limit | ε: 0.2093
# Episode  313 | Steps:  965 | Reward:  164.05 | 🟢 Landed Success | ε: 0.2083
# Episode  314 | Steps:  165 | Reward:  -70.51 | 🔴 Crashed | ε: 0.2072
# Episode  315 | Steps: 1000 | Reward:   94.04 | 🔵 Time Limit | ε: 0.2062
# Episode  316 | Steps: 1000 | Reward:  -26.83 | 🔵 Time Limit | ε: 0.2052
# Episode  317 | Steps:  238 | Reward:    6.88 | 🔴 Crashed | ε: 0.2041
# Episode  318 | Steps: 1000 | Reward:   84.66 | 🔵 Time Limit | ε: 0.2031
# Episode  319 | Steps: 1000 | Reward:  -36.51 | 🔵 Time Limit | ε: 0.2021
# Episode  320 | Steps: 1000 | Reward:  -75.18 | 🔵 Time Limit | ε: 0.2011
#   └─ Avg Reward:  -7.621 | Success: 1, Crashed: 11, Out of bounds: 0, Time limit: 8
#
# Episode  321 | Steps: 1000 | Reward:  -35.15 | 🔵 Time Limit | ε: 0.2001
# Episode  322 | Steps: 1000 | Reward:  -72.01 | 🔵 Time Limit | ε: 0.1991
# Episode  323 | Steps: 1000 | Reward:  -30.28 | 🔵 Time Limit | ε: 0.1981
# Episode  324 | Steps: 1000 | Reward:   10.28 | 🔵 Time Limit | ε: 0.1971
# Episode  325 | Steps:  133 | Reward: -157.45 | 🔴 Crashed | ε: 0.1961
# Episode  326 | Steps: 1000 | Reward:  -17.14 | 🔵 Time Limit | ε: 0.1951
# Episode  327 | Steps: 1000 | Reward:    7.73 | 🔵 Time Limit | ε: 0.1942
# Episode  328 | Steps:  992 | Reward:  144.28 | 🟢 Landed Success | ε: 0.1932
# Episode  329 | Steps:  985 | Reward:  171.90 | 🟢 Landed Success | ε: 0.1922
# Episode  330 | Steps: 1000 | Reward:   47.56 | 🔵 Time Limit | ε: 0.1913
# Episode  331 | Steps:  406 | Reward:  275.93 | 🟢 Landed Success | ε: 0.1903
# Episode  332 | Steps: 1000 | Reward:   59.15 | 🔵 Time Limit | ε: 0.1893
# Episode  333 | Steps: 1000 | Reward:    8.77 | 🔵 Time Limit | ε: 0.1884
# Episode  334 | Steps: 1000 | Reward:  135.17 | 🔵 Time Limit | ε: 0.1875
# Episode  335 | Steps: 1000 | Reward:   92.61 | 🔵 Time Limit | ε: 0.1865
# Episode  336 | Steps:  695 | Reward:  224.63 | 🟢 Landed Success | ε: 0.1856
# Episode  337 | Steps:  635 | Reward:  225.80 | 🟢 Landed Success | ε: 0.1847
# Episode  338 | Steps: 1000 | Reward:   31.47 | 🔵 Time Limit | ε: 0.1837
# Episode  339 | Steps: 1000 | Reward:   31.76 | 🔵 Time Limit | ε: 0.1828
# Episode  340 | Steps: 1000 | Reward:  -10.88 | 🔵 Time Limit | ε: 0.1819
#   └─ Avg Reward:  57.207 | Success: 5, Crashed: 1, Out of bounds: 0, Time limit: 14
#
# Episode  341 | Steps:  992 | Reward:  133.33 | 🟢 Landed Success | ε: 0.1810
# Episode  342 | Steps: 1000 | Reward:  -83.88 | 🔵 Time Limit | ε: 0.1801
# Episode  343 | Steps: 1000 | Reward:   47.40 | 🔵 Time Limit | ε: 0.1792
# Episode  344 | Steps: 1000 | Reward:   41.95 | 🔵 Time Limit | ε: 0.1783
# Episode  345 | Steps:  800 | Reward:  180.03 | 🟢 Landed Success | ε: 0.1774
# Episode  346 | Steps: 1000 | Reward:   22.68 | 🔵 Time Limit | ε: 0.1765
# Episode  347 | Steps:  545 | Reward:  194.43 | 🟢 Landed Success | ε: 0.1756
# Episode  348 | Steps: 1000 | Reward:   82.21 | 🔵 Time Limit | ε: 0.1748
# Episode  349 | Steps:  282 | Reward:  252.98 | 🟢 Landed Success | ε: 0.1739
# Episode  350 | Steps:  869 | Reward:  211.41 | 🟢 Landed Success | ε: 0.1730
# Episode  351 | Steps: 1000 | Reward:    7.64 | 🔵 Time Limit | ε: 0.1721
# Episode  352 | Steps:  538 | Reward:  227.59 | 🟢 Landed Success | ε: 0.1713
# Episode  353 | Steps: 1000 | Reward:   99.55 | 🔵 Time Limit | ε: 0.1704
# Episode  354 | Steps: 1000 | Reward:    0.81 | 🔵 Time Limit | ε: 0.1696
# Episode  355 | Steps: 1000 | Reward:   62.54 | 🔵 Time Limit | ε: 0.1687
# Episode  356 | Steps: 1000 | Reward:   94.88 | 🔵 Time Limit | ε: 0.1679
# Episode  357 | Steps: 1000 | Reward:  -41.99 | 🔵 Time Limit | ε: 0.1670
# Episode  358 | Steps: 1000 | Reward:  -67.28 | 🔵 Time Limit | ε: 0.1662
# Episode  359 | Steps: 1000 | Reward:  -50.02 | 🔵 Time Limit | ε: 0.1654
# Episode  360 | Steps: 1000 | Reward:   -7.91 | 🔵 Time Limit | ε: 0.1646
#   └─ Avg Reward:  70.418 | Success: 6, Crashed: 0, Out of bounds: 0, Time limit: 14
#
# Episode  361 | Steps: 1000 | Reward:  -79.38 | 🔵 Time Limit | ε: 0.1637
# Episode  362 | Steps: 1000 | Reward:  -46.61 | 🔵 Time Limit | ε: 0.1629
# Episode  363 | Steps:  727 | Reward:  214.09 | 🟢 Landed Success | ε: 0.1621
# Episode  364 | Steps: 1000 | Reward:   17.04 | 🔵 Time Limit | ε: 0.1613
# Episode  365 | Steps:  691 | Reward:  194.43 | 🟢 Landed Success | ε: 0.1605
# Episode  366 | Steps:  874 | Reward:  175.61 | 🟢 Landed Success | ε: 0.1597
# Episode  367 | Steps: 1000 | Reward:  -18.16 | 🔵 Time Limit | ε: 0.1589
# Episode  368 | Steps:  836 | Reward:  182.05 | 🟢 Landed Success | ε: 0.1581
# Episode  369 | Steps: 1000 | Reward:  -48.96 | 🔵 Time Limit | ε: 0.1573
# Episode  370 | Steps: 1000 | Reward:   69.15 | 🔵 Time Limit | ε: 0.1565
# Episode  371 | Steps:  399 | Reward:  -29.19 | 🔴 Crashed | ε: 0.1557
# Episode  372 | Steps: 1000 | Reward:   96.78 | 🔵 Time Limit | ε: 0.1549
# Episode  373 | Steps: 1000 | Reward:   65.38 | 🔵 Time Limit | ε: 0.1542
# Episode  374 | Steps: 1000 | Reward:   52.60 | 🔵 Time Limit | ε: 0.1534
# Episode  375 | Steps: 1000 | Reward:   54.00 | 🔵 Time Limit | ε: 0.1526
# Episode  376 | Steps: 1000 | Reward:   56.90 | 🔵 Time Limit | ε: 0.1519
# Episode  377 | Steps:  852 | Reward:  252.21 | 🟢 Landed Success | ε: 0.1511
# Episode  378 | Steps:  814 | Reward:  193.76 | 🟢 Landed Success | ε: 0.1504
# Episode  379 | Steps:  651 | Reward:  237.51 | 🟢 Landed Success | ε: 0.1496
# Episode  380 | Steps:  452 | Reward:  227.02 | 🟢 Landed Success | ε: 0.1489
#   └─ Avg Reward:  93.310 | Success: 8, Crashed: 1, Out of bounds: 0, Time limit: 11
#
# Episode  381 | Steps:  693 | Reward:  199.37 | 🟢 Landed Success | ε: 0.1481
# Episode  382 | Steps: 1000 | Reward:  101.33 | 🔵 Time Limit | ε: 0.1474
# Episode  383 | Steps:  557 | Reward:  208.83 | 🟢 Landed Success | ε: 0.1466
# Episode  384 | Steps:  410 | Reward:  299.70 | 🟢 Landed Success | ε: 0.1459
# Episode  385 | Steps:  631 | Reward:  243.73 | 🟢 Landed Success | ε: 0.1452
# Episode  386 | Steps:  132 | Reward:  -33.56 | 🔴 Crashed | ε: 0.1444
# Episode  387 | Steps:  436 | Reward:  269.03 | 🟢 Landed Success | ε: 0.1437
# Episode  388 | Steps:  514 | Reward:  257.76 | 🟢 Landed Success | ε: 0.1430
# Episode  389 | Steps:  869 | Reward:  189.06 | 🟢 Landed Success | ε: 0.1423
# Episode  390 | Steps: 1000 | Reward:   83.29 | 🔵 Time Limit | ε: 0.1416
# Episode  391 | Steps: 1000 | Reward:  120.87 | 🔵 Time Limit | ε: 0.1409
# Episode  392 | Steps:  527 | Reward:  229.76 | 🟢 Landed Success | ε: 0.1402
# Episode  393 | Steps:  705 | Reward:  185.49 | 🟢 Landed Success | ε: 0.1395
# Episode  394 | Steps:  317 | Reward:  264.74 | 🟢 Landed Success | ε: 0.1388
# Episode  395 | Steps:  761 | Reward:  198.78 | 🟢 Landed Success | ε: 0.1381
# Episode  396 | Steps:  365 | Reward:  190.35 | 🟢 Landed Success | ε: 0.1374
# Episode  397 | Steps:  105 | Reward:    9.89 | 🔴 Crashed | ε: 0.1367
# Episode  398 | Steps:  652 | Reward:  203.47 | 🟢 Landed Success | ε: 0.1360
# Episode  399 | Steps: 1000 | Reward:    0.16 | 🔵 Time Limit | ε: 0.1353
# Episode  400 | Steps:  880 | Reward:  190.86 | 🟢 Landed Success | ε: 0.1347
#   └─ Avg Reward: 170.645 | Success: 14, Crashed: 2, Out of bounds: 0, Time limit: 4
#
# Episode  401 | Steps:  452 | Reward:  202.63 | 🟢 Landed Success | ε: 0.1340
# Episode  402 | Steps: 1000 | Reward:   42.40 | 🔵 Time Limit | ε: 0.1333
# Episode  403 | Steps: 1000 | Reward:   64.89 | 🔵 Time Limit | ε: 0.1326
# Episode  404 | Steps:  474 | Reward:  277.70 | 🟢 Landed Success | ε: 0.1320
# Episode  405 | Steps:  493 | Reward:  162.30 | 🟢 Landed Success | ε: 0.1313
# Episode  406 | Steps:  626 | Reward:  193.67 | 🟢 Landed Success | ε: 0.1307
# Episode  407 | Steps:  705 | Reward:  199.52 | 🟢 Landed Success | ε: 0.1300
# Episode  408 | Steps:  695 | Reward:  211.66 | 🟢 Landed Success | ε: 0.1294
# Episode  409 | Steps: 1000 | Reward:  105.66 | 🔵 Time Limit | ε: 0.1287
# Episode  410 | Steps: 1000 | Reward:   73.78 | 🔵 Time Limit | ε: 0.1281
# Episode  411 | Steps:  881 | Reward:  199.69 | 🟢 Landed Success | ε: 0.1274
# Episode  412 | Steps:  426 | Reward:  207.02 | 🟢 Landed Success | ε: 0.1268
# Episode  413 | Steps:  435 | Reward:  242.44 | 🟢 Landed Success | ε: 0.1262
# Episode  414 | Steps:  549 | Reward:  160.43 | 🟢 Landed Success | ε: 0.1255
# Episode  415 | Steps:  529 | Reward:  245.88 | 🟢 Landed Success | ε: 0.1249
# Episode  416 | Steps: 1000 | Reward:  128.40 | 🔵 Time Limit | ε: 0.1243
# Episode  417 | Steps:  679 | Reward:  203.23 | 🟢 Landed Success | ε: 0.1237
# Episode  418 | Steps:  570 | Reward:  175.54 | 🟢 Landed Success | ε: 0.1230
# Episode  419 | Steps:  723 | Reward:  223.89 | 🟢 Landed Success | ε: 0.1224
# Episode  420 | Steps:  597 | Reward:  227.52 | 🟢 Landed Success | ε: 0.1218
#   └─ Avg Reward: 177.412 | Success: 15, Crashed: 0, Out of bounds: 0, Time limit: 5
#
# Episode  421 | Steps:  460 | Reward:  262.01 | 🟢 Landed Success | ε: 0.1212
# Episode  422 | Steps: 1000 | Reward:   27.72 | 🔵 Time Limit | ε: 0.1206
# Episode  423 | Steps:  496 | Reward:  195.99 | 🟢 Landed Success | ε: 0.1200
# Episode  424 | Steps:  504 | Reward:  233.56 | 🟢 Landed Success | ε: 0.1194
# Episode  425 | Steps:  459 | Reward:  213.06 | 🟢 Landed Success | ε: 0.1188
# Episode  426 | Steps:  920 | Reward:  165.86 | 🟢 Landed Success | ε: 0.1182
# Episode  427 | Steps:  360 | Reward:  213.98 | 🟢 Landed Success | ε: 0.1176
# Episode  428 | Steps:  356 | Reward: -147.62 | 🟡 Out Of Bounds | ε: 0.1170
# Episode  429 | Steps:  384 | Reward:  278.72 | 🟢 Landed Success | ε: 0.1164
# Episode  430 | Steps:  806 | Reward:  200.89 | 🟢 Landed Success | ε: 0.1159
# Episode  431 | Steps:  543 | Reward:  234.25 | 🟢 Landed Success | ε: 0.1153
# Episode  432 | Steps:  732 | Reward:  227.55 | 🟢 Landed Success | ε: 0.1147
# Episode  433 | Steps:  433 | Reward:  266.02 | 🟢 Landed Success | ε: 0.1141
# Episode  434 | Steps:  462 | Reward:  237.83 | 🟢 Landed Success | ε: 0.1136
# Episode  435 | Steps:  402 | Reward:  249.59 | 🟢 Landed Success | ε: 0.1130
# Episode  436 | Steps:  512 | Reward:  229.78 | 🟢 Landed Success | ε: 0.1124
# Episode  437 | Steps:  706 | Reward:  183.67 | 🟢 Landed Success | ε: 0.1119
# Episode  438 | Steps:  603 | Reward:  206.41 | 🟢 Landed Success | ε: 0.1113
# Episode  439 | Steps:  455 | Reward:  214.33 | 🟢 Landed Success | ε: 0.1107
# Episode  440 | Steps:  368 | Reward:  246.11 | 🟢 Landed Success | ε: 0.1102
#   └─ Avg Reward: 196.986 | Success: 18, Crashed: 0, Out of bounds: 1, Time limit: 1
#
# Episode  441 | Steps:  367 | Reward:  252.99 | 🟢 Landed Success | ε: 0.1096
# Episode  442 | Steps:  705 | Reward:  225.96 | 🟢 Landed Success | ε: 0.1091
# Episode  443 | Steps:  379 | Reward:  214.47 | 🟢 Landed Success | ε: 0.1085
# Episode  444 | Steps:  277 | Reward:  167.74 | 🟢 Landed Success | ε: 0.1080
# Episode  445 | Steps:  468 | Reward:  230.14 | 🟢 Landed Success | ε: 0.1075
# Episode  446 | Steps:  595 | Reward:  266.03 | 🟢 Landed Success | ε: 0.1069
# Episode  447 | Steps:  367 | Reward:  298.44 | 🟢 Landed Success | ε: 0.1064
# Episode  448 | Steps:  390 | Reward:  226.02 | 🟢 Landed Success | ε: 0.1059
# Episode  449 | Steps:  586 | Reward:  226.42 | 🟢 Landed Success | ε: 0.1053
# Episode  450 | Steps:  431 | Reward:  173.52 | 🟢 Landed Success | ε: 0.1048
# Episode  451 | Steps: 1000 | Reward:   47.82 | 🔵 Time Limit | ε: 0.1043
# Episode  452 | Steps: 1000 | Reward:   87.77 | 🔵 Time Limit | ε: 0.1038
# Episode  453 | Steps:  458 | Reward:  167.62 | 🟢 Landed Success | ε: 0.1032
# Episode  454 | Steps:  525 | Reward:  188.86 | 🟢 Landed Success | ε: 0.1027
# Episode  455 | Steps:  401 | Reward:  204.11 | 🟢 Landed Success | ε: 0.1022
# Episode  456 | Steps:  474 | Reward:  184.93 | 🟢 Landed Success | ε: 0.1017
# Episode  457 | Steps:  495 | Reward:  206.81 | 🟢 Landed Success | ε: 0.1012
# Episode  458 | Steps:  702 | Reward:  154.54 | 🟢 Landed Success | ε: 0.1007
# Episode  459 | Steps:  613 | Reward:  216.07 | 🟢 Landed Success | ε: 0.1002
# Episode  460 | Steps:  604 | Reward:  196.27 | 🟢 Landed Success | ε: 0.0997
#   └─ Avg Reward: 196.826 | Success: 18, Crashed: 0, Out of bounds: 0, Time limit: 2
#
# Episode  461 | Steps:  345 | Reward:  283.04 | 🟢 Landed Success | ε: 0.0992
# Episode  462 | Steps:  499 | Reward:  240.09 | 🟢 Landed Success | ε: 0.0987
# Episode  463 | Steps:  641 | Reward:  189.76 | 🟢 Landed Success | ε: 0.0982
# Episode  464 | Steps:  686 | Reward:  232.84 | 🟢 Landed Success | ε: 0.0977
# Episode  465 | Steps:  515 | Reward:  198.69 | 🟢 Landed Success | ε: 0.0972
# Episode  466 | Steps:  503 | Reward:  228.90 | 🟢 Landed Success | ε: 0.0967
# Episode  467 | Steps:  465 | Reward:  215.48 | 🟢 Landed Success | ε: 0.0962
# Episode  468 | Steps:  446 | Reward:  247.42 | 🟢 Landed Success | ε: 0.0958
# Episode  469 | Steps:  579 | Reward:  234.42 | 🟢 Landed Success | ε: 0.0953
# Episode  470 | Steps:  474 | Reward:  196.48 | 🟢 Landed Success | ε: 0.0948
# Episode  471 | Steps:  522 | Reward:  246.73 | 🟢 Landed Success | ε: 0.0943
# Episode  472 | Steps:  459 | Reward:  229.84 | 🟢 Landed Success | ε: 0.0939
# Episode  473 | Steps:  506 | Reward:  253.69 | 🟢 Landed Success | ε: 0.0934
# Episode  474 | Steps:  326 | Reward:  268.07 | 🟢 Landed Success | ε: 0.0929
# Episode  475 | Steps:  512 | Reward:  245.51 | 🟢 Landed Success | ε: 0.0925
# Episode  476 | Steps:  346 | Reward:  213.53 | 🟢 Landed Success | ε: 0.0920
# Episode  477 | Steps:  774 | Reward: -148.74 | 🟡 Out Of Bounds | ε: 0.0915
# Episode  478 | Steps:  424 | Reward:  230.82 | 🟢 Landed Success | ε: 0.0911
# Episode  479 | Steps:  389 | Reward:  241.04 | 🟢 Landed Success | ε: 0.0906
# Episode  480 | Steps:  718 | Reward:  208.88 | 🟢 Landed Success | ε: 0.0902
#   └─ Avg Reward: 212.824 | Success: 19, Crashed: 0, Out of bounds: 1, Time limit: 0
#
# Episode  481 | Steps:  469 | Reward:  242.66 | 🟢 Landed Success | ε: 0.0897
# Episode  482 | Steps:  844 | Reward:  199.04 | 🟢 Landed Success | ε: 0.0893
# Episode  483 | Steps:  423 | Reward:  214.66 | 🟢 Landed Success | ε: 0.0888
# Episode  484 | Steps:  489 | Reward:  280.22 | 🟢 Landed Success | ε: 0.0884
# Episode  485 | Steps:  382 | Reward:  203.02 | 🟢 Landed Success | ε: 0.0879
# Episode  486 | Steps:  491 | Reward:  214.42 | 🟢 Landed Success | ε: 0.0875
# Episode  487 | Steps:  325 | Reward:  249.49 | 🟢 Landed Success | ε: 0.0871
# Episode  488 | Steps:  552 | Reward:  193.72 | 🟢 Landed Success | ε: 0.0866
# Episode  489 | Steps:  367 | Reward:  242.96 | 🟢 Landed Success | ε: 0.0862
# Episode  490 | Steps:  693 | Reward:  259.85 | 🟢 Landed Success | ε: 0.0858
# Episode  491 | Steps:  159 | Reward:   -9.94 | 🔴 Crashed | ε: 0.0853
# Episode  492 | Steps:  402 | Reward:  234.63 | 🟢 Landed Success | ε: 0.0849
# Episode  493 | Steps:  395 | Reward:  261.46 | 🟢 Landed Success | ε: 0.0845
# Episode  494 | Steps:  533 | Reward:  240.47 | 🟢 Landed Success | ε: 0.0841
# Episode  495 | Steps:  423 | Reward:  229.21 | 🟢 Landed Success | ε: 0.0836
# Episode  496 | Steps:  381 | Reward:  261.79 | 🟢 Landed Success | ε: 0.0832
# Episode  497 | Steps:  439 | Reward:  146.01 | 🟢 Landed Success | ε: 0.0828
# Episode  498 | Steps:  373 | Reward:  246.01 | 🟢 Landed Success | ε: 0.0824
# Episode  499 | Steps:  345 | Reward:  244.53 | 🟢 Landed Success | ε: 0.0820
# Episode  500 | Steps:  409 | Reward:  248.19 | 🟢 Landed Success | ε: 0.0816
#   └─ Avg Reward: 220.119 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  501 | Steps:  379 | Reward:  271.03 | 🟢 Landed Success | ε: 0.0812
# Episode  502 | Steps:  869 | Reward:  199.24 | 🟢 Landed Success | ε: 0.0808
# Episode  503 | Steps:  438 | Reward:  224.84 | 🟢 Landed Success | ε: 0.0804
# Episode  504 | Steps:  358 | Reward:  248.96 | 🟢 Landed Success | ε: 0.0800
# Episode  505 | Steps:  475 | Reward:  249.79 | 🟢 Landed Success | ε: 0.0796
# Episode  506 | Steps:  461 | Reward:  235.05 | 🟢 Landed Success | ε: 0.0792
# Episode  507 | Steps:  472 | Reward:  242.17 | 🟢 Landed Success | ε: 0.0788
# Episode  508 | Steps:  358 | Reward:  226.84 | 🟢 Landed Success | ε: 0.0784
# Episode  509 | Steps:  527 | Reward:  224.00 | 🟢 Landed Success | ε: 0.0780
# Episode  510 | Steps:  458 | Reward:  228.32 | 🟢 Landed Success | ε: 0.0776
# Episode  511 | Steps:  367 | Reward:  227.64 | 🟢 Landed Success | ε: 0.0772
# Episode  512 | Steps:  417 | Reward:  229.03 | 🟢 Landed Success | ε: 0.0768
# Episode  513 | Steps:  382 | Reward:  239.45 | 🟢 Landed Success | ε: 0.0764
# Episode  514 | Steps:  394 | Reward:  246.57 | 🟢 Landed Success | ε: 0.0760
# Episode  515 | Steps:  456 | Reward:  233.65 | 🟢 Landed Success | ε: 0.0757
# Episode  516 | Steps:  360 | Reward:  253.60 | 🟢 Landed Success | ε: 0.0753
# Episode  517 | Steps:  387 | Reward:  261.49 | 🟢 Landed Success | ε: 0.0749
# Episode  518 | Steps:  424 | Reward:  241.59 | 🟢 Landed Success | ε: 0.0745
# Episode  519 | Steps:  373 | Reward:  211.81 | 🟢 Landed Success | ε: 0.0742
# Episode  520 | Steps:  141 | Reward:   15.55 | 🔴 Crashed | ε: 0.0738
#   └─ Avg Reward: 225.531 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  521 | Steps:  349 | Reward:  228.29 | 🟢 Landed Success | ε: 0.0734
# Episode  522 | Steps:  315 | Reward:  228.86 | 🟢 Landed Success | ε: 0.0731
# Episode  523 | Steps:  386 | Reward:  213.98 | 🟢 Landed Success | ε: 0.0727
# Episode  524 | Steps:  668 | Reward:  197.43 | 🟢 Landed Success | ε: 0.0723
# Episode  525 | Steps:  422 | Reward:  197.87 | 🟢 Landed Success | ε: 0.0720
# Episode  526 | Steps:  337 | Reward:  284.32 | 🟢 Landed Success | ε: 0.0716
# Episode  527 | Steps:  402 | Reward:  230.54 | 🟢 Landed Success | ε: 0.0712
# Episode  528 | Steps:  397 | Reward:  254.72 | 🟢 Landed Success | ε: 0.0709
# Episode  529 | Steps:  354 | Reward:  228.74 | 🟢 Landed Success | ε: 0.0705
# Episode  530 | Steps:  357 | Reward:  244.67 | 🟢 Landed Success | ε: 0.0702
# Episode  531 | Steps:  144 | Reward:  -97.16 | 🔴 Crashed | ε: 0.0698
# Episode  532 | Steps:  700 | Reward:  218.37 | 🟢 Landed Success | ε: 0.0695
# Episode  533 | Steps:  631 | Reward:  197.08 | 🟢 Landed Success | ε: 0.0691
# Episode  534 | Steps:  417 | Reward:  217.49 | 🟢 Landed Success | ε: 0.0688
# Episode  535 | Steps:  389 | Reward:  218.63 | 🟢 Landed Success | ε: 0.0684
# Episode  536 | Steps:  470 | Reward:  235.94 | 🟢 Landed Success | ε: 0.0681
# Episode  537 | Steps:  357 | Reward:  272.36 | 🟢 Landed Success | ε: 0.0678
# Episode  538 | Steps:  391 | Reward:  242.74 | 🟢 Landed Success | ε: 0.0674
# Episode  539 | Steps:  394 | Reward:  219.30 | 🟢 Landed Success | ε: 0.0671
# Episode  540 | Steps:  362 | Reward:  243.27 | 🟢 Landed Success | ε: 0.0668
#   └─ Avg Reward: 213.872 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  541 | Steps:  399 | Reward:  210.71 | 🟢 Landed Success | ε: 0.0664
# Episode  542 | Steps:  379 | Reward:  227.21 | 🟢 Landed Success | ε: 0.0661
# Episode  543 | Steps:  536 | Reward:  252.11 | 🟢 Landed Success | ε: 0.0658
# Episode  544 | Steps:  198 | Reward: -165.20 | 🔴 Crashed | ε: 0.0654
# Episode  545 | Steps:  430 | Reward:  217.14 | 🟢 Landed Success | ε: 0.0651
# Episode  546 | Steps:  541 | Reward:  203.58 | 🟢 Landed Success | ε: 0.0648
# Episode  547 | Steps: 1000 | Reward:   68.73 | 🔵 Time Limit | ε: 0.0645
# Episode  548 | Steps:  678 | Reward:  248.96 | 🟢 Landed Success | ε: 0.0641
# Episode  549 | Steps:  523 | Reward:  291.90 | 🟢 Landed Success | ε: 0.0638
# Episode  550 | Steps:  355 | Reward:  265.38 | 🟢 Landed Success | ε: 0.0635
# Episode  551 | Steps:  525 | Reward:  196.14 | 🟢 Landed Success | ε: 0.0632
# Episode  552 | Steps:  471 | Reward:  248.83 | 🟢 Landed Success | ε: 0.0629
# Episode  553 | Steps:  362 | Reward:  224.53 | 🟢 Landed Success | ε: 0.0625
# Episode  554 | Steps:  479 | Reward:  201.23 | 🟢 Landed Success | ε: 0.0622
# Episode  555 | Steps:  597 | Reward:  175.94 | 🟢 Landed Success | ε: 0.0619
# Episode  556 | Steps:  344 | Reward:  233.28 | 🟢 Landed Success | ε: 0.0616
# Episode  557 | Steps:  485 | Reward:  161.35 | 🟢 Landed Success | ε: 0.0613
# Episode  558 | Steps:  346 | Reward:  245.89 | 🟢 Landed Success | ε: 0.0610
# Episode  559 | Steps:  305 | Reward:  243.72 | 🟢 Landed Success | ε: 0.0607
# Episode  560 | Steps:  395 | Reward:  247.23 | 🟢 Landed Success | ε: 0.0604
#   └─ Avg Reward: 199.933 | Success: 18, Crashed: 1, Out of bounds: 0, Time limit: 1
#
# Episode  561 | Steps:  314 | Reward:  230.99 | 🟢 Landed Success | ε: 0.0601
# Episode  562 | Steps:  499 | Reward:  230.02 | 🟢 Landed Success | ε: 0.0598
# Episode  563 | Steps:  305 | Reward:  217.69 | 🟢 Landed Success | ε: 0.0595
# Episode  564 | Steps:  386 | Reward:  234.25 | 🟢 Landed Success | ε: 0.0592
# Episode  565 | Steps:  366 | Reward:  230.87 | 🟢 Landed Success | ε: 0.0589
# Episode  566 | Steps:  479 | Reward:  263.39 | 🟢 Landed Success | ε: 0.0586
# Episode  567 | Steps:  420 | Reward:  274.29 | 🟢 Landed Success | ε: 0.0583
# Episode  568 | Steps:  397 | Reward:  200.08 | 🟢 Landed Success | ε: 0.0580
# Episode  569 | Steps:  377 | Reward:  256.59 | 🟢 Landed Success | ε: 0.0577
# Episode  570 | Steps:  380 | Reward:  218.82 | 🟢 Landed Success | ε: 0.0574
# Episode  571 | Steps:  382 | Reward:  261.01 | 🟢 Landed Success | ε: 0.0571
# Episode  572 | Steps:  340 | Reward:  197.28 | 🟢 Landed Success | ε: 0.0569
# Episode  573 | Steps:   82 | Reward: -193.32 | 🔴 Crashed | ε: 0.0566
# Episode  574 | Steps:  472 | Reward:  254.04 | 🟢 Landed Success | ε: 0.0563
# Episode  575 | Steps:  444 | Reward:  218.21 | 🟢 Landed Success | ε: 0.0560
# Episode  576 | Steps:  436 | Reward:  212.69 | 🟢 Landed Success | ε: 0.0557
# Episode  577 | Steps:  293 | Reward:  282.03 | 🟢 Landed Success | ε: 0.0555
# Episode  578 | Steps:  482 | Reward:  232.75 | 🟢 Landed Success | ε: 0.0552
# Episode  579 | Steps:  479 | Reward:  233.10 | 🟢 Landed Success | ε: 0.0549
# Episode  580 | Steps:  371 | Reward:  213.68 | 🟢 Landed Success | ε: 0.0546
#   └─ Avg Reward: 213.423 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  581 | Steps:  545 | Reward:  186.15 | 🟢 Landed Success | ε: 0.0544
# Episode  582 | Steps:  462 | Reward:  207.78 | 🟢 Landed Success | ε: 0.0541
# Episode  583 | Steps:  483 | Reward:  256.32 | 🟢 Landed Success | ε: 0.0538
# Episode  584 | Steps:  520 | Reward:  275.34 | 🟢 Landed Success | ε: 0.0535
# Episode  585 | Steps:  339 | Reward:  254.67 | 🟢 Landed Success | ε: 0.0533
# Episode  586 | Steps:  543 | Reward:  221.95 | 🟢 Landed Success | ε: 0.0530
# Episode  587 | Steps:  346 | Reward:  224.69 | 🟢 Landed Success | ε: 0.0527
# Episode  588 | Steps:  462 | Reward:  244.72 | 🟢 Landed Success | ε: 0.0525
# Episode  589 | Steps:  385 | Reward:  221.39 | 🟢 Landed Success | ε: 0.0522
# Episode  590 | Steps:  382 | Reward:  279.83 | 🟢 Landed Success | ε: 0.0520
# Episode  591 | Steps:  386 | Reward:  242.16 | 🟢 Landed Success | ε: 0.0517
# Episode  592 | Steps:  430 | Reward:  193.40 | 🟢 Landed Success | ε: 0.0514
# Episode  593 | Steps:  310 | Reward:  233.99 | 🟢 Landed Success | ε: 0.0512
# Episode  594 | Steps:  232 | Reward:  172.93 | 🟢 Landed Success | ε: 0.0509
# Episode  595 | Steps:  258 | Reward:  244.88 | 🟢 Landed Success | ε: 0.0507
# Episode  596 | Steps:  335 | Reward:  189.04 | 🟢 Landed Success | ε: 0.0504
# Episode  597 | Steps:  324 | Reward:  246.03 | 🟢 Landed Success | ε: 0.0502
# Episode  598 | Steps:  716 | Reward:  243.89 | 🟢 Landed Success | ε: 0.0499
# Episode  599 | Steps:  418 | Reward:  267.24 | 🟢 Landed Success | ε: 0.0497
# Episode  600 | Steps:  289 | Reward:  204.25 | 🟢 Landed Success | ε: 0.0494
#   └─ Avg Reward: 230.532 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  601 | Steps:  405 | Reward:  238.03 | 🟢 Landed Success | ε: 0.0492
# Episode  602 | Steps:  354 | Reward:  235.43 | 🟢 Landed Success | ε: 0.0489
# Episode  603 | Steps:  369 | Reward:  222.74 | 🟢 Landed Success | ε: 0.0487
# Episode  604 | Steps:  459 | Reward:  267.62 | 🟢 Landed Success | ε: 0.0484
# Episode  605 | Steps:  330 | Reward:  277.35 | 🟢 Landed Success | ε: 0.0482
# Episode  606 | Steps:  321 | Reward:  225.72 | 🟢 Landed Success | ε: 0.0479
# Episode  607 | Steps:  385 | Reward:  237.33 | 🟢 Landed Success | ε: 0.0477
# Episode  608 | Steps:  532 | Reward:  200.00 | 🟢 Landed Success | ε: 0.0475
# Episode  609 | Steps:  452 | Reward:  244.13 | 🟢 Landed Success | ε: 0.0472
# Episode  610 | Steps:  431 | Reward:  218.12 | 🟢 Landed Success | ε: 0.0470
# Episode  611 | Steps:  298 | Reward:  291.52 | 🟢 Landed Success | ε: 0.0468
# Episode  612 | Steps:  298 | Reward:  259.61 | 🟢 Landed Success | ε: 0.0465
# Episode  613 | Steps:  380 | Reward:  230.23 | 🟢 Landed Success | ε: 0.0463
# Episode  614 | Steps:  456 | Reward:  270.78 | 🟢 Landed Success | ε: 0.0461
# Episode  615 | Steps:  546 | Reward:  249.59 | 🟢 Landed Success | ε: 0.0458
# Episode  616 | Steps:  337 | Reward:  245.62 | 🟢 Landed Success | ε: 0.0456
# Episode  617 | Steps:  475 | Reward:  226.44 | 🟢 Landed Success | ε: 0.0454
# Episode  618 | Steps:  419 | Reward:  256.02 | 🟢 Landed Success | ε: 0.0452
# Episode  619 | Steps:  265 | Reward:  245.77 | 🟢 Landed Success | ε: 0.0449
# Episode  620 | Steps:  429 | Reward:  272.87 | 🟢 Landed Success | ε: 0.0447
#   └─ Avg Reward: 245.747 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  621 | Steps:  315 | Reward:  240.58 | 🟢 Landed Success | ε: 0.0445
# Episode  622 | Steps:  252 | Reward:  272.49 | 🟢 Landed Success | ε: 0.0443
# Episode  623 | Steps:  639 | Reward:  285.65 | 🟢 Landed Success | ε: 0.0440
# Episode  624 | Steps:  313 | Reward:  263.73 | 🟢 Landed Success | ε: 0.0438
# Episode  625 | Steps:  279 | Reward:  239.75 | 🟢 Landed Success | ε: 0.0436
# Episode  626 | Steps:  308 | Reward:  237.19 | 🟢 Landed Success | ε: 0.0434
# Episode  627 | Steps:  304 | Reward:  260.20 | 🟢 Landed Success | ε: 0.0432
# Episode  628 | Steps:  315 | Reward:  293.44 | 🟢 Landed Success | ε: 0.0429
# Episode  629 | Steps:  317 | Reward:  246.83 | 🟢 Landed Success | ε: 0.0427
# Episode  630 | Steps:  398 | Reward:  221.71 | 🟢 Landed Success | ε: 0.0425
# Episode  631 | Steps:  608 | Reward:  224.80 | 🟢 Landed Success | ε: 0.0423
# Episode  632 | Steps:  342 | Reward:  210.67 | 🟢 Landed Success | ε: 0.0421
# Episode  633 | Steps:  564 | Reward:  200.13 | 🟢 Landed Success | ε: 0.0419
# Episode  634 | Steps:  277 | Reward:  239.18 | 🟢 Landed Success | ε: 0.0417
# Episode  635 | Steps:  392 | Reward:  235.03 | 🟢 Landed Success | ε: 0.0415
# Episode  636 | Steps:  223 | Reward:   30.17 | 🔴 Crashed | ε: 0.0413
# Episode  637 | Steps:  403 | Reward:  267.43 | 🟢 Landed Success | ε: 0.0410
# Episode  638 | Steps:  256 | Reward:  235.35 | 🟢 Landed Success | ε: 0.0408
# Episode  639 | Steps:  286 | Reward:  230.48 | 🟢 Landed Success | ε: 0.0406
# Episode  640 | Steps:  468 | Reward:  251.97 | 🟢 Landed Success | ε: 0.0404
#   └─ Avg Reward: 234.340 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# Episode  641 | Steps:  211 | Reward:   17.87 | 🔴 Crashed | ε: 0.0402
# Episode  642 | Steps:  351 | Reward:  246.01 | 🟢 Landed Success | ε: 0.0400
# Episode  643 | Steps:  265 | Reward:  278.60 | 🟢 Landed Success | ε: 0.0398
# Episode  644 | Steps:  356 | Reward:  281.33 | 🟢 Landed Success | ε: 0.0396
# Episode  645 | Steps:  265 | Reward:  262.61 | 🟢 Landed Success | ε: 0.0394
# Episode  646 | Steps:  295 | Reward:  232.22 | 🟢 Landed Success | ε: 0.0392
# Episode  647 | Steps:  404 | Reward:  240.78 | 🟢 Landed Success | ε: 0.0390
# Episode  648 | Steps:  419 | Reward:  245.64 | 🟢 Landed Success | ε: 0.0388
# Episode  649 | Steps:  125 | Reward:   10.72 | 🔴 Crashed | ε: 0.0387
# Episode  650 | Steps:  382 | Reward:  291.76 | 🟢 Landed Success | ε: 0.0385
# Episode  651 | Steps:  246 | Reward:  267.72 | 🟢 Landed Success | ε: 0.0383
# Episode  652 | Steps:  335 | Reward:  279.40 | 🟢 Landed Success | ε: 0.0381
# Episode  653 | Steps:  380 | Reward:  241.07 | 🟢 Landed Success | ε: 0.0379
# Episode  654 | Steps:  593 | Reward:  209.87 | 🟢 Landed Success | ε: 0.0377
# Episode  655 | Steps:  285 | Reward:  278.64 | 🟢 Landed Success | ε: 0.0375
# Episode  656 | Steps:  244 | Reward:  263.79 | 🟢 Landed Success | ε: 0.0373
# Episode  657 | Steps:  205 | Reward:  275.89 | 🟢 Landed Success | ε: 0.0371
# Episode  658 | Steps:  262 | Reward:  212.27 | 🟢 Landed Success | ε: 0.0369
# Episode  659 | Steps:  372 | Reward:  265.64 | 🟢 Landed Success | ε: 0.0368
# Episode  660 | Steps:  297 | Reward:  271.67 | 🟢 Landed Success | ε: 0.0366
#   └─ Avg Reward: 233.676 | Success: 18, Crashed: 2, Out of bounds: 0, Time limit: 0
#
# Episode  661 | Steps:  286 | Reward:  303.43 | 🟢 Landed Success | ε: 0.0364
# Episode  662 | Steps:  349 | Reward:  263.40 | 🟢 Landed Success | ε: 0.0362
# Episode  663 | Steps:  346 | Reward:  246.75 | 🟢 Landed Success | ε: 0.0360
# Episode  664 | Steps:  273 | Reward:  252.08 | 🟢 Landed Success | ε: 0.0359
# Episode  665 | Steps:  269 | Reward:  277.36 | 🟢 Landed Success | ε: 0.0357
# Episode  666 | Steps:  312 | Reward:  273.23 | 🟢 Landed Success | ε: 0.0355
# Episode  667 | Steps:  339 | Reward:  271.27 | 🟢 Landed Success | ε: 0.0353
# Episode  668 | Steps:  215 | Reward:  258.27 | 🟢 Landed Success | ε: 0.0351
# Episode  669 | Steps:  194 | Reward:   21.01 | 🔴 Crashed | ε: 0.0350
# Episode  670 | Steps:  361 | Reward:  238.18 | 🟢 Landed Success | ε: 0.0348
# Episode  671 | Steps:  447 | Reward:  265.03 | 🟢 Landed Success | ε: 0.0346
# Episode  672 | Steps:  488 | Reward:  217.43 | 🟢 Landed Success | ε: 0.0344
# Episode  673 | Steps:  133 | Reward:   -6.63 | 🔴 Crashed | ε: 0.0343
# Episode  674 | Steps:  319 | Reward:  246.90 | 🟢 Landed Success | ε: 0.0341
# Episode  675 | Steps:  338 | Reward:  231.57 | 🟢 Landed Success | ε: 0.0339
# Episode  676 | Steps:  357 | Reward:  289.72 | 🟢 Landed Success | ε: 0.0338
# Episode  677 | Steps:  310 | Reward:  277.92 | 🟢 Landed Success | ε: 0.0336
# Episode  678 | Steps:  741 | Reward:  229.24 | 🟢 Landed Success | ε: 0.0334
# Episode  679 | Steps:  374 | Reward:  236.57 | 🟢 Landed Success | ε: 0.0333
# Episode  680 | Steps:  640 | Reward:  201.47 | 🟢 Landed Success | ε: 0.0331
#   └─ Avg Reward: 229.710 | Success: 18, Crashed: 2, Out of bounds: 0, Time limit: 0
#
# Episode  681 | Steps:  406 | Reward:  225.50 | 🟢 Landed Success | ε: 0.0329
# Episode  682 | Steps:  495 | Reward:  207.33 | 🟢 Landed Success | ε: 0.0328
# Episode  683 | Steps:  678 | Reward:  186.83 | 🟢 Landed Success | ε: 0.0326
# Episode  684 | Steps:  922 | Reward:  217.34 | 🟢 Landed Success | ε: 0.0324
# Episode  685 | Steps:  393 | Reward:  262.60 | 🟢 Landed Success | ε: 0.0323
# Episode  686 | Steps:  413 | Reward:  275.27 | 🟢 Landed Success | ε: 0.0321
# Episode  687 | Steps:  238 | Reward:  249.40 | 🟢 Landed Success | ε: 0.0319
# Episode  688 | Steps:  314 | Reward:  255.93 | 🟢 Landed Success | ε: 0.0318
# Episode  689 | Steps:  296 | Reward:  219.42 | 🟢 Landed Success | ε: 0.0316
# Episode  690 | Steps:  369 | Reward:  294.13 | 🟢 Landed Success | ε: 0.0315
# Episode  691 | Steps:  307 | Reward:  290.55 | 🟢 Landed Success | ε: 0.0313
# Episode  692 | Steps:  354 | Reward:  264.30 | 🟢 Landed Success | ε: 0.0312
# Episode  693 | Steps:  271 | Reward:  299.19 | 🟢 Landed Success | ε: 0.0310
# Episode  694 | Steps:  340 | Reward:  289.10 | 🟢 Landed Success | ε: 0.0308
# Episode  695 | Steps:  249 | Reward:  253.83 | 🟢 Landed Success | ε: 0.0307
# Episode  696 | Steps:  364 | Reward:  265.73 | 🟢 Landed Success | ε: 0.0305
# Episode  697 | Steps:  352 | Reward:  239.93 | 🟢 Landed Success | ε: 0.0304
# Episode  698 | Steps:  258 | Reward:  247.56 | 🟢 Landed Success | ε: 0.0302
# Episode  699 | Steps:  376 | Reward:  251.76 | 🟢 Landed Success | ε: 0.0301
# Episode  700 | Steps:  422 | Reward:  237.55 | 🟢 Landed Success | ε: 0.0299
#   └─ Avg Reward: 251.662 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  701 | Steps:  292 | Reward:  261.23 | 🟢 Landed Success | ε: 0.0298
# Episode  702 | Steps:  244 | Reward:  251.23 | 🟢 Landed Success | ε: 0.0296
# Episode  703 | Steps:  317 | Reward:  263.21 | 🟢 Landed Success | ε: 0.0295
# Episode  704 | Steps:  447 | Reward:  225.04 | 🟢 Landed Success | ε: 0.0293
# Episode  705 | Steps:  276 | Reward:  214.61 | 🟢 Landed Success | ε: 0.0292
# Episode  706 | Steps:  424 | Reward:  245.74 | 🟢 Landed Success | ε: 0.0290
# Episode  707 | Steps:  295 | Reward:  229.73 | 🟢 Landed Success | ε: 0.0289
# Episode  708 | Steps:  374 | Reward:  264.49 | 🟢 Landed Success | ε: 0.0288
# Episode  709 | Steps:  285 | Reward:  247.41 | 🟢 Landed Success | ε: 0.0286
# Episode  710 | Steps:  710 | Reward:  216.42 | 🟢 Landed Success | ε: 0.0285
# Episode  711 | Steps:  349 | Reward:  280.37 | 🟢 Landed Success | ε: 0.0283
# Episode  712 | Steps:  456 | Reward:  223.73 | 🟢 Landed Success | ε: 0.0282
# Episode  713 | Steps:  270 | Reward:  244.02 | 🟢 Landed Success | ε: 0.0280
# Episode  714 | Steps:  288 | Reward:  194.65 | 🟢 Landed Success | ε: 0.0279
# Episode  715 | Steps:  312 | Reward:  265.13 | 🟢 Landed Success | ε: 0.0278
# Episode  716 | Steps:  328 | Reward:  222.12 | 🟢 Landed Success | ε: 0.0276
# Episode  717 | Steps:  342 | Reward:  282.33 | 🟢 Landed Success | ε: 0.0275
# Episode  718 | Steps:  545 | Reward:  257.17 | 🟢 Landed Success | ε: 0.0274
# Episode  719 | Steps:  444 | Reward:  219.44 | 🟢 Landed Success | ε: 0.0272
# Episode  720 | Steps:  312 | Reward:  238.55 | 🟢 Landed Success | ε: 0.0271
#   └─ Avg Reward: 242.331 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  721 | Steps:  314 | Reward:  255.53 | 🟢 Landed Success | ε: 0.0269
# Episode  722 | Steps:  367 | Reward:  203.91 | 🟢 Landed Success | ε: 0.0268
# Episode  723 | Steps:  315 | Reward:  256.02 | 🟢 Landed Success | ε: 0.0267
# Episode  724 | Steps:  335 | Reward:  277.82 | 🟢 Landed Success | ε: 0.0265
# Episode  725 | Steps:  227 | Reward:  264.00 | 🟢 Landed Success | ε: 0.0264
# Episode  726 | Steps:  357 | Reward:  262.43 | 🟢 Landed Success | ε: 0.0263
# Episode  727 | Steps:  376 | Reward:  273.55 | 🟢 Landed Success | ε: 0.0261
# Episode  728 | Steps:  258 | Reward:  243.85 | 🟢 Landed Success | ε: 0.0260
# Episode  729 | Steps:  261 | Reward:  255.10 | 🟢 Landed Success | ε: 0.0259
# Episode  730 | Steps:  565 | Reward:  271.54 | 🟢 Landed Success | ε: 0.0258
# Episode  731 | Steps:  309 | Reward:  253.21 | 🟢 Landed Success | ε: 0.0256
# Episode  732 | Steps:  211 | Reward:  257.68 | 🟢 Landed Success | ε: 0.0255
# Episode  733 | Steps:  232 | Reward:  285.20 | 🟢 Landed Success | ε: 0.0254
# Episode  734 | Steps:  202 | Reward:  226.62 | 🟢 Landed Success | ε: 0.0252
# Episode  735 | Steps:  248 | Reward:  270.28 | 🟢 Landed Success | ε: 0.0251
# Episode  736 | Steps:  348 | Reward:  214.84 | 🟢 Landed Success | ε: 0.0250
# Episode  737 | Steps:  300 | Reward:  292.52 | 🟢 Landed Success | ε: 0.0249
# Episode  738 | Steps:  293 | Reward:  253.37 | 🟢 Landed Success | ε: 0.0247
# Episode  739 | Steps:  252 | Reward:  276.51 | 🟢 Landed Success | ε: 0.0246
# Episode  740 | Steps:  282 | Reward:  221.16 | 🟢 Landed Success | ε: 0.0245
#   └─ Avg Reward: 255.758 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  741 | Steps:  475 | Reward:  294.03 | 🟢 Landed Success | ε: 0.0244
# Episode  742 | Steps:  330 | Reward:  192.88 | 🟢 Landed Success | ε: 0.0243
# Episode  743 | Steps:  449 | Reward:  228.68 | 🟢 Landed Success | ε: 0.0241
# Episode  744 | Steps:  265 | Reward:  257.02 | 🟢 Landed Success | ε: 0.0240
# Episode  745 | Steps:  285 | Reward:  282.22 | 🟢 Landed Success | ε: 0.0239
# Episode  746 | Steps:  290 | Reward:  270.10 | 🟢 Landed Success | ε: 0.0238
# Episode  747 | Steps:  299 | Reward:  246.06 | 🟢 Landed Success | ε: 0.0237
# Episode  748 | Steps:  307 | Reward:  232.16 | 🟢 Landed Success | ε: 0.0235
# Episode  749 | Steps:  313 | Reward:  263.28 | 🟢 Landed Success | ε: 0.0234
# Episode  750 | Steps:  292 | Reward:  265.92 | 🟢 Landed Success | ε: 0.0233
# Episode  751 | Steps:  307 | Reward:  243.73 | 🟢 Landed Success | ε: 0.0232
# Episode  752 | Steps:  262 | Reward:  247.10 | 🟢 Landed Success | ε: 0.0231
# Episode  753 | Steps:  246 | Reward:  231.22 | 🟢 Landed Success | ε: 0.0229
# Episode  754 | Steps:  250 | Reward:  266.37 | 🟢 Landed Success | ε: 0.0228
# Episode  755 | Steps:  351 | Reward:  275.88 | 🟢 Landed Success | ε: 0.0227
# Episode  756 | Steps:  297 | Reward:  279.64 | 🟢 Landed Success | ε: 0.0226
# Episode  757 | Steps:  349 | Reward:  251.90 | 🟢 Landed Success | ε: 0.0225
# Episode  758 | Steps:  351 | Reward:  273.86 | 🟢 Landed Success | ε: 0.0224
# Episode  759 | Steps:  358 | Reward:  247.57 | 🟢 Landed Success | ε: 0.0223
# Episode  760 | Steps:  359 | Reward:  263.14 | 🟢 Landed Success | ε: 0.0222
#   └─ Avg Reward: 255.638 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  761 | Steps:  350 | Reward:  251.06 | 🟢 Landed Success | ε: 0.0220
# Episode  762 | Steps:  351 | Reward:  260.50 | 🟢 Landed Success | ε: 0.0219
# Episode  763 | Steps:  282 | Reward:  259.69 | 🟢 Landed Success | ε: 0.0218
# Episode  764 | Steps:  306 | Reward:  276.24 | 🟢 Landed Success | ε: 0.0217
# Episode  765 | Steps:  325 | Reward:  264.55 | 🟢 Landed Success | ε: 0.0216
# Episode  766 | Steps:  281 | Reward:  274.92 | 🟢 Landed Success | ε: 0.0215
# Episode  767 | Steps:  277 | Reward:  249.28 | 🟢 Landed Success | ε: 0.0214
# Episode  768 | Steps:  256 | Reward:  244.61 | 🟢 Landed Success | ε: 0.0213
# Episode  769 | Steps:  260 | Reward:  236.62 | 🟢 Landed Success | ε: 0.0212
# Episode  770 | Steps:  249 | Reward:  255.00 | 🟢 Landed Success | ε: 0.0211
# Episode  771 | Steps:  248 | Reward:  234.49 | 🟢 Landed Success | ε: 0.0210
# Episode  772 | Steps:  281 | Reward:  255.79 | 🟢 Landed Success | ε: 0.0209
# Episode  773 | Steps:  360 | Reward:  226.75 | 🟢 Landed Success | ε: 0.0208
# Episode  774 | Steps:  258 | Reward:  260.36 | 🟢 Landed Success | ε: 0.0207
# Episode  775 | Steps:  321 | Reward:  284.75 | 🟢 Landed Success | ε: 0.0206
# Episode  776 | Steps:  316 | Reward:  258.29 | 🟢 Landed Success | ε: 0.0205
# Episode  777 | Steps:  282 | Reward:  281.25 | 🟢 Landed Success | ε: 0.0203
# Episode  778 | Steps:  263 | Reward:  230.27 | 🟢 Landed Success | ε: 0.0202
# Episode  779 | Steps:  294 | Reward:  223.26 | 🟢 Landed Success | ε: 0.0201
# Episode  780 | Steps:  337 | Reward:  253.27 | 🟢 Landed Success | ε: 0.0200
#   └─ Avg Reward: 254.048 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# Episode  781 | Steps:  236 | Reward:  266.83 | 🟢 Landed Success | ε: 0.0199
# Episode  782 | Steps:  278 | Reward:  287.33 | 🟢 Landed Success | ε: 0.0198
# Episode  783 | Steps:  227 | Reward:  262.33 | 🟢 Landed Success | ε: 0.0197
# Episode  784 | Steps:  245 | Reward:  271.11 | 🟢 Landed Success | ε: 0.0196
# Episode  785 | Steps:  417 | Reward:  258.66 | 🟢 Landed Success | ε: 0.0195
# Episode  786 | Steps:  227 | Reward:  274.78 | 🟢 Landed Success | ε: 0.0195
# Episode  787 | Steps:  262 | Reward:  295.83 | 🟢 Landed Success | ε: 0.0194
# Episode  788 | Steps:  235 | Reward:  216.25 | 🟢 Landed Success | ε: 0.0193
# Episode  789 | Steps:  275 | Reward:  289.39 | 🟢 Landed Success | ε: 0.0192
# Episode  790 | Steps:  278 | Reward:  252.07 | 🟢 Landed Success | ε: 0.0191
# Episode  791 | Steps:  281 | Reward:  223.12 | 🟢 Landed Success | ε: 0.0190
# Episode  792 | Steps:  309 | Reward:  271.53 | 🟢 Landed Success | ε: 0.0189
# Episode  793 | Steps:  248 | Reward:  289.92 | 🟢 Landed Success | ε: 0.0188
# Episode  794 | Steps:  211 | Reward:  254.85 | 🟢 Landed Success | ε: 0.0187
# Episode  795 | Steps:  296 | Reward:  265.58 | 🟢 Landed Success | ε: 0.0186
# Episode  796 | Steps:  245 | Reward:  301.31 | 🟢 Landed Success | ε: 0.0185
# Episode  797 | Steps:  244 | Reward:  297.43 | 🟢 Landed Success | ε: 0.0184
# Episode  798 | Steps:  516 | Reward:  203.21 | 🟢 Landed Success | ε: 0.0183
# Episode  799 | Steps:  283 | Reward:  274.76 | 🟢 Landed Success | ε: 0.0182
# Episode  800 | Steps:  287 | Reward:  261.62 | 🟢 Landed Success | ε: 0.0181
#   └─ Avg Reward: 265.896 | Success: 20, Crashed: 0, Out of bounds: 0, Time limit: 0
#
# ✅ Logs appended to runs/all_runs_combined.csv
#
# ✅ Training completed for Run 14!
# Total episodes: 800
# Replay buffer size: 50000 transitions
# Total training steps: 371982
# Final epsilon: 0.0181
#
# 📊 Episode Outcomes:
#   🚀 Landed successfully: 419 (52.4%)
#   💥 Crashed: 207 (25.9%)
#   📍 Out of bounds: 23 (2.9%)
#   ⏱️  Time limit: 151 (18.9%)
#
# 📁 Individual log saved to: runs/run_list/run14.csv
# 📁 Combined logs updated: runs/all_runs_combined.csv
# 📁 Configs updated: runs/all_configs_combined.csv

# %% [markdown]
# ## Plot Training Progress

# %%
# Plot episode rewards over time with outcome colors and different markers
fig, ax = plt.subplots(figsize=(14, 6))

# Base line plot
ax.plot(episode_rewards, alpha=0.3, label='Episode Reward', linewidth=1, color='gray')

# Plot moving average
window = 40
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
ax.plot(range(window-1, len(episode_rewards)), moving_avg, linewidth=2.5, 
         label=f'Moving Avg ({window} episodes)', color='black')

# Color and marker mapping for outcomes
outcome_styles = {
    'landed_success': {'color': 'green', 'marker': 'o', 'label': 'Landed Success'},
    'crashed': {'color': 'red', 'marker': 'X', 'label': 'Crashed'},
    'out_of_bounds': {'color': 'yellow', 'marker': '^', 'label': 'Out of Bounds'},
    'time_limit': {'color': 'blue', 'marker': 's', 'label': 'Time Limit'}
}

# Plot scatter points with different markers for each outcome
for outcome, style in outcome_styles.items():
    episodes = [i for i, o in enumerate(episode_outcomes) if o == outcome]
    rewards = [episode_rewards[i] for i in episodes]
    ax.scatter(episodes, rewards, c=style['color'], marker=style['marker'], 
              label=style['label'], s=80, alpha=0.7, edgecolors='black', linewidth=1)

ax.set_xlabel('Episode', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('LunarLander DQN - Training Progress by Outcome', fontsize=14, fontweight='bold')
ax.legend(fontsize=10, loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 Training Statistics:")
print(f"  Average Reward: {np.mean(episode_rewards):.3f}")
print(f"  Max Reward: {np.max(episode_rewards):.3f}")
print(f"  Min Reward: {np.min(episode_rewards):.3f}")
print(f"  Std Dev: {np.std(episode_rewards):.3f}")
# Out:
# 📊 Training Statistics:
#   Average Reward: 99.630
#   Max Reward: 303.431
#   Min Reward: -408.215
#   Std Dev: 160.687

# %% [markdown]
# ## Watch Trained Agent in Action

# %%
from gymnasium.wrappers import RecordVideo
from IPython.display import HTML
import glob
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="rgb_array")
env = RecordVideo(
    env,
    video_folder="videos",
    episode_trigger=lambda episode_id: True,
    name_prefix="trained_agent"
)

obs, info = env.reset()

final_reward = 0.0
terminated = False
truncated = False
episode_steps = 0
final_obs = obs
last_step_reward = 0.0  # ✅ NEW: needed for outcome

agent.set_epsilon(0.0)  # exploit only

while not (terminated or truncated):
    action = agent.act(obs)
    obs, reward, terminated, truncated, info = env.step(action)

    final_reward += reward
    episode_steps += 1
    final_obs = obs
    last_step_reward = reward  # ✅ NEW: keep last step reward

env.close()

# ✅ Categorize episode outcome (correct args)
outcome = categorize_episode_outcome(
    final_obs,
    episode_steps,
    last_step_reward
)
outcome_icon = get_outcome_icon(outcome)

print(f"\n🎬 Trained Agent Performance:")
print(f" Total Reward: {final_reward:.3f}")
print(f" Episode Steps: {episode_steps}")
print(f" Outcome: {outcome_icon} {outcome.replace('_', ' ').title()}")

# pick the newest video (avoids grabbing an older mp4)
video_path = max(glob.glob("videos/*.mp4"), key=lambda p: p)

HTML(f"""
<video width="600" controls autoplay loop>
    <source src="{video_path}" type="video/mp4">
</video>
""")
# Out:
# c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\.venv\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\DataScience_Unitn\Lunar_Lander_Reinforcement_Learning\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 🎬 Trained Agent Performance:
#  Total Reward: 253.644
#  Episode Steps: 313
#  Outcome: 🟢 Landed Success
# <video width="600" controls autoplay loop>
#     <source src="videos\trained_agent-episode-outofbound.mp4" type="video/mp4">
# </video>
