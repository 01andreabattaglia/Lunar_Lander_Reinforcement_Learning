# %% [markdown]
# # LunarLander DQN Training
#
# Interactive training notebook with configurable hyperparameters.

# %%
import gymnasium as gym
from src.envs.make_env import make_env
from src.agents.epsilon_greedy_agent import EpsilonGreedyAgent
from src.networks.q_network import QNetwork
from src.replay.replay_buffer import ReplayBuffer
from src.training.DQN_trainer import Trainer as DQNTrainer
from src.training.DDQN_trainer import Trainer as DDQNTrainer
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Hyperparameters Configuration
#
# Modify these values to tune the training process:

# %%
# ============ TRAINING HYPERPARAMETERS ============
# Model Selection
model_type = 'DQN'  # 'DQN' or 'DDQN' - Choose which algorithm to use

# Environment
num_episodes = 800  # Total number of training episodes
log_interval = 20  # Print stats every N episodes

# Training
train_every = 4  # Training step every N environment steps
batch_size = 64
learning_rate = 0.0001
gamma = 0.99  # Discount factor
replay_buffer_size = 50000  # Maximum size of the replay buffer

# Target Network Update
update_mode = 'soft'  # 'soft' for soft update every step, 'hard' for hard update every N steps
tau = 1e-3  # Soft update rate (used only if update_mode='soft')
target_update_freq = 10  # Hard update frequency (used only if update_mode='hard')

# Exploration
epsilon_starting_value = 1  # Initial exploration rate
epsilon_ending_value = 0.01   # Final exploration rate
epsilon_decay_value = 0.995   # Decay factor per episode

# %% [markdown]
# ## Initialize Components

# %%
# Initialize Q-Network
q_network = QNetwork(input_size=8, output_size=4)

# Initialize epsilon from config
epsilon = epsilon_starting_value

# Initialize agent
agent = EpsilonGreedyAgent(action_space=4, q_network=q_network, epsilon=epsilon)

# Initialize replay buffer
replay_buffer = ReplayBuffer(max_size=replay_buffer_size)

# Initialize trainer based on model_type selection
if model_type == 'DQN':
    trainer = DQNTrainer(
        q_network, 
        learning_rate=learning_rate, 
        replay_buffer=replay_buffer, 
        gamma=gamma,
        update_mode=update_mode,
        tau=tau,
        target_update_freq=target_update_freq
    )
    print(f"🔵 Using DQN Trainer (classic DQN with max over target network)")
elif model_type == 'DDQN':
    trainer = DDQNTrainer(
        q_network, 
        learning_rate=learning_rate, 
        replay_buffer=replay_buffer, 
        gamma=gamma,
        update_mode=update_mode,
        tau=tau,
        target_update_freq=target_update_freq
    )
    print(f"🟢 Using Double DQN Trainer (action selection: online, evaluation: target)")
else:
    raise ValueError(f"Invalid model_type: {model_type}. Must be 'DQN' or 'DDQN'")

# Create environment
env = make_env(render_mode="rgb_array")
# Out:
# 🔵 Using DQN Trainer (classic DQN with max over target network)

# %%
import csv
import os
import pandas as pd
from src.training.episode_outcome import categorize_episode_outcome, get_outcome_icon

# ===== AUTO-INCREMENT RUN ID =====
configs_file = 'runs/all_configs_combined.csv'
runs_file = 'runs/all_runs_combined.csv'

# Read existing configs to find last run_id
df_configs = pd.read_csv(configs_file, dtype={'run_id': str})
last_run_id = df_configs['run_id'].astype(int).max()
new_run_id = str(last_run_id + 1).zfill(2)

print(f"📋 Last run_id found: {last_run_id:02d}")
print(f"🆕 New run_id: {new_run_id}")

# ===== APPEND NEW CONFIG TO all_configs_combined.csv =====
new_config = {
    'run_id': new_run_id,
    'model_type': model_type,
    'num_episodes': num_episodes,
    'log_interval': log_interval,
    'train_every': train_every,
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'gamma': gamma,
    'update_mode': update_mode,
    'tau': tau,
    'target_update_freq': target_update_freq,
    'replay_buffer_size': replay_buffer_size,
    'epsilon_starting_value': epsilon_starting_value,
    'epsilon_ending_value': epsilon_ending_value,
    'epsilon_decay_value': epsilon_decay_value,
    # Policy Gradient specific params (NA for DQN/DDQN)
    'baseline': 'NA',
    'value_lr': 'NA',
    'n_envs': 'NA',
    'n_steps': 'NA',
    'max_grad_norm': 'NA'
}

# Append to configs file
new_config_df = pd.DataFrame([new_config])
new_config_df.to_csv(configs_file, mode='a', header=False, index=False)
print(f"✅ Config appended to {configs_file}")

# ===== SETUP LOG FILE =====
run_list_dir = 'runs/sample_runs_list'
os.makedirs(run_list_dir, exist_ok=True)
log_file = f'{run_list_dir}/run{new_run_id}.csv'

with open(log_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['episode', 'reward', 'length', 'terminated', 'truncated', 'outcome'])

print(f"📁 Log file created: {log_file}")
# Out:
# 📋 Last run_id found: 54
# 🆕 New run_id: 55
# ✅ Config appended to runs/all_configs_combined.csv
# 📁 Log file created: runs/sample_runs_list/run55.csv

# %% [markdown]
# ## Training Loop with Visualization

# %%
# Training loop with episode outcome logging
episode_rewards = []
training_steps = 0
episode_outcomes = []
episode_logs = []  # Store logs for appending to combined file

print(f"🚀 Starting training for Run {new_run_id}...\n")

for episode in range(num_episodes):
    obs, info = env.reset()
    total_reward = 0.0
    terminated = False
    truncated = False
    episode_length = 0
    final_obs = obs
    last_step_reward = 0.0  # keep last reward of the episode

    while not (terminated or truncated):
        # Ask agent for action
        action = agent.act(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)

        # store last step reward (used for outcome classification)
        last_step_reward = reward

        # Store transition in replay buffer
        done = terminated or truncated
        replay_buffer.add(obs, action, reward, next_obs, done)

        # Training step: sample batch and update network
        if training_steps % train_every == 0:
            loss = trainer.train_step(batch_size=batch_size)

        training_steps += 1
        total_reward += reward
        episode_length += 1
        obs = next_obs
        final_obs = next_obs

    episode_rewards.append(total_reward)

    # Categorize episode outcome
    outcome = categorize_episode_outcome(final_obs, episode_length, last_step_reward)
    episode_outcomes.append(outcome)

    # Store log entry
    log_entry = {
        'run_id': new_run_id,
        'episode': episode + 1,
        'reward': round(total_reward, 2),
        'length': episode_length,
        'terminated': int(terminated),
        'truncated': int(truncated),
        'outcome': outcome
    }
    episode_logs.append(log_entry)

    # Log to individual run CSV file
    with open(log_file, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([episode + 1, f"{total_reward:.2f}", episode_length,
                         int(terminated), int(truncated), outcome])

    # Decay epsilon after each episode
    epsilon = max(epsilon_ending_value, epsilon * epsilon_decay_value)
    agent.set_epsilon(epsilon)

    # Print individual episode result
    outcome_icon = get_outcome_icon(outcome)
    print(
        f"Episode {episode + 1:4d} | Steps: {episode_length:4d} | Reward: {total_reward:7.2f} | "
        f"{outcome_icon} {outcome.replace('_', ' ').title()} | ε: {epsilon:.4f}"
    )

    # Log average reward every N episodes
    if (episode + 1) % log_interval == 0:
        avg_reward = sum(episode_rewards[-log_interval:]) / log_interval

        # Count outcomes in recent window
        recent_outcomes = episode_outcomes[-log_interval:]
        outcome_counts = {
            'success': recent_outcomes.count('landed_success'),
            'crashed': recent_outcomes.count('crashed'),
            'out_of_bounds': recent_outcomes.count('out_of_bounds'),
            'time_limit': recent_outcomes.count('time_limit')
        }

        print(
            f"  └─ Avg Reward: {avg_reward:7.3f} | "
            f"Success: {outcome_counts['success']}, "
            f"Crashed: {outcome_counts['crashed']}, "
            f"Out of bounds: {outcome_counts['out_of_bounds']}, "
            f"Time limit: {outcome_counts['time_limit']}"
        )
        print()

env.close()

# ===== APPEND LOGS TO all_runs_combined.csv =====
logs_df = pd.DataFrame(episode_logs)
logs_df.to_csv(runs_file, mode='a', header=False, index=False)
print(f"✅ Logs appended to {runs_file}")

print(f"\n✅ Training completed for Run {new_run_id}!")
print(f"Total episodes: {num_episodes}")
print(f"Replay buffer size: {len(replay_buffer)} transitions")
print(f"Total training steps: {training_steps}")
print(f"Final epsilon: {epsilon:.4f}")

# Final statistics
success_count = episode_outcomes.count('landed_success')
crashed_count = episode_outcomes.count('crashed')
out_of_bounds_count = episode_outcomes.count('out_of_bounds')
time_limit_count = episode_outcomes.count('time_limit')

print(f"\n📊 Episode Outcomes:")
print(f"  🚀 Landed successfully: {success_count} ({100*success_count/num_episodes:.1f}%)")
print(f"  💥 Crashed: {crashed_count} ({100*crashed_count/num_episodes:.1f}%)")
print(f"  📍 Out of bounds: {out_of_bounds_count} ({100*out_of_bounds_count/num_episodes:.1f}%)")
print(f"  ⏱️  Time limit: {time_limit_count} ({100*time_limit_count/num_episodes:.1f}%)")
print(f"\n📁 Individual log saved to: {log_file}")
print(f"📁 Combined logs updated: {runs_file}")
print(f"📁 Configs updated: {configs_file}")
# Out:
# 🚀 Starting training for Run 55...
#
# Episode    1 | Steps:   76 | Reward:  -38.82 | 🔴 Crashed | ε: 0.9950
# Episode    2 | Steps:   66 | Reward: -115.83 | 🔴 Crashed | ε: 0.9900
# Episode    3 | Steps:   97 | Reward: -129.27 | 🔴 Crashed | ε: 0.9851
# Episode    4 | Steps:   82 | Reward: -260.19 | 🔴 Crashed | ε: 0.9801
# Episode    5 | Steps:  110 | Reward: -238.03 | 🔴 Crashed | ε: 0.9752
# Episode    6 | Steps:  117 | Reward: -131.10 | 🔴 Crashed | ε: 0.9704
# Episode    7 | Steps:  112 | Reward: -193.08 | 🔴 Crashed | ε: 0.9655
# Episode    8 | Steps:   91 | Reward: -410.91 | 🟡 Out Of Bounds | ε: 0.9607
# Episode    9 | Steps:   63 | Reward: -213.98 | 🔴 Crashed | ε: 0.9559
# Episode   10 | Steps:  125 | Reward:    4.43 | 🔴 Crashed | ε: 0.9511
# Episode   11 | Steps:  119 | Reward: -291.23 | 🔴 Crashed | ε: 0.9464
# Episode   12 | Steps:  113 | Reward: -209.72 | 🔴 Crashed | ε: 0.9416
# Episode  234 | Steps: 1000 | Reward:   50.03 | 🔵 Time Limit | ε: 0.3095
# Episode  235 | Steps:  540 | Reward:  -59.33 | 🔴 Crashed | ε: 0.3079
# Episode  236 | Steps:  181 | Reward:  -17.00 | 🔴 Crashed | ε: 0.3064
# Episode  237 | Steps: 1000 | Reward:   16.81 | 🔵 Time Limit | ε: 0.3048
# Episode  238 | Steps:  183 | Reward: -192.47 | 🔴 Crashed | ε: 0.3033
# Episode  239 | Steps:  424 | Reward:  213.41 | 🟢 Landed Success | ε: 0.3018
# Episode  240 | Steps: 1000 | Reward: -164.39 | 🔵 Time Limit | ε: 0.3003
#   └─ Avg Reward: -56.405 | Success: 1, Crashed: 11, Out of bounds: 1, Time limit: 7
#
# Episode  241 | Steps: 1000 | Reward: -157.20 | 🔵 Time Limit | ε: 0.2988
# Episode  242 | Steps:  717 | Reward: -160.48 | 🔴 Crashed | ε: 0.2973
# Episode  243 | Steps:  416 | Reward: -312.54 | 🔴 Crashed | ε: 0.2958
# Episode  244 | Steps: 1000 | Reward:  -20.32 | 🔵 Time Limit | ε: 0.2943
# Episode  245 | Steps:  597 | Reward:  -76.68 | 🔴 Crashed | ε: 0.2929
# Episode  246 | Steps: 1000 | Reward:  -45.14 | 🔵 Time Limit | ε: 0.2914
# Episode  247 | Steps: 1000 | Reward:   10.82 | 🔵 Time Limit | ε: 0.2899
# Episode  248 | Steps: 1000 | Reward: -150.24 | 🔵 Time Limit | ε: 0.2885
# Episode  249 | Steps: 1000 | Reward:  -12.35 | 🔵 Time Limit | ε: 0.2870
# Episode  250 | Steps: 1000 | Reward:   93.63 | 🔵 Time Limit | ε: 0.2856
# Episode  251 | Steps: 1000 | Reward:  -52.81 | 🔵 Time Limit | ε: 0.2842
# Episode  252 | Steps:  826 | Reward: -105.00 | 🔴 Crashed | ε: 0.2828
# Episode  253 | Steps: 1000 | Reward:  -14.15 | 🔵 Time Limit | ε: 0.2813
# Episode  254 | Steps: 1000 | Reward:  -40.70 | 🔵 Time Limit | ε: 0.2799
# Episode  255 | Steps: 1000 | Reward: -100.25 | 🔵 Time Limit | ε: 0.2785
# Episode  256 | Steps: 1000 | Reward:  -16.71 | 🔵 Time Limit | ε: 0.2771
# Episode  257 | Steps: 1000 | Reward:   15.03 | 🔵 Time Limit | ε: 0.2758
# Episode  258 | Steps: 1000 | Reward:  -63.16 | 🔵 Time Limit | ε: 0.2744
# Episode  259 | Steps: 1000 | Reward:  -51.09 | 🔵 Time Limit | ε: 0.2730
# Episode  260 | Steps: 1000 | Reward: -104.70 | 🔵 Time Limit | ε: 0.2716
#   └─ Avg Reward: -68.202 | Success: 0, Crashed: 4, Out of bounds: 0, Time limit: 16
#
# Episode  261 | Steps:  301 | Reward:  -23.99 | 🔴 Crashed | ε: 0.2703
# Episode  262 | Steps: 1000 | Reward:   -4.10 | 🔵 Time Limit | ε: 0.2689
# Episode  263 | Steps:  255 | Reward: -130.68 | 🔴 Crashed | ε: 0.2676
# Episode  264 | Steps: 1000 | Reward:  -83.15 | 🔵 Time Limit | ε: 0.2663
# Episode  265 | Steps: 1000 | Reward:   30.68 | 🔵 Time Limit | ε: 0.2649
# Episode  266 | Steps: 1000 | Reward:  -57.62 | 🔵 Time Limit | ε: 0.2636
# Episode  267 | Steps: 1000 | Reward:  -87.47 | 🔵 Time Limit | ε: 0.2623
# Episode  268 | Steps: 1000 | Reward:  -17.95 | 🔵 Time Limit | ε: 0.2610
# Episode  269 | Steps: 1000 | Reward:  -89.48 | 🔵 Time Limit | ε: 0.2597
# Episode  270 | Steps:  191 | Reward: -145.00 | 🔴 Crashed | ε: 0.2584
# Episode  271 | Steps: 1000 | Reward:  -21.31 | 🔵 Time Limit | ε: 0.2571
# Episode  272 | Steps: 1000 | Reward:   27.23 | 🔵 Time Limit | ε: 0.2558
# Episode  273 | Steps: 1000 | Reward:  -52.19 | 🔵 Time Limit | ε: 0.2545
# Episode  274 | Steps: 1000 | Reward:    5.06 | 🔵 Time Limit | ε: 0.2532
# Episode  275 | Steps:  444 | Reward:    4.01 | 🔴 Crashed | ε: 0.2520
# Episode  276 | Steps: 1000 | Reward: -105.47 | 🔵 Time Limit | ε: 0.2507
# Episode  277 | Steps: 1000 | Reward:  -75.77 | 🔵 Time Limit | ε: 0.2495
# Episode  278 | Steps: 1000 | Reward: -100.96 | 🔵 Time Limit | ε: 0.2482
# Episode  279 | Steps: 1000 | Reward:  -96.29 | 🔵 Time Limit | ε: 0.2470
# Episode  280 | Steps: 1000 | Reward:  -58.02 | 🔵 Time Limit | ε: 0.2457
#   └─ Avg Reward: -54.123 | Success: 0, Crashed: 4, Out of bounds: 0, Time limit: 16
#
# Episode  281 | Steps: 1000 | Reward:  -12.57 | 🔵 Time Limit | ε: 0.2445
# Episode  282 | Steps: 1000 | Reward:  -47.87 | 🔵 Time Limit | ε: 0.2433
# Episode  283 | Steps: 1000 | Reward:  -11.43 | 🔵 Time Limit | ε: 0.2421
# Episode  284 | Steps: 1000 | Reward:  -76.38 | 🔵 Time Limit | ε: 0.2409
# Episode  285 | Steps: 1000 | Reward: -112.33 | 🔵 Time Limit | ε: 0.2397
# Episode  286 | Steps: 1000 | Reward:  -15.66 | 🔵 Time Limit | ε: 0.2385
# Episode  287 | Steps: 1000 | Reward:  -46.95 | 🔵 Time Limit | ε: 0.2373
# Episode  288 | Steps: 1000 | Reward:  -61.10 | 🔵 Time Limit | ε: 0.2361
# Episode  289 | Steps: 1000 | Reward:    2.99 | 🔵 Time Limit | ε: 0.2349
# Episode  290 | Steps: 1000 | Reward: -101.58 | 🔵 Time Limit | ε: 0.2337
# Episode  291 | Steps: 1000 | Reward:  -40.84 | 🔵 Time Limit | ε: 0.2326
# Episode  292 | Steps: 1000 | Reward:   16.10 | 🔵 Time Limit | ε: 0.2314
# Episode  293 | Steps: 1000 | Reward:  -75.54 | 🔵 Time Limit | ε: 0.2302
# Episode  294 | Steps: 1000 | Reward:    8.30 | 🔵 Time Limit | ε: 0.2291
# Episode  295 | Steps: 1000 | Reward:  -15.91 | 🔵 Time Limit | ε: 0.2279
# Episode  296 | Steps: 1000 | Reward:  -73.94 | 🔵 Time Limit | ε: 0.2268
# Episode  297 | Steps: 1000 | Reward:  -62.27 | 🔵 Time Limit | ε: 0.2257
# Episode  298 | Steps: 1000 | Reward:   11.62 | 🔵 Time Limit | ε: 0.2245
# Episode  299 | Steps: 1000 | Reward:   14.88 | 🔵 Time Limit | ε: 0.2234
# Episode  300 | Steps: 1000 | Reward:  -48.18 | 🔵 Time Limit | ε: 0.2223
#   └─ Avg Reward: -37.432 | Success: 0, Crashed: 0, Out of bounds: 0, Time limit: 20
#
# Episode  301 | Steps: 1000 | Reward:    9.76 | 🔵 Time Limit | ε: 0.2212
# Episode  302 | Steps: 1000 | Reward:  -13.19 | 🔵 Time Limit | ε: 0.2201
# Episode  303 | Steps: 1000 | Reward:  -71.92 | 🔵 Time Limit | ε: 0.2190
# Episode  304 | Steps: 1000 | Reward:  -40.68 | 🔵 Time Limit | ε: 0.2179
# Episode  305 | Steps: 1000 | Reward:   16.82 | 🔵 Time Limit | ε: 0.2168
# Episode  306 | Steps:  335 | Reward: -140.34 | 🟡 Out Of Bounds | ε: 0.2157
# Episode  307 | Steps: 1000 | Reward:  -59.86 | 🔵 Time Limit | ε: 0.2146
# Episode  308 | Steps: 1000 | Reward:  -43.29 | 🔵 Time Limit | ε: 0.2136
# Episode  309 | Steps: 1000 | Reward:  -20.65 | 🔵 Time Limit | ε: 0.2125
# Episode  310 | Steps:  261 | Reward:  300.30 | 🟢 Landed Success | ε: 0.2114
# Episode  311 | Steps: 1000 | Reward:  -28.64 | 🔵 Time Limit | ε: 0.2104
# Episode  312 | Steps: 1000 | Reward:  -19.06 | 🔵 Time Limit | ε: 0.2093
# Episode  313 | Steps: 1000 | Reward:   16.56 | 🔵 Time Limit | ε: 0.2083
# Episode  314 | Steps: 1000 | Reward:  -45.72 | 🔵 Time Limit | ε: 0.2072
# Episode  315 | Steps: 1000 | Reward:  -33.49 | 🔵 Time Limit | ε: 0.2062
# Episode  316 | Steps: 1000 | Reward:    4.57 | 🔵 Time Limit | ε: 0.2052
# Episode  317 | Steps:  671 | Reward: -198.65 | 🔴 Crashed | ε: 0.2041
# Episode  318 | Steps:  530 | Reward:  -35.72 | 🔴 Crashed | ε: 0.2031
# Episode  319 | Steps: 1000 | Reward:   72.94 | 🔵 Time Limit | ε: 0.2021
# Episode  320 | Steps: 1000 | Reward:  -57.38 | 🔵 Time Limit | ε: 0.2011
#   └─ Avg Reward: -19.382 | Success: 1, Crashed: 2, Out of bounds: 1, Time limit: 16
#
# Episode  321 | Steps: 1000 | Reward:  -31.08 | 🔵 Time Limit | ε: 0.2001
# Episode  322 | Steps: 1000 | Reward:  -52.04 | 🔵 Time Limit | ε: 0.1991
# Episode  323 | Steps: 1000 | Reward:  -19.69 | 🔵 Time Limit | ε: 0.1981
# Episode  324 | Steps: 1000 | Reward:  -67.95 | 🔵 Time Limit | ε: 0.1971
# Episode  356 | Steps: 1000 | Reward:  -28.80 | 🔵 Time Limit | ε: 0.1679
# Episode  357 | Steps:  418 | Reward:  -61.90 | 🟡 Out Of Bounds | ε: 0.1670
# Episode  358 | Steps:  153 | Reward:  -96.70 | 🟡 Out Of Bounds | ε: 0.1662
# Episode  359 | Steps: 1000 | Reward:   -4.09 | 🔵 Time Limit | ε: 0.1654
# Episode  360 | Steps: 1000 | Reward:   40.49 | 🔵 Time Limit | ε: 0.1646
#   └─ Avg Reward: -17.742 | Success: 2, Crashed: 1, Out of bounds: 4, Time limit: 13
#
# Episode  361 | Steps:  433 | Reward:  -24.53 | 🔴 Crashed | ε: 0.1637
# Episode  362 | Steps: 1000 | Reward:    8.79 | 🔵 Time Limit | ε: 0.1629
# Episode  363 | Steps: 1000 | Reward:  -42.37 | 🔵 Time Limit | ε: 0.1621
# Episode  364 | Steps: 1000 | Reward:    5.69 | 🔵 Time Limit | ε: 0.1613
# Episode  365 | Steps: 1000 | Reward:   -5.11 | 🔵 Time Limit | ε: 0.1605
# Episode  366 | Steps: 1000 | Reward:   13.77 | 🔵 Time Limit | ε: 0.1597
# Episode  367 | Steps: 1000 | Reward:  -50.98 | 🔵 Time Limit | ε: 0.1589
# Episode  368 | Steps: 1000 | Reward:  -40.20 | 🔵 Time Limit | ε: 0.1581
# Episode  369 | Steps: 1000 | Reward:   25.30 | 🔵 Time Limit | ε: 0.1573
# Episode  370 | Steps: 1000 | Reward:   41.82 | 🔵 Time Limit | ε: 0.1565
# Episode  371 | Steps:  876 | Reward:  123.19 | 🟢 Landed Success | ε: 0.1557
# Episode  372 | Steps: 1000 | Reward:   25.41 | 🔵 Time Limit | ε: 0.1549
# Episode  373 | Steps:  186 | Reward:  -61.13 | 🟡 Out Of Bounds | ε: 0.1542
# Episode  374 | Steps: 1000 | Reward:   35.91 | 🔵 Time Limit | ε: 0.1534
# Episode  375 | Steps: 1000 | Reward:  -27.08 | 🔵 Time Limit | ε: 0.1526
# Episode  376 | Steps:  493 | Reward:  -88.48 | 🟡 Out Of Bounds | ε: 0.1519
# Episode  377 | Steps: 1000 | Reward:   24.31 | 🔵 Time Limit | ε: 0.1511
# Episode  378 | Steps: 1000 | Reward:  -77.18 | 🔵 Time Limit | ε: 0.1504
# Episode  379 | Steps: 1000 | Reward:   -2.22 | 🔵 Time Limit | ε: 0.1496
# Episode  380 | Steps: 1000 | Reward:  -18.97 | 🔵 Time Limit | ε: 0.1489
#   └─ Avg Reward:  -6.704 | Success: 1, Crashed: 1, Out of bounds: 2, Time limit: 16
#
# Episode  381 | Steps: 1000 | Reward:    4.51 | 🔵 Time Limit | ε: 0.1481
# Episode  382 | Steps: 1000 | Reward:  -48.17 | 🔵 Time Limit | ε: 0.1474
# Episode  383 | Steps: 1000 | Reward:  -46.31 | 🔵 Time Limit | ε: 0.1466
# Episode  384 | Steps: 1000 | Reward:  -73.12 | 🔵 Time Limit | ε: 0.1459
# Episode  385 | Steps:  609 | Reward:  208.79 | 🟢 Landed Success | ε: 0.1452
# Episode  386 | Steps: 1000 | Reward:  -10.32 | 🔵 Time Limit | ε: 0.1444
# Episode  387 | Steps: 1000 | Reward:  -32.95 | 🔵 Time Limit | ε: 0.1437
# Episode  388 | Steps: 1000 | Reward:  -62.18 | 🔵 Time Limit | ε: 0.1430
# Episode  389 | Steps: 1000 | Reward:  -31.84 | 🔵 Time Limit | ε: 0.1423
# Episode  390 | Steps: 1000 | Reward:  -20.79 | 🔵 Time Limit | ε: 0.1416
# Episode  391 | Steps: 1000 | Reward:  -77.31 | 🔵 Time Limit | ε: 0.1409
# Episode  392 | Steps:  826 | Reward: -136.84 | 🟡 Out Of Bounds | ε: 0.1402
# Episode  393 | Steps: 1000 | Reward:  -23.05 | 🔵 Time Limit | ε: 0.1395
# Episode  394 | Steps: 1000 | Reward:  -59.05 | 🔵 Time Limit | ε: 0.1388
# Episode  395 | Steps: 1000 | Reward:  -56.26 | 🔵 Time Limit | ε: 0.1381
# Episode  396 | Steps:  147 | Reward:  -67.06 | 🟡 Out Of Bounds | ε: 0.1374
# Episode  397 | Steps: 1000 | Reward:   29.94 | 🔵 Time Limit | ε: 0.1367
# Episode  398 | Steps:  636 | Reward:  220.87 | 🟢 Landed Success | ε: 0.1360
# Episode  399 | Steps: 1000 | Reward:  -42.65 | 🔵 Time Limit | ε: 0.1353
# Episode  400 | Steps: 1000 | Reward:    2.94 | 🔵 Time Limit | ε: 0.1347
#   └─ Avg Reward: -16.043 | Success: 2, Crashed: 0, Out of bounds: 2, Time limit: 16
#
# Episode  401 | Steps: 1000 | Reward:  -11.78 | 🔵 Time Limit | ε: 0.1340
# Episode  402 | Steps:  174 | Reward:  -54.77 | 🟡 Out Of Bounds | ε: 0.1333
# Episode  403 | Steps: 1000 | Reward:  -23.00 | 🔵 Time Limit | ε: 0.1326
# Episode  404 | Steps:  836 | Reward:  123.01 | 🟢 Landed Success | ε: 0.1320
# Episode  405 | Steps:  783 | Reward:  175.52 | 🟢 Landed Success | ε: 0.1313
# Episode  406 | Steps: 1000 | Reward:   -7.81 | 🔵 Time Limit | ε: 0.1307
# Episode  407 | Steps: 1000 | Reward:  -15.41 | 🔵 Time Limit | ε: 0.1300
# Episode  408 | Steps: 1000 | Reward:    2.43 | 🔵 Time Limit | ε: 0.1294
# Episode  409 | Steps:  324 | Reward:  -13.67 | 🔴 Crashed | ε: 0.1287
# Episode  410 | Steps:  486 | Reward:  186.61 | 🟢 Landed Success | ε: 0.1281
# Episode  411 | Steps:  143 | Reward:  -68.54 | 🟡 Out Of Bounds | ε: 0.1274
# Episode  412 | Steps:  227 | Reward:  -59.58 | 🟡 Out Of Bounds | ε: 0.1268
# Episode  413 | Steps: 1000 | Reward:  -26.63 | 🔵 Time Limit | ε: 0.1262
# Episode  414 | Steps:  862 | Reward:  176.51 | 🟢 Landed Success | ε: 0.1255
# Episode  415 | Steps: 1000 | Reward:  -26.14 | 🔵 Time Limit | ε: 0.1249
# Episode  447 | Steps:  658 | Reward:  266.10 | 🟢 Landed Success | ε: 0.1064
# Episode  448 | Steps:  495 | Reward:  204.50 | 🟢 Landed Success | ε: 0.1059
# Episode  449 | Steps:  554 | Reward:  214.73 | 🟢 Landed Success | ε: 0.1053
# Episode  450 | Steps:  542 | Reward:  223.73 | 🟢 Landed Success | ε: 0.1048
# Episode  451 | Steps:  803 | Reward:  148.63 | 🟢 Landed Success | ε: 0.1043
# Episode  452 | Steps:  725 | Reward:  233.76 | 🟢 Landed Success | ε: 0.1038
# Episode  453 | Steps:  850 | Reward:  144.77 | 🟢 Landed Success | ε: 0.1032
# Episode  454 | Steps:  719 | Reward:  -96.99 | 🔴 Crashed | ε: 0.1027
# Episode  455 | Steps: 1000 | Reward:   24.78 | 🔵 Time Limit | ε: 0.1022
# Episode  456 | Steps:  954 | Reward:  155.40 | 🟢 Landed Success | ε: 0.1017
# Episode  457 | Steps:  910 | Reward:  145.09 | 🟢 Landed Success | ε: 0.1012
# Episode  458 | Steps:  755 | Reward:  201.83 | 🟢 Landed Success | ε: 0.1007
# Episode  459 | Steps: 1000 | Reward:   21.48 | 🔵 Time Limit | ε: 0.1002
# Episode  460 | Steps: 1000 | Reward:  -10.26 | 🔵 Time Limit | ε: 0.0997
#   └─ Avg Reward: 128.299 | Success: 15, Crashed: 2, Out of bounds: 0, Time limit: 3
#
# Episode  461 | Steps:  965 | Reward:  141.15 | 🟢 Landed Success | ε: 0.0992
# Episode  462 | Steps: 1000 | Reward:   -9.51 | 🔵 Time Limit | ε: 0.0987
# Episode  463 | Steps:  552 | Reward: -165.04 | 🟡 Out Of Bounds | ε: 0.0982
# Episode  464 | Steps: 1000 | Reward:  -55.56 | 🔵 Time Limit | ε: 0.0977
# Episode  465 | Steps: 1000 | Reward:   61.01 | 🔵 Time Limit | ε: 0.0972
# Episode  466 | Steps: 1000 | Reward:  -27.17 | 🔵 Time Limit | ε: 0.0967
# Episode  467 | Steps:  892 | Reward:  121.40 | 🟢 Landed Success | ε: 0.0962
# Episode  468 | Steps: 1000 | Reward:   42.01 | 🔵 Time Limit | ε: 0.0958
# Episode  469 | Steps: 1000 | Reward:  -35.78 | 🔵 Time Limit | ε: 0.0953
# Episode  470 | Steps:  737 | Reward:  167.96 | 🟢 Landed Success | ε: 0.0948
# Episode  471 | Steps:  367 | Reward:  -86.21 | 🟡 Out Of Bounds | ε: 0.0943
# Episode  472 | Steps:  842 | Reward:  117.49 | 🟢 Landed Success | ε: 0.0939
# Episode  473 | Steps:  610 | Reward:  210.16 | 🟢 Landed Success | ε: 0.0934
# Episode  474 | Steps: 1000 | Reward:    3.94 | 🔵 Time Limit | ε: 0.0929
# Episode  475 | Steps:  617 | Reward:  178.40 | 🟢 Landed Success | ε: 0.0925
# Episode  476 | Steps:  746 | Reward:  225.27 | 🟢 Landed Success | ε: 0.0920
# Episode  477 | Steps:  718 | Reward:  133.15 | 🟢 Landed Success | ε: 0.0915
# Episode  478 | Steps:  932 | Reward:  164.49 | 🟢 Landed Success | ε: 0.0911
# Episode  479 | Steps: 1000 | Reward:  -54.46 | 🔵 Time Limit | ε: 0.0906
# Episode  480 | Steps: 1000 | Reward:  -24.51 | 🔵 Time Limit | ε: 0.0902
#   └─ Avg Reward:  55.409 | Success: 9, Crashed: 0, Out of bounds: 2, Time limit: 9
#
# Episode  481 | Steps: 1000 | Reward:    1.44 | 🔵 Time Limit | ε: 0.0897
# Episode  482 | Steps:  508 | Reward:  185.54 | 🟢 Landed Success | ε: 0.0893
# Episode  483 | Steps:  724 | Reward:  170.98 | 🟢 Landed Success | ε: 0.0888
# Episode  484 | Steps:  952 | Reward:  120.96 | 🟢 Landed Success | ε: 0.0884
# Episode  485 | Steps:  721 | Reward:  124.20 | 🟢 Landed Success | ε: 0.0879
# Episode  486 | Steps: 1000 | Reward:  -45.10 | 🔵 Time Limit | ε: 0.0875
# Episode  487 | Steps:  295 | Reward:  -56.61 | 🔴 Crashed | ε: 0.0871
# Episode  488 | Steps:  920 | Reward:   60.14 | 🟢 Landed Success | ε: 0.0866
# Episode  489 | Steps: 1000 | Reward:   24.47 | 🔵 Time Limit | ε: 0.0862
# Episode  490 | Steps: 1000 | Reward:  -50.63 | 🔵 Time Limit | ε: 0.0858
# Episode  491 | Steps:  188 | Reward:  -54.80 | 🟡 Out Of Bounds | ε: 0.0853
# Episode  492 | Steps:  585 | Reward:  159.08 | 🟢 Landed Success | ε: 0.0849
# Episode  493 | Steps:  607 | Reward:  181.34 | 🟢 Landed Success | ε: 0.0845
# Episode  494 | Steps:  412 | Reward:  215.93 | 🟢 Landed Success | ε: 0.0841
# Episode  495 | Steps:  610 | Reward:  169.61 | 🟢 Landed Success | ε: 0.0836
# Episode  496 | Steps:  706 | Reward:  201.00 | 🟢 Landed Success | ε: 0.0832
# Episode  497 | Steps: 1000 | Reward:  -31.51 | 🔵 Time Limit | ε: 0.0828
# Episode  498 | Steps: 1000 | Reward:   -1.83 | 🔵 Time Limit | ε: 0.0824
# Episode  499 | Steps:  616 | Reward:  -35.78 | 🔴 Crashed | ε: 0.0820
# Episode  500 | Steps: 1000 | Reward:  -62.35 | 🔵 Time Limit | ε: 0.0816
#   └─ Avg Reward:  63.804 | Success: 10, Crashed: 2, Out of bounds: 1, Time limit: 7
#
# Episode  501 | Steps: 1000 | Reward:   52.56 | 🔵 Time Limit | ε: 0.0812
# Episode  502 | Steps:  462 | Reward:  227.88 | 🟢 Landed Success | ε: 0.0808
# Episode  503 | Steps:  971 | Reward:  116.87 | 🟢 Landed Success | ε: 0.0804
# Episode  504 | Steps:  832 | Reward:  195.15 | 🟢 Landed Success | ε: 0.0800
# Episode  505 | Steps:  434 | Reward:  235.06 | 🟢 Landed Success | ε: 0.0796
# Episode  506 | Steps:  227 | Reward:  -46.67 | 🟡 Out Of Bounds | ε: 0.0792
# Episode  507 | Steps:  513 | Reward:  190.76 | 🟢 Landed Success | ε: 0.0788
# Episode  792 | Steps:  276 | Reward:  261.55 | 🟢 Landed Success | ε: 0.0189
# Episode  793 | Steps:  120 | Reward:   78.74 | 🔴 Crashed | ε: 0.0188
# Episode  794 | Steps:  187 | Reward:  264.62 | 🟢 Landed Success | ε: 0.0187
# Episode  795 | Steps:  256 | Reward:  240.90 | 🟢 Landed Success | ε: 0.0186
# Episode  796 | Steps:  265 | Reward:  236.96 | 🟢 Landed Success | ε: 0.0185
# Episode  797 | Steps:  229 | Reward:  231.98 | 🟢 Landed Success | ε: 0.0184
# Episode  798 | Steps:  214 | Reward:  198.45 | 🟢 Landed Success | ε: 0.0183
# Episode  799 | Steps:  211 | Reward:  263.93 | 🟢 Landed Success | ε: 0.0182
# Episode  800 | Steps:  251 | Reward:  249.74 | 🟢 Landed Success | ε: 0.0181
#   └─ Avg Reward: 238.872 | Success: 19, Crashed: 1, Out of bounds: 0, Time limit: 0
#
# ✅ Logs appended to runs/all_runs_combined.csv
#
# ✅ Training completed for Run 55!
# Total episodes: 800
# Replay buffer size: 50000 transitions
# Total training steps: 417191
# Final epsilon: 0.0181
#
# 📊 Episode Outcomes:
#   🚀 Landed successfully: 326 (40.8%)
#   💥 Crashed: 240 (30.0%)
#   📍 Out of bounds: 39 (4.9%)
#   ⏱️  Time limit: 195 (24.4%)
#
# 📁 Individual log saved to: runs/sample_runs_list/run55.csv
# 📁 Combined logs updated: runs/all_runs_combined.csv
# 📁 Configs updated: runs/all_configs_combined.csv

# %% [markdown]
# ## Plot Training Progress

# %%
# Plot episode rewards over time with outcome colors and different markers
fig, ax = plt.subplots(figsize=(14, 6))

# Base line plot
ax.plot(episode_rewards, alpha=0.3, label='Episode Reward', linewidth=1, color='gray')

# Plot moving average
window = 20
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
ax.plot(range(window-1, len(episode_rewards)), moving_avg, linewidth=2.5, 
         label=f'Moving Avg ({window} episodes)', color='black')

# Color and marker mapping for outcomes
outcome_styles = {
    'landed_success': {'color': 'green', 'marker': 'o', 'label': 'Landed Success'},
    'crashed': {'color': 'red', 'marker': 'X', 'label': 'Crashed'},
    'out_of_bounds': {'color': 'yellow', 'marker': '^', 'label': 'Out of Bounds'},
    'time_limit': {'color': 'blue', 'marker': 's', 'label': 'Time Limit'}
}

# Plot scatter points with different markers for each outcome
for outcome, style in outcome_styles.items():
    episodes = [i for i, o in enumerate(episode_outcomes) if o == outcome]
    rewards = [episode_rewards[i] for i in episodes]
    ax.scatter(episodes, rewards, c=style['color'], marker=style['marker'], 
              label=style['label'], s=80, alpha=0.7, edgecolors='black', linewidth=1)

ax.set_xlabel('Episode', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('LunarLander DQN - Training Progress by Outcome', fontsize=14, fontweight='bold')
ax.legend(fontsize=10, loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 Training Statistics:")
print(f"  Average Reward: {np.mean(episode_rewards):.3f}")
print(f"  Max Reward: {np.max(episode_rewards):.3f}")
print(f"  Min Reward: {np.min(episode_rewards):.3f}")
print(f"  Std Dev: {np.std(episode_rewards):.3f}")
# Out:
# 📊 Training Statistics:
#   Average Reward: 34.354
#   Max Reward: 311.227
#   Min Reward: -569.780
#   Std Dev: 168.401

# %% [markdown]
# ## Watch Trained Agent in Action

# %%
from IPython.display import HTML
import gymnasium as gym
import imageio
import os

# ========== NUMBER OF EPISODES TO RECORD ==========
num_video_episodes = 5  # Change this to record more/fewer episodes
# ==================================================

env = gym.make("LunarLander-v3", render_mode="rgb_array")

agent.set_epsilon(0.0)  # exploit only

# Collect all frames from all episodes
all_frames = []
all_rewards = []
all_outcomes = []
all_steps = []

for ep in range(num_video_episodes):
    obs, info = env.reset()
    
    episode_reward = 0.0
    terminated = False
    truncated = False
    episode_steps = 0
    final_obs = obs
    last_step_reward = 0.0

    # Capture initial frame
    all_frames.append(env.render())

    while not (terminated or truncated):
        action = agent.act(obs)
        obs, reward, terminated, truncated, info = env.step(action)

        # Capture frame
        all_frames.append(env.render())

        episode_reward += reward
        episode_steps += 1
        final_obs = obs
        last_step_reward = reward

    # Categorize episode outcome
    outcome = categorize_episode_outcome(final_obs, episode_steps, last_step_reward)
    outcome_icon = get_outcome_icon(outcome)
    
    all_rewards.append(episode_reward)
    all_outcomes.append(outcome)
    all_steps.append(episode_steps)
    
    print(f"Episode {ep+1}/{num_video_episodes} | Reward: {episode_reward:7.2f} | Steps: {episode_steps:4d} | {outcome_icon} {outcome.replace('_', ' ').title()}")

env.close()

# Create single video with all episodes
os.makedirs("videos", exist_ok=True)
video_path = "videos/trained_agent_combined.mp4"
imageio.mimsave(video_path, all_frames, fps=50)

print(f"\n🎬 Video saved: {video_path}")
print(f"   Total frames: {len(all_frames)}")
print(f"   Duration: ~{len(all_frames)/50:.1f} seconds")

# Print summary
print(f"\n📊 Trained Agent Performance ({num_video_episodes} episodes):")
print(f"  Average Reward: {np.mean(all_rewards):.2f}")
print(f"  Max Reward: {np.max(all_rewards):.2f}")
print(f"  Min Reward: {np.min(all_rewards):.2f}")
print(f"  Success Rate: {all_outcomes.count('landed_success')}/{num_video_episodes}")

HTML(f"""
<video width="600" controls autoplay loop>
    <source src="{video_path}" type="video/mp4">
</video>
""")
# Out:
# Episode 1/5 | Reward:  281.39 | Steps:  187 | 🟢 Landed Success
# Episode 2/5 | Reward:  282.94 | Steps:  200 | 🟢 Landed Success
# Episode 3/5 | Reward:  234.12 | Steps:  277 | 🟢 Landed Success
# Episode 4/5 | Reward:  248.39 | Steps:  222 | 🟢 Landed Success
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode 5/5 | Reward:  269.23 | Steps:  195 | 🟢 Landed Success
#
# 🎬 Video saved: videos/trained_agent_combined.mp4
#    Total frames: 1086
#    Duration: ~21.7 seconds
#
# 📊 Trained Agent Performance (5 episodes):
#   Average Reward: 263.21
#   Max Reward: 282.94
#   Min Reward: 234.12
#   Success Rate: 5/5
# <video width="600" controls autoplay loop>
#     <source src="videos/trained_agent_combined.mp4" type="video/mp4">
# </video>
